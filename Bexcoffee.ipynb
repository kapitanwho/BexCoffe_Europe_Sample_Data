# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], 
columns=["A","B","C"], 
index=["x","y","z"])

# %%
df.nunique() # How many unique values are there?
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.isnull().sum() # How many missing values are there?
# Out:
# A    0
# B    0
# C    0
# dtype: int64

# %%
df.duplicated().sum() # How many duplicate rows are there?
# Out:
# np.int64(0)

# %%
df['A'].unique() # unique values in column A
# Out:
# array([1, 4, 7])

# %%
df.shape # shape of the dataframe
# Out:
# (3, 3)

# %% [markdown]
# ### Coffee DF

# %%
cdf = pd.read_csv('index_1.csv')
cdf2 = pd.read_csv('index_2.csv')

# %%
cdf.head(1)
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
#
#   coffee_name
# 0       Latte

# %%
#pd.merge(cdf, cdf2, on='date', how='inner')
cdfs =pd.concat([cdf, cdf2], axis=0)
# axis 1 means columns
# axis 0 means rows

# %%
cdfs['date'] = pd.to_datetime(cdfs['date'])

# %%
cdfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3898 entries, 0 to 261
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3898 non-null   datetime64[ns]
#  1   datetime     3898 non-null   object
#  2   cash_type    3898 non-null   object
#  3   card         3547 non-null   object
#  4   money        3898 non-null   float64
#  5   coffee_name  3898 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 213.2+ KB

# %%
cdfs['time'] = cdfs['datetime'].str.split(' ').str[1]

# %%
cdfs['ztime'] = cdfs['time'].str.split('.').str[0]

# %%
cdfs.info()
cdfs.iloc[:,5:7]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3898 entries, 0 to 261
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3898 non-null   datetime64[ns]
#  1   datetime     3898 non-null   object
#  2   cash_type    3898 non-null   object
#  3   card         3547 non-null   object
#  4   money        3898 non-null   float64
#  5   coffee_name  3898 non-null   object
#  6   time         3898 non-null   object
#  7   ztime        3898 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 274.1+ KB
#                     coffee_name          time
# 0                         Latte  10:15:50.520
# 1                 Hot Chocolate  12:19:22.539
# 2                 Hot Chocolate  12:20:18.089
# 3                     Americano  13:46:33.006
# 4                         Latte  13:48:14.626
# ..                          ...           ...
# 257                  Cappuccino      14:55:46
# 258               Irish whiskey      15:15:36
# 259             Super chocolate      17:59:25
# 260  Vanilla with Irish whiskey      18:01:33
# 261   Coffee with Irish whiskey      21:23:11
#
# [3898 rows x 2 columns]

# %%
cdfs.drop('datetime', axis=1, inplace=True)
#cdfs.drop('htime', axis=1, inplace=True)
cdfs.drop('time', axis=1, inplace=True)

# %%
cdfst = cdfs['ztime']
cdfs.insert(1,'htime',cdfst)

# %%
cdfs.drop('ztime', axis=1, inplace=True)

# %%
cdfs.sample(2, random_state=3) 
#random sample from the data frame
# Out:
#            date     htime cash_type                 card  money  \
# 20   2025-02-09  18:01:22      card                  NaN  33.00
# 2713 2025-01-04  16:12:55      card  ANON-0000-0000-1034  30.86
#
#               coffee_name
# 20                  Latte
# 2713  Americano with Milk

# %%
cdfs.loc[:,'date':'card'] #Rows,Columns
# Out:
#           date     htime cash_type                 card
# 0   2024-03-01  10:15:50      card  ANON-0000-0000-0001
# 1   2024-03-01  12:19:22      card  ANON-0000-0000-0002
# 2   2024-03-01  12:20:18      card  ANON-0000-0000-0002
# 3   2024-03-01  13:46:33      card  ANON-0000-0000-0003
# 4   2024-03-01  13:48:14      card  ANON-0000-0000-0004
# ..         ...       ...       ...                  ...
# 257 2025-03-23  14:55:46      cash                  NaN
# 258 2025-03-23  15:15:36      card                  NaN
# 259 2025-03-23  17:59:25      card                  NaN
# 260 2025-03-23  18:01:33      card                  NaN
# 261 2025-03-23  21:23:11      card                  NaN
#
# [3898 rows x 4 columns]

# %%
cdfs.loc[:,['date','money','cash_type']].groupby(
    ['date','cash_type']).sum()
# Out:
#                        money
# date       cash_type
# 2024-03-01 card       396.30
# 2024-03-02 card       188.10
#            cash        40.00
# 2024-03-03 card       309.10
#            cash        40.00
# ...                      ...
# 2025-03-21 card       741.80
# 2025-03-22 card       566.42
#            cash        47.00
# 2025-03-23 card       314.76
#            cash       105.00
#
# [470 rows x 1 columns]

# %%
cdfs.loc[:,['coffee_name','money']].groupby(
    'coffee_name').agg(
        {'money':'sum','coffee_name':'count'})
# Out:
#                                money  coffee_name
# coffee_name
# Americano                   15437.26          593
# Americano with Milk         25269.12          824
# Americano with milk          1100.00           44
# Cappuccino                  18514.14          517
# Caramel                        22.00            1
# Caramel coffee                 56.00            2
# Caramel with Irish whiskey    224.00            8
# Caramel with chocolate        112.00            4
# Caramel with milk              75.00            3
# Chocolate                      25.00            1
# Chocolate with coffee         150.00            5
# Chocolate with milk           324.00           12
# Cocoa                        8678.16          243
# Coffee with Irish whiskey     464.00           16
# Coffee with chocolate          28.00            1
# Cortado                      7534.86          292
# Double Irish whiskey          336.00           12
# Double chocolate               25.00            1
# Double espresso                27.00            1
# Double espresso with milk      64.00            2
# Double ristretto               27.00            1
# Double vanilla                 47.00            2
# Espresso                     3187.28          152
# Hot Chocolate               10172.46          282
# Hot milkshake                  30.00            1
# Irish whiskey                 525.00           21
# Irish whiskey with milk       405.00           15
# Irish with chocolate          135.00            5
# Latte                       28658.30          806
# Mochaccino                    150.00            5
# Super chocolate               168.00            6
# Tea                           240.00           16
# Vanilla coffee                 27.00            1
# Vanilla with Irish whiskey     84.00            3

# %%
cdfs['month'] = cdfs['date'].dt.month

# %%
cdfs.index = cdfs['month']
# Resetted index as month

# %%
cdfs.loc[3, ['coffee_name', 'money']]
# Give me the coffee_name and money records of the 
# 3rd of the months
# Out:
#                       coffee_name  money
# month
# 3                           Latte   38.7
# 3                   Hot Chocolate   38.7
# 3                   Hot Chocolate   38.7
# 3                       Americano   28.9
# 3                           Latte   38.7
# ...                           ...    ...
# 3                      Cappuccino   30.0
# 3                   Irish whiskey   25.0
# 3                 Super chocolate   28.0
# 3      Vanilla with Irish whiskey   28.0
# 3       Coffee with Irish whiskey   29.0
#
# [649 rows x 2 columns]

# %%
# Get 3 columns at one time with double brackets
cdfs[['coffee_name','money','cash_type']].sample(n=3)
# Out:
#                coffee_name  money cash_type
# month
# 11           Hot Chocolate  35.76      card
# 1      Americano with Milk  30.86      card
# 11                   Latte  35.76      card

# %%
cdfs[cdfs['coffee_name'].str.contains(
    'Espresso')].sample(1)
# Out:
#             date     htime cash_type                 card  money coffee_name  \
# month
# 2     2025-02-22  12:59:41      card  ANON-0000-0000-0095  21.06    Espresso
#
#        month
# month
# 2          2

# %%
cdfs[cdfs['coffee_name'].str.contains(
    '^A.*o$')].sample(1)
# Out:
#             date     htime cash_type                 card  money coffee_name  \
# month
# 2     2025-02-14  17:03:16      card  ANON-0000-0000-1160  25.96   Americano
#
#        month
# month
# 2          2

# %%
cdfs[cdfs['cash_type'].isin(['card']) & 
(cdfs['coffee_name'].str.contains('Americano')) &
(cdfs['money'] >= 33 ) &
(cdfs['cash_type'] == 'card')
].sample(n=1)
# Out:
#             date     htime cash_type                 card  money  \
# month
# 3     2024-03-01  19:23:15      card  ANON-0000-0000-0008   33.8
#
#                coffee_name  month
# month
# 3      Americano with Milk      3

# %%
cdfs.query('coffee_name == "Espresso"'
 and 'cash_type == "card"').sample(n=1)
# Out:
#             date     htime cash_type                 card  money coffee_name  \
# month
# 3     2025-03-14  15:54:20      card  ANON-0000-0000-1191  35.76       Latte
#
#        month
# month
# 3          3

# %%
# New price for cocoa and
# fixed price for other coffees
cdfs['new_price'] = np.where(cdfs['coffee_name'] == 
'Cocoa', 5.99, 50.99)

# %%
cdfs.drop('new_price', axis=1, inplace=True)

# %%
cdfs = cdfs.reset_index(drop=True)

# %%
sorti_col = [('money','sum'),
            ('coffee_name','count')]
order = [True,False]

# %%
cdfs_monthly = cdfs.loc[(cdfs['date'].dt.year == 2024) &
(cdfs['date'].dt.month == 5) &
(cdfs['money'] > 1)].groupby('coffee_name').agg(
    {'money': ['sum','median'],
    'coffee_name': 'count'}).sort_values(
        by=sorti_col, ascending=order)
cdfs_monthly.columns = ['_'.join(column).strip() for 
column in cdfs_monthly.columns]
cdfs_monthly
# Out:
#                      money_sum  money_median  coffee_name_count
# coffee_name
# Espresso                185.14         23.02                  8
# Cocoa                   340.76         37.72                  9
# Cortado                 474.64         27.92                 17
# Hot Chocolate           529.36         37.72                 14
# Americano              1348.80         27.92                 48
# Americano with Milk    1908.28         32.82                 58
# Cappuccino             2078.44         37.72                 55
# Latte                  2198.00         37.72                 58

# %% [markdown]
# --------------

# %%
cdfs.isnull().sum()
# Out:
# date             0
# htime            0
# cash_type        0
# card           351
# money            0
# coffee_name      0
# month            0
# dtype: int64

# %%
# Creating a mask for NaN values
# axis = 1 for column
# axis = 0 for row
cdfs_nan_mask = cdfs.isna().any(axis=1)
cdfs_nan = cdfs.loc[cdfs_nan_mask]

# %%
cdfs_nan.drop('card', axis=1, inplace=True)
# Out:
# /var/folders/b2/qc1xpbnn1wxdq6xmj3kvxxvw0000gn/T/ipykernel_3634/188055965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdfs_nan.drop('card', axis=1, inplace=True)

# %%
# Dividing them into card and cash payments 
cdfs_card = cdfs_nan[cdfs_nan['cash_type'] == 'card']
cdfs_cash = cdfs_nan[cdfs_nan['cash_type'] == 'cash']

# %%
cdfs_card.groupby('coffee_name')['money'].agg(
    {'sum', 'median','count'}).sort_values('count', ascending=False)
# Out:
#                               sum  count  median
# coffee_name
# Americano with milk         700.0     28    25.0
# Latte                       660.0     20    33.0
# Irish whiskey               400.0     16    25.0
# Coffee with Irish whiskey   377.0     13    29.0
# Irish whiskey with milk     324.0     12    27.0
# Cappuccino                  330.0     11    30.0
# Tea                         150.0     10    15.0
# Double Irish whiskey        280.0     10    28.0
# Espresso                    193.0      9    20.0
# Americano                   225.0      9    25.0
# Caramel with Irish whiskey  224.0      8    28.0
# Chocolate with milk         135.0      5    27.0
# Irish with chocolate        135.0      5    27.0
# Super chocolate             112.0      4    28.0
# Caramel with chocolate      112.0      4    28.0
# Chocolate with coffee        90.0      3    30.0
# Mochaccino                   60.0      2    30.0
# Vanilla with Irish whiskey   56.0      2    28.0
# Double espresso with milk    64.0      2    32.0
# Caramel with milk            50.0      2    25.0
# Caramel coffee               56.0      2    28.0
# Hot milkshake                30.0      1    30.0
# Double vanilla               27.0      1    27.0
# Chocolate                    25.0      1    25.0
# Vanilla coffee               27.0      1    27.0
# Double ristretto             27.0      1    27.0

# %%
cdfs_cash_grouped_year = cdfs_cash.groupby(['coffee_name',
cdfs_cash['date'].dt.year])['money'].agg(['median','sum','count'])
###
cdfs_card_grouped_year = cdfs_card.groupby(['coffee_name',
cdfs_card['date'].dt.year])['money'].agg(['median','sum','count'])

# %%
# indexing on groupby objects
cdfs_cash_grouped_year.loc[('Americano',2024),:]
# Out:
# median     29.0
# sum       412.0
# count      14.0
# Name: (Americano, 2024), dtype: float64

# %%
cdfs_cash_grouped_month = cdfs_cash.groupby(['coffee_name',
cdfs_cash['date'].dt.month])['money'].agg(['median','sum','count'])
########
cdfs_card_grouped_month = cdfs_card.groupby(['coffee_name',
cdfs_card['date'].dt.month])['money'].agg(['median','sum','count'])

# %%
a = cdfs.groupby(['coffee_name', 
cdfs['date'].dt.month, 'money']).agg(
    {'coffee_name': 'count', 'money': 'sum'})

# %%
# indexing on groupby objects
a.loc[('Americano',2),:]
# Out:
#        coffee_name    money
# money
# 25.00            7   175.00
# 25.96          117  3037.32

# %%
# First sorting by money then if money is same for different dates,
# sorting by date with ascending order    
cdfs.sort_values(by = ['money','date'], 
ascending=True)
# Out:
#            date     htime cash_type card  money    coffee_name  month
# 3636 2025-02-08  14:26:04      cash  NaN   15.0            Tea      2
# 3637 2025-02-08  14:28:26      cash  NaN   15.0            Tea      2
# 3657 2025-02-09  18:01:22      card  NaN   15.0            Tea      2
# 3663 2025-02-11  09:49:22      card  NaN   15.0            Tea      2
# 3683 2025-02-15  15:33:24      card  NaN   15.0            Tea      2
# ...         ...       ...       ...  ...    ...            ...    ...
# 264  2024-04-10  17:55:07      cash  NaN   40.0  Hot Chocolate      4
# 277  2024-04-13  15:06:52      cash  NaN   40.0  Hot Chocolate      4
# 278  2024-04-13  15:07:55      cash  NaN   40.0  Hot Chocolate      4
# 283  2024-04-14  10:55:27      cash  NaN   40.0          Latte      4
# 311  2024-04-17  16:13:24      cash  NaN   40.0     Cappuccino      4
#
# [3898 rows x 7 columns]

# %%
cdfs.sort_values(by = ['money','date'], 
ascending=[False, True])
# Money is descending, date is ascending order sorted
# Out:
#            date     htime cash_type card  money    coffee_name  month
# 12   2024-03-02  10:30:35      cash  NaN   40.0          Latte      3
# 18   2024-03-03  10:10:43      cash  NaN   40.0          Latte      3
# 46   2024-03-07  10:08:58      cash  NaN   40.0          Latte      3
# 49   2024-03-07  11:25:43      cash  NaN   40.0          Latte      3
# 60   2024-03-09  11:49:37      cash  NaN   40.0  Hot Chocolate      3
# ...         ...       ...       ...  ...    ...            ...    ...
# 3756 2025-02-26  12:22:20      card  NaN   15.0            Tea      2
# 3764 2025-02-27  17:04:29      cash  NaN   15.0            Tea      2
# 3776 2025-03-01  12:48:46      cash  NaN   15.0            Tea      3
# 3842 2025-03-15  13:12:26      card  NaN   15.0            Tea      3
# 3883 2025-03-22  16:59:05      card  NaN   15.0            Tea      3
#
# [3898 rows x 7 columns]

# %%
# Iterating over rows by index 
# also can navigate by column name in the loop
for index, row in cdfs.iterrows():
    print(index)
    print(row.iloc[5]) # or row['column_name']
    print("\n")
# Out:
# 0
# Latte
#
#
# 1
# Hot Chocolate
#
#
# 2
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 4
# Latte
#
#
# 5
# Americano with Milk
#
#
# 6
# Hot Chocolate
#
#
# 7
# Americano with Milk
#
#
# 8
# Cocoa
#
#
# 9
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 11
# Americano
#
#
# 12
# Latte
#
#
# 13
# Americano with Milk
#
#
# 14
# Americano with Milk
#
#
# 15
# Americano
#
#
# 16
# Americano with Milk
#
#
# 17
# Americano
#
#
# 18
# Latte
#
#
# 19
# Latte
#
#
# 20
# Cortado
#
#
# 21
# Americano
#
#
# 22
# Hot Chocolate
#
#
# 23
# Cocoa
#
#
# 24
# Cortado
#
#
# 25
# Americano with Milk
#
#
# 26
# Americano with Milk
#
#
# 27
# Hot Chocolate
#
#
# 28
# Latte
#
#
# 29
# Latte
#
#
# 30
# Americano with Milk
#
#
# 31
# Espresso
#
#
# 32
# Latte
#
#
# 33
# Latte
#
#
# 34
# Latte
#
#
# 35
# Hot Chocolate
#
#
# 36
# Cocoa
#
#
# 37
# Hot Chocolate
#
#
# 38
# Hot Chocolate
#
#
# 39
# Cortado
#
#
# 40
# Hot Chocolate
#
#
# 41
# Americano with Milk
#
#
# 42
# Americano
#
#
# 43
# Cortado
#
#
# 44
# Cappuccino
#
#
# 45
# Cappuccino
#
#
# 46
# Latte
#
#
# 47
# Hot Chocolate
#
#
# 48
# Latte
#
#
# 49
# Latte
#
#
# 50
# Americano
#
#
# 51
# Americano with Milk
#
#
# 52
# Cortado
#
#
# 53
# Cappuccino
#
#
# 54
# Americano
#
#
# 55
# Americano
#
#
# 56
# Americano
#
#
# 57
# Americano with Milk
#
#
# 58
# Latte
#
#
# 59
# Latte
#
#
# 60
# Hot Chocolate
#
#
# 61
# Espresso
#
#
# 62
# Americano
#
#
# 63
# Cappuccino
#
#
# 64
# Americano
#
#
# 65
# Americano
#
#
# 66
# Latte
#
#
# 67
# Americano with Milk
#
#
# 68
# Cortado
#
#
# 69
# Cappuccino
#
#
# 70
# Americano with Milk
#
#
# 71
# Hot Chocolate
#
#
# 72
# Cappuccino
#
#
# 73
# Hot Chocolate
#
#
# 74
# Americano
#
#
# 75
# Americano with Milk
#
#
# 76
# Latte
#
#
# 77
# Espresso
#
#
# 78
# Americano with Milk
#
#
# 79
# Latte
#
#
# 80
# Cortado
#
#
# 81
# Latte
#
#
# 82
# Cappuccino
#
#
# 83
# Cortado
#
#
# 84
# Americano
#
#
# 85
# Cappuccino
#
#
# 86
# Americano
#
#
# 87
# Latte
#
#
# 88
# Cortado
#
#
# 89
# Latte
#
#
# 90
# Americano
#
#
# 91
# Cortado
#
#
# 92
# Hot Chocolate
#
#
# 93
# Americano with Milk
#
#
# 94
# Americano
#
#
# 95
# Americano
#
#
# 96
# Hot Chocolate
#
#
# 97
# Americano
#
#
# 98
# Americano
#
#
# 99
# Americano
#
#
# 100
# Espresso
#
#
# 101
# Americano with Milk
#
#
# 102
# Espresso
#
#
# 103
# Espresso
#
#
# 104
# Espresso
#
#
# 105
# Latte
#
#
# 106
# Latte
#
#
# 107
# Hot Chocolate
#
#
# 108
# Cortado
#
#
# 109
# Americano
#
#
# 110
# Americano with Milk
#
#
# 111
# Espresso
#
#
# 112
# Latte
#
#
# 113
# Americano with Milk
#
#
# 114
# Espresso
#
#
# 115
# Hot Chocolate
#
#
# 116
# Cortado
#
#
# 117
# Latte
#
#
# 118
# Hot Chocolate
#
#
# 119
# Americano
#
#
# 120
# Americano with Milk
#
#
# 121
# Americano
#
#
# 122
# Cortado
#
#
# 123
# Cortado
#
#
# 124
# Cortado
#
#
# 125
# Americano with Milk
#
#
# 126
# Latte
#
#
# 127
# Cortado
#
#
# 128
# Cortado
#
#
# 129
# Americano
#
#
# 130
# Americano
#
#
# 131
# Americano
#
#
# 132
# Cortado
#
#
# 133
# Latte
#
#
# 134
# Latte
#
#
# 135
# Hot Chocolate
#
#
# 136
# Americano with Milk
#
#
# 137
# Hot Chocolate
#
#
# 138
# Cortado
#
#
# 139
# Latte
#
#
# 140
# Cortado
#
#
# 141
# Cappuccino
#
#
# 142
# Cocoa
#
#
# 143
# Latte
#
#
# 144
# Cappuccino
#
#
# 145
# Cortado
#
#
# 146
# Cappuccino
#
#
# 147
# Americano
#
#
# 148
# Cortado
#
#
# 149
# Latte
#
#
# 150
# Americano with Milk
#
#
# 151
# Americano with Milk
#
#
# 152
# Cappuccino
#
#
# 153
# Americano
#
#
# 154
# Espresso
#
#
# 155
# Americano
#
#
# 156
# Latte
#
#
# 157
# Americano with Milk
#
#
# 158
# Cappuccino
#
#
# 159
# Cocoa
#
#
# 160
# Americano with Milk
#
#
# 161
# Latte
#
#
# 162
# Americano with Milk
#
#
# 163
# Cortado
#
#
# 164
# Latte
#
#
# 165
# Latte
#
#
# 166
# Latte
#
#
# 167
# Americano with Milk
#
#
# 168
# Latte
#
#
# 169
# Latte
#
#
# 170
# Americano with Milk
#
#
# 171
# Cappuccino
#
#
# 172
# Cocoa
#
#
# 173
# Latte
#
#
# 174
# Latte
#
#
# 175
# Cortado
#
#
# 176
# Americano
#
#
# 177
# Cortado
#
#
# 178
# Cortado
#
#
# 179
# Americano
#
#
# 180
# Latte
#
#
# 181
# Latte
#
#
# 182
# Hot Chocolate
#
#
# 183
# Cortado
#
#
# 184
# Americano with Milk
#
#
# 185
# Americano with Milk
#
#
# 186
# Hot Chocolate
#
#
# 187
# Cappuccino
#
#
# 188
# Americano
#
#
# 189
# Cortado
#
#
# 190
# Latte
#
#
# 191
# Cortado
#
#
# 192
# Cortado
#
#
# 193
# Americano
#
#
# 194
# Latte
#
#
# 195
# Latte
#
#
# 196
# Cappuccino
#
#
# 197
# Cappuccino
#
#
# 198
# Cappuccino
#
#
# 199
# Latte
#
#
# 200
# Cappuccino
#
#
# 201
# Latte
#
#
# 202
# Latte
#
#
# 203
# Americano with Milk
#
#
# 204
# Cappuccino
#
#
# 205
# Americano
#
#
# 206
# Americano
#
#
# 207
# Americano with Milk
#
#
# 208
# Americano with Milk
#
#
# 209
# Americano with Milk
#
#
# 210
# Cappuccino
#
#
# 211
# Americano with Milk
#
#
# 212
# Hot Chocolate
#
#
# 213
# Latte
#
#
# 214
# Americano
#
#
# 215
# Cortado
#
#
# 216
# Cappuccino
#
#
# 217
# Cortado
#
#
# 218
# Americano
#
#
# 219
# Cappuccino
#
#
# 220
# Cortado
#
#
# 221
# Latte
#
#
# 222
# Latte
#
#
# 223
# Cappuccino
#
#
# 224
# Cortado
#
#
# 225
# Latte
#
#
# 226
# Americano
#
#
# 227
# Americano
#
#
# 228
# Cortado
#
#
# 229
# Americano with Milk
#
#
# 230
# Latte
#
#
# 231
# Cortado
#
#
# 232
# Latte
#
#
# 233
# Cappuccino
#
#
# 234
# Americano
#
#
# 235
# Cocoa
#
#
# 236
# Espresso
#
#
# 237
# Americano with Milk
#
#
# 238
# Cappuccino
#
#
# 239
# Americano
#
#
# 240
# Latte
#
#
# 241
# Latte
#
#
# 242
# Cappuccino
#
#
# 243
# Cappuccino
#
#
# 244
# Cortado
#
#
# 245
# Espresso
#
#
# 246
# Hot Chocolate
#
#
# 247
# Americano with Milk
#
#
# 248
# Americano with Milk
#
#
# 249
# Cappuccino
#
#
# 250
# Americano
#
#
# 251
# Cappuccino
#
#
# 252
# Espresso
#
#
# 253
# Americano with Milk
#
#
# 254
# Latte
#
#
# 255
# Americano
#
#
# 256
# Americano with Milk
#
#
# 257
# Cappuccino
#
#
# 258
# Cappuccino
#
#
# 259
# Americano
#
#
# 260
# Latte
#
#
# 261
# Hot Chocolate
#
#
# 262
# Hot Chocolate
#
#
# 263
# Espresso
#
#
# 264
# Hot Chocolate
#
#
# 265
# Espresso
#
#
# 266
# Cappuccino
#
#
# 267
# Latte
#
#
# 268
# Americano
#
#
# 269
# Americano
#
#
# 270
# Latte
#
#
# 271
# Cappuccino
#
#
# 272
# Americano with Milk
#
#
# 273
# Hot Chocolate
#
#
# 274
# Cortado
#
#
# 275
# Latte
#
#
# 276
# Americano
#
#
# 277
# Hot Chocolate
#
#
# 278
# Hot Chocolate
#
#
# 279
# Cappuccino
#
#
# 280
# Latte
#
#
# 281
# Cappuccino
#
#
# 282
# Cappuccino
#
#
# 283
# Latte
#
#
# 284
# Cappuccino
#
#
# 285
# Cortado
#
#
# 286
# Cortado
#
#
# 287
# Americano with Milk
#
#
# 288
# Cortado
#
#
# 289
# Americano
#
#
# 290
# Americano
#
#
# 291
# Americano
#
#
# 292
# Cappuccino
#
#
# 293
# Cortado
#
#
# 294
# Latte
#
#
# 295
# Cappuccino
#
#
# 296
# Americano
#
#
# 297
# Americano
#
#
# 298
# Americano with Milk
#
#
# 299
# Americano with Milk
#
#
# 300
# Espresso
#
#
# 301
# Americano with Milk
#
#
# 302
# Americano with Milk
#
#
# 303
# Cocoa
#
#
# 304
# Cortado
#
#
# 305
# Americano
#
#
# 306
# Americano with Milk
#
#
# 307
# Cappuccino
#
#
# 308
# Cocoa
#
#
# 309
# Americano
#
#
# 310
# Espresso
#
#
# 311
# Cappuccino
#
#
# 312
# Cappuccino
#
#
# 313
# Cappuccino
#
#
# 314
# Cortado
#
#
# 315
# Americano
#
#
# 316
# Americano
#
#
# 317
# Americano with Milk
#
#
# 318
# Cortado
#
#
# 319
# Cappuccino
#
#
# 320
# Latte
#
#
# 321
# Latte
#
#
# 322
# Cappuccino
#
#
# 323
# Hot Chocolate
#
#
# 324
# Hot Chocolate
#
#
# 325
# Latte
#
#
# 326
# Americano with Milk
#
#
# 327
# Cappuccino
#
#
# 328
# Hot Chocolate
#
#
# 329
# Cappuccino
#
#
# 330
# Cocoa
#
#
# 331
# Americano with Milk
#
#
# 332
# Americano with Milk
#
#
# 333
# Americano with Milk
#
#
# 334
# Americano with Milk
#
#
# 335
# Americano
#
#
# 336
# Americano with Milk
#
#
# 337
# Hot Chocolate
#
#
# 338
# Cappuccino
#
#
# 339
# Americano with Milk
#
#
# 340
# Americano with Milk
#
#
# 341
# Americano with Milk
#
#
# 342
# Cocoa
#
#
# 343
# Cappuccino
#
#
# 344
# Cappuccino
#
#
# 345
# Latte
#
#
# 346
# Latte
#
#
# 347
# Americano
#
#
# 348
# Cappuccino
#
#
# 349
# Americano
#
#
# 350
# Americano with Milk
#
#
# 351
# Latte
#
#
# 352
# Latte
#
#
# 353
# Cappuccino
#
#
# 354
# Cappuccino
#
#
# 355
# Americano with Milk
#
#
# 356
# Cappuccino
#
#
# 357
# Americano with Milk
#
#
# 358
# Americano with Milk
#
#
# 359
# Latte
#
#
# 360
# Americano with Milk
#
#
# 361
# Americano with Milk
#
#
# 362
# Americano with Milk
#
#
# 363
# Americano with Milk
#
#
# 364
# Americano with Milk
#
#
# 365
# Americano with Milk
#
#
# 366
# Cappuccino
#
#
# 367
# Americano
#
#
# 368
# Latte
#
#
# 369
# Americano
#
#
# 370
# Americano
#
#
# 371
# Latte
#
#
# 372
# Latte
#
#
# 373
# Cappuccino
#
#
# 374
# Americano
#
#
# 375
# Americano
#
#
# 376
# Cortado
#
#
# 377
# Americano
#
#
# 378
# Hot Chocolate
#
#
# 379
# Cocoa
#
#
# 380
# Cappuccino
#
#
# 381
# Latte
#
#
# 382
# Cappuccino
#
#
# 383
# Americano
#
#
# 384
# Americano
#
#
# 385
# Latte
#
#
# 386
# Cortado
#
#
# 387
# Americano
#
#
# 388
# Cortado
#
#
# 389
# Cortado
#
#
# 390
# Americano with Milk
#
#
# 391
# Cappuccino
#
#
# 392
# Cappuccino
#
#
# 393
# Cappuccino
#
#
# 394
# Latte
#
#
# 395
# Americano with Milk
#
#
# 396
# Americano with Milk
#
#
# 397
# Americano
#
#
# 398
# Americano with Milk
#
#
# 399
# Cappuccino
#
#
# 400
# Americano with Milk
#
#
# 401
# Latte
#
#
# 402
# Americano
#
#
# 403
# Latte
#
#
# 404
# Americano with Milk
#
#
# 405
# Cappuccino
#
#
# 406
# Americano with Milk
#
#
# 407
# Latte
#
#
# 408
# Cappuccino
#
#
# 409
# Latte
#
#
# 410
# Latte
#
#
# 411
# Latte
#
#
# 412
# Americano
#
#
# 413
# Cappuccino
#
#
# 414
# Americano with Milk
#
#
# 415
# Americano
#
#
# 416
# Cortado
#
#
# 417
# Americano
#
#
# 418
# Cortado
#
#
# 419
# Americano
#
#
# 420
# Cappuccino
#
#
# 421
# Cappuccino
#
#
# 422
# Cocoa
#
#
# 423
# Cortado
#
#
# 424
# Cortado
#
#
# 425
# Cocoa
#
#
# 426
# Americano
#
#
# 427
# Cappuccino
#
#
# 428
# Latte
#
#
# 429
# Americano with Milk
#
#
# 430
# Cappuccino
#
#
# 431
# Cappuccino
#
#
# 432
# Latte
#
#
# 433
# Cappuccino
#
#
# 434
# Americano
#
#
# 435
# Latte
#
#
# 436
# Latte
#
#
# 437
# Latte
#
#
# 438
# Americano
#
#
# 439
# Americano
#
#
# 440
# Americano
#
#
# 441
# Americano with Milk
#
#
# 442
# Latte
#
#
# 443
# Latte
#
#
# 444
# Latte
#
#
# 445
# Americano with Milk
#
#
# 446
# Latte
#
#
# 447
# Latte
#
#
# 448
# Americano with Milk
#
#
# 449
# Cocoa
#
#
# 450
# Cappuccino
#
#
# 451
# Americano with Milk
#
#
# 452
# Cappuccino
#
#
# 453
# Latte
#
#
# 454
# Latte
#
#
# 455
# Latte
#
#
# 456
# Americano
#
#
# 457
# Latte
#
#
# 458
# Americano with Milk
#
#
# 459
# Americano with Milk
#
#
# 460
# Americano with Milk
#
#
# 461
# Americano with Milk
#
#
# 462
# Americano with Milk
#
#
# 463
# Americano
#
#
# 464
# Americano
#
#
# 465
# Americano
#
#
# 466
# Americano
#
#
# 467
# Americano
#
#
# 468
# Cappuccino
#
#
# 469
# Latte
#
#
# 470
# Cappuccino
#
#
# 471
# Cappuccino
#
#
# 472
# Americano with Milk
#
#
# 473
# Americano
#
#
# 474
# Americano with Milk
#
#
# 475
# Cappuccino
#
#
# 476
# Hot Chocolate
#
#
# 477
# Latte
#
#
# 478
# Espresso
#
#
# 479
# Americano
#
#
# 480
# Americano
#
#
# 481
# Americano
#
#
# 482
# Americano
#
#
# 483
# Americano with Milk
#
#
# 484
# Americano
#
#
# 485
# Cortado
#
#
# 486
# Cortado
#
#
# 487
# Espresso
#
#
# 488
# Cappuccino
#
#
# 489
# Americano with Milk
#
#
# 490
# Americano with Milk
#
#
# 491
# Latte
#
#
# 492
# Cappuccino
#
#
# 493
# Americano with Milk
#
#
# 494
# Hot Chocolate
#
#
# 495
# Latte
#
#
# 496
# Hot Chocolate
#
#
# 497
# Latte
#
#
# 498
# Americano
#
#
# 499
# Americano with Milk
#
#
# 500
# Americano with Milk
#
#
# 501
# Americano with Milk
#
#
# 502
# Cappuccino
#
#
# 503
# Cappuccino
#
#
# 504
# Americano
#
#
# 505
# Latte
#
#
# 506
# Latte
#
#
# 507
# Cappuccino
#
#
# 508
# Cappuccino
#
#
# 509
# Americano with Milk
#
#
# 510
# Americano with Milk
#
#
# 511
# Americano with Milk
#
#
# 512
# Americano with Milk
#
#
# 513
# Latte
#
#
# 514
# Cappuccino
#
#
# 515
# Americano
#
#
# 516
# Americano
#
#
# 517
# Cappuccino
#
#
# 518
# Espresso
#
#
# 519
# Americano with Milk
#
#
# 520
# Americano
#
#
# 521
# Americano with Milk
#
#
# 522
# Americano with Milk
#
#
# 523
# Espresso
#
#
# 524
# Hot Chocolate
#
#
# 525
# Cappuccino
#
#
# 526
# Cappuccino
#
#
# 527
# Cappuccino
#
#
# 528
# Americano with Milk
#
#
# 529
# Latte
#
#
# 530
# Latte
#
#
# 531
# Americano
#
#
# 532
# Americano
#
#
# 533
# Americano
#
#
# 534
# Americano
#
#
# 535
# Americano with Milk
#
#
# 536
# Cappuccino
#
#
# 537
# Americano
#
#
# 538
# Latte
#
#
# 539
# Latte
#
#
# 540
# Americano with Milk
#
#
# 541
# Cocoa
#
#
# 542
# Cortado
#
#
# 543
# Americano with Milk
#
#
# 544
# Americano with Milk
#
#
# 545
# Latte
#
#
# 546
# Americano
#
#
# 547
# Americano with Milk
#
#
# 548
# Cocoa
#
#
# 549
# Latte
#
#
# 550
# Latte
#
#
# 551
# Espresso
#
#
# 552
# Cappuccino
#
#
# 553
# Cappuccino
#
#
# 554
# Cappuccino
#
#
# 555
# Americano with Milk
#
#
# 556
# Cortado
#
#
# 557
# Americano with Milk
#
#
# 558
# Americano
#
#
# 559
# Americano
#
#
# 560
# Americano with Milk
#
#
# 561
# Cappuccino
#
#
# 562
# Cappuccino
#
#
# 563
# Hot Chocolate
#
#
# 564
# Cappuccino
#
#
# 565
# Cappuccino
#
#
# 566
# Espresso
#
#
# 567
# Cappuccino
#
#
# 568
# Cappuccino
#
#
# 569
# Cappuccino
#
#
# 570
# Latte
#
#
# 571
# Cappuccino
#
#
# 572
# Latte
#
#
# 573
# Cortado
#
#
# 574
# Cappuccino
#
#
# 575
# Cappuccino
#
#
# 576
# Cappuccino
#
#
# 577
# Cappuccino
#
#
# 578
# Latte
#
#
# 579
# Americano with Milk
#
#
# 580
# Hot Chocolate
#
#
# 581
# Cortado
#
#
# 582
# Americano
#
#
# 583
# Americano
#
#
# 584
# Hot Chocolate
#
#
# 585
# Cortado
#
#
# 586
# Cortado
#
#
# 587
# Americano with Milk
#
#
# 588
# Americano
#
#
# 589
# Latte
#
#
# 590
# Americano
#
#
# 591
# Americano with Milk
#
#
# 592
# Americano with Milk
#
#
# 593
# Americano with Milk
#
#
# 594
# Americano with Milk
#
#
# 595
# Americano
#
#
# 596
# Latte
#
#
# 597
# Americano with Milk
#
#
# 598
# Cortado
#
#
# 599
# Americano with Milk
#
#
# 600
# Cappuccino
#
#
# 601
# Hot Chocolate
#
#
# 602
# Hot Chocolate
#
#
# 603
# Americano
#
#
# 604
# Latte
#
#
# 605
# Hot Chocolate
#
#
# 606
# Cappuccino
#
#
# 607
# Cortado
#
#
# 608
# Cappuccino
#
#
# 609
# Latte
#
#
# 610
# Cappuccino
#
#
# 611
# Americano
#
#
# 612
# Americano with Milk
#
#
# 613
# Cocoa
#
#
# 614
# Americano
#
#
# 615
# Americano
#
#
# 616
# Latte
#
#
# 617
# Americano
#
#
# 618
# Latte
#
#
# 619
# Latte
#
#
# 620
# Americano with Milk
#
#
# 621
# Cappuccino
#
#
# 622
# Americano with Milk
#
#
# 623
# Americano with Milk
#
#
# 624
# Cappuccino
#
#
# 625
# Cappuccino
#
#
# 626
# Cocoa
#
#
# 627
# Cortado
#
#
# 628
# Cappuccino
#
#
# 629
# Americano
#
#
# 630
# Latte
#
#
# 631
# Americano with Milk
#
#
# 632
# Americano
#
#
# 633
# Latte
#
#
# 634
# Latte
#
#
# 635
# Hot Chocolate
#
#
# 636
# Americano
#
#
# 637
# Latte
#
#
# 638
# Cappuccino
#
#
# 639
# Latte
#
#
# 640
# Cortado
#
#
# 641
# Latte
#
#
# 642
# Hot Chocolate
#
#
# 643
# Cocoa
#
#
# 644
# Cappuccino
#
#
# 645
# Latte
#
#
# 646
# Americano with Milk
#
#
# 647
# Latte
#
#
# 648
# Americano with Milk
#
#
# 649
# Espresso
#
#
# 650
# Espresso
#
#
# 651
# Cappuccino
#
#
# 652
# Latte
#
#
# 653
# Hot Chocolate
#
#
# 654
# Americano with Milk
#
#
# 655
# Americano with Milk
#
#
# 656
# Latte
#
#
# 657
# Latte
#
#
# 658
# Hot Chocolate
#
#
# 659
# Cocoa
#
#
# 660
# Americano with Milk
#
#
# 661
# Latte
#
#
# 662
# Latte
#
#
# 663
# Cappuccino
#
#
# 664
# Americano with Milk
#
#
# 665
# Latte
#
#
# 666
# Cappuccino
#
#
# 667
# Americano with Milk
#
#
# 668
# Cortado
#
#
# 669
# Cortado
#
#
# 670
# Latte
#
#
# 671
# Latte
#
#
# 672
# Americano with Milk
#
#
# 673
# Americano with Milk
#
#
# 674
# Americano with Milk
#
#
# 675
# Cappuccino
#
#
# 676
# Cappuccino
#
#
# 677
# Cocoa
#
#
# 678
# Cocoa
#
#
# 679
# Americano with Milk
#
#
# 680
# Latte
#
#
# 681
# Americano with Milk
#
#
# 682
# Cappuccino
#
#
# 683
# Americano with Milk
#
#
# 684
# Latte
#
#
# 685
# Americano with Milk
#
#
# 686
# Latte
#
#
# 687
# Latte
#
#
# 688
# Cappuccino
#
#
# 689
# Americano with Milk
#
#
# 690
# Latte
#
#
# 691
# Americano with Milk
#
#
# 692
# Americano with Milk
#
#
# 693
# Cortado
#
#
# 694
# Americano with Milk
#
#
# 695
# Latte
#
#
# 696
# Hot Chocolate
#
#
# 697
# Latte
#
#
# 698
# Cortado
#
#
# 699
# Cappuccino
#
#
# 700
# Hot Chocolate
#
#
# 701
# Cappuccino
#
#
# 702
# Cortado
#
#
# 703
# Americano with Milk
#
#
# 704
# Americano with Milk
#
#
# 705
# Americano with Milk
#
#
# 706
# Americano with Milk
#
#
# 707
# Cappuccino
#
#
# 708
# Cappuccino
#
#
# 709
# Americano
#
#
# 710
# Latte
#
#
# 711
# Americano with Milk
#
#
# 712
# Americano with Milk
#
#
# 713
# Latte
#
#
# 714
# Cocoa
#
#
# 715
# Cortado
#
#
# 716
# Americano with Milk
#
#
# 717
# Americano with Milk
#
#
# 718
# Latte
#
#
# 719
# Americano
#
#
# 720
# Americano with Milk
#
#
# 721
# Cappuccino
#
#
# 722
# Latte
#
#
# 723
# Latte
#
#
# 724
# Cappuccino
#
#
# 725
# Americano with Milk
#
#
# 726
# Latte
#
#
# 727
# Cappuccino
#
#
# 728
# Espresso
#
#
# 729
# Americano with Milk
#
#
# 730
# Cortado
#
#
# 731
# Cortado
#
#
# 732
# Cortado
#
#
# 733
# Americano with Milk
#
#
# 734
# Cappuccino
#
#
# 735
# Cappuccino
#
#
# 736
# Latte
#
#
# 737
# Latte
#
#
# 738
# Cappuccino
#
#
# 739
# Cortado
#
#
# 740
# Espresso
#
#
# 741
# Cappuccino
#
#
# 742
# Americano with Milk
#
#
# 743
# Latte
#
#
# 744
# Latte
#
#
# 745
# Cortado
#
#
# 746
# Cappuccino
#
#
# 747
# Americano with Milk
#
#
# 748
# Americano
#
#
# 749
# Cappuccino
#
#
# 750
# Latte
#
#
# 751
# Hot Chocolate
#
#
# 752
# Hot Chocolate
#
#
# 753
# Latte
#
#
# 754
# Latte
#
#
# 755
# Americano with Milk
#
#
# 756
# Latte
#
#
# 757
# Latte
#
#
# 758
# Hot Chocolate
#
#
# 759
# Americano with Milk
#
#
# 760
# Americano with Milk
#
#
# 761
# Hot Chocolate
#
#
# 762
# Cappuccino
#
#
# 763
# Latte
#
#
# 764
# Latte
#
#
# 765
# Hot Chocolate
#
#
# 766
# Americano with Milk
#
#
# 767
# Americano
#
#
# 768
# Latte
#
#
# 769
# Americano with Milk
#
#
# 770
# Cortado
#
#
# 771
# Americano with Milk
#
#
# 772
# Hot Chocolate
#
#
# 773
# Latte
#
#
# 774
# Americano with Milk
#
#
# 775
# Espresso
#
#
# 776
# Espresso
#
#
# 777
# Americano with Milk
#
#
# 778
# Americano with Milk
#
#
# 779
# Cortado
#
#
# 780
# Americano
#
#
# 781
# Latte
#
#
# 782
# Americano with Milk
#
#
# 783
# Cappuccino
#
#
# 784
# Latte
#
#
# 785
# Americano with Milk
#
#
# 786
# Espresso
#
#
# 787
# Cocoa
#
#
# 788
# Americano with Milk
#
#
# 789
# Americano with Milk
#
#
# 790
# Americano
#
#
# 791
# Americano with Milk
#
#
# 792
# Latte
#
#
# 793
# Hot Chocolate
#
#
# 794
# Hot Chocolate
#
#
# 795
# Americano with Milk
#
#
# 796
# Espresso
#
#
# 797
# Americano with Milk
#
#
# 798
# Americano with Milk
#
#
# 799
# Hot Chocolate
#
#
# 800
# Hot Chocolate
#
#
# 801
# Americano with Milk
#
#
# 802
# Americano with Milk
#
#
# 803
# Americano
#
#
# 804
# Cortado
#
#
# 805
# Cortado
#
#
# 806
# Cappuccino
#
#
# 807
# Cappuccino
#
#
# 808
# Cappuccino
#
#
# 809
# Cappuccino
#
#
# 810
# Americano
#
#
# 811
# Americano
#
#
# 812
# Americano with Milk
#
#
# 813
# Americano
#
#
# 814
# Cappuccino
#
#
# 815
# Cappuccino
#
#
# 816
# Cappuccino
#
#
# 817
# Cortado
#
#
# 818
# Americano with Milk
#
#
# 819
# Americano with Milk
#
#
# 820
# Latte
#
#
# 821
# Cortado
#
#
# 822
# Americano
#
#
# 823
# Latte
#
#
# 824
# Cocoa
#
#
# 825
# Americano with Milk
#
#
# 826
# Cappuccino
#
#
# 827
# Latte
#
#
# 828
# Americano with Milk
#
#
# 829
# Cappuccino
#
#
# 830
# Americano with Milk
#
#
# 831
# Latte
#
#
# 832
# Latte
#
#
# 833
# Latte
#
#
# 834
# Latte
#
#
# 835
# Latte
#
#
# 836
# Americano with Milk
#
#
# 837
# Latte
#
#
# 838
# Americano
#
#
# 839
# Americano with Milk
#
#
# 840
# Americano with Milk
#
#
# 841
# Espresso
#
#
# 842
# Latte
#
#
# 843
# Cappuccino
#
#
# 844
# Cappuccino
#
#
# 845
# Cappuccino
#
#
# 846
# Cappuccino
#
#
# 847
# Americano
#
#
# 848
# Americano with Milk
#
#
# 849
# Cortado
#
#
# 850
# Americano with Milk
#
#
# 851
# Americano with Milk
#
#
# 852
# Latte
#
#
# 853
# Cappuccino
#
#
# 854
# Americano with Milk
#
#
# 855
# Americano with Milk
#
#
# 856
# Cappuccino
#
#
# 857
# Latte
#
#
# 858
# Cappuccino
#
#
# 859
# Americano with Milk
#
#
# 860
# Cappuccino
#
#
# 861
# Cappuccino
#
#
# 862
# Latte
#
#
# 863
# Cappuccino
#
#
# 864
# Cappuccino
#
#
# 865
# Latte
#
#
# 866
# Americano with Milk
#
#
# 867
# Americano with Milk
#
#
# 868
# Cappuccino
#
#
# 869
# Latte
#
#
# 870
# Espresso
#
#
# 871
# Americano
#
#
# 872
# Latte
#
#
# 873
# Cappuccino
#
#
# 874
# Americano with Milk
#
#
# 875
# Americano with Milk
#
#
# 876
# Cortado
#
#
# 877
# Americano with Milk
#
#
# 878
# Cappuccino
#
#
# 879
# Cortado
#
#
# 880
# Espresso
#
#
# 881
# Americano with Milk
#
#
# 882
# Latte
#
#
# 883
# Cappuccino
#
#
# 884
# Americano with Milk
#
#
# 885
# Americano with Milk
#
#
# 886
# Americano with Milk
#
#
# 887
# Cappuccino
#
#
# 888
# Cappuccino
#
#
# 889
# Cappuccino
#
#
# 890
# Hot Chocolate
#
#
# 891
# Latte
#
#
# 892
# Latte
#
#
# 893
# Espresso
#
#
# 894
# Hot Chocolate
#
#
# 895
# Americano with Milk
#
#
# 896
# Espresso
#
#
# 897
# Cappuccino
#
#
# 898
# Cappuccino
#
#
# 899
# Americano with Milk
#
#
# 900
# Americano
#
#
# 901
# Latte
#
#
# 902
# Americano
#
#
# 903
# Americano with Milk
#
#
# 904
# Americano with Milk
#
#
# 905
# Americano with Milk
#
#
# 906
# Cappuccino
#
#
# 907
# Cappuccino
#
#
# 908
# Americano with Milk
#
#
# 909
# Americano with Milk
#
#
# 910
# Latte
#
#
# 911
# Espresso
#
#
# 912
# Cappuccino
#
#
# 913
# Latte
#
#
# 914
# Americano with Milk
#
#
# 915
# Americano
#
#
# 916
# Cocoa
#
#
# 917
# Americano with Milk
#
#
# 918
# Americano with Milk
#
#
# 919
# Espresso
#
#
# 920
# Americano
#
#
# 921
# Espresso
#
#
# 922
# Americano
#
#
# 923
# Americano
#
#
# 924
# Cappuccino
#
#
# 925
# Americano with Milk
#
#
# 926
# Latte
#
#
# 927
# Latte
#
#
# 928
# Latte
#
#
# 929
# Latte
#
#
# 930
# Americano with Milk
#
#
# 931
# Cappuccino
#
#
# 932
# Americano with Milk
#
#
# 933
# Americano with Milk
#
#
# 934
# Cappuccino
#
#
# 935
# Cappuccino
#
#
# 936
# Hot Chocolate
#
#
# 937
# Cocoa
#
#
# 938
# Latte
#
#
# 939
# Cappuccino
#
#
# 940
# Hot Chocolate
#
#
# 941
# Americano with Milk
#
#
# 942
# Latte
#
#
# 943
# Americano
#
#
# 944
# Americano
#
#
# 945
# Americano with Milk
#
#
# 946
# Latte
#
#
# 947
# Americano with Milk
#
#
# 948
# Americano with Milk
#
#
# 949
# Americano with Milk
#
#
# 950
# Cappuccino
#
#
# 951
# Americano with Milk
#
#
# 952
# Americano
#
#
# 953
# Americano with Milk
#
#
# 954
# Latte
#
#
# 955
# Hot Chocolate
#
#
# 956
# Americano with Milk
#
#
# 957
# Latte
#
#
# 958
# Americano
#
#
# 959
# Cortado
#
#
# 960
# Hot Chocolate
#
#
# 961
# Hot Chocolate
#
#
# 962
# Hot Chocolate
#
#
# 963
# Hot Chocolate
#
#
# 964
# Latte
#
#
# 965
# Latte
#
#
# 966
# Americano
#
#
# 967
# Americano with Milk
#
#
# 968
# Cappuccino
#
#
# 969
# Latte
#
#
# 970
# Americano
#
#
# 971
# Latte
#
#
# 972
# Cappuccino
#
#
# 973
# Americano with Milk
#
#
# 974
# Hot Chocolate
#
#
# 975
# Americano with Milk
#
#
# 976
# Americano with Milk
#
#
# 977
# Espresso
#
#
# 978
# Americano
#
#
# 979
# Americano
#
#
# 980
# Cortado
#
#
# 981
# Latte
#
#
# 982
# Cappuccino
#
#
# 983
# Latte
#
#
# 984
# Hot Chocolate
#
#
# 985
# Latte
#
#
# 986
# Latte
#
#
# 987
# Americano
#
#
# 988
# Americano with Milk
#
#
# 989
# Latte
#
#
# 990
# Americano with Milk
#
#
# 991
# Latte
#
#
# 992
# Cocoa
#
#
# 993
# Latte
#
#
# 994
# Latte
#
#
# 995
# Americano
#
#
# 996
# Latte
#
#
# 997
# Americano
#
#
# 998
# Latte
#
#
# 999
# Latte
#
#
# 1000
# Americano
#
#
# 1001
# Latte
#
#
# 1002
# Cocoa
#
#
# 1003
# Cappuccino
#
#
# 1004
# Cortado
#
#
# 1005
# Latte
#
#
# 1006
# Americano
#
#
# 1007
# Americano
#
#
# 1008
# Americano with Milk
#
#
# 1009
# Latte
#
#
# 1010
# Latte
#
#
# 1011
# Americano
#
#
# 1012
# Americano with Milk
#
#
# 1013
# Cocoa
#
#
# 1014
# Latte
#
#
# 1015
# Americano
#
#
# 1016
# Americano with Milk
#
#
# 1017
# Americano with Milk
#
#
# 1018
# Latte
#
#
# 1019
# Latte
#
#
# 1020
# Americano
#
#
# 1021
# Americano
#
#
# 1022
# Americano with Milk
#
#
# 1023
# Americano with Milk
#
#
# 1024
# Espresso
#
#
# 1025
# Cappuccino
#
#
# 1026
# Latte
#
#
# 1027
# Espresso
#
#
# 1028
# Latte
#
#
# 1029
# Cappuccino
#
#
# 1030
# Cappuccino
#
#
# 1031
# Americano with Milk
#
#
# 1032
# Americano
#
#
# 1033
# Americano
#
#
# 1034
# Americano
#
#
# 1035
# Latte
#
#
# 1036
# Americano with Milk
#
#
# 1037
# Americano
#
#
# 1038
# Cappuccino
#
#
# 1039
# Cappuccino
#
#
# 1040
# Cortado
#
#
# 1041
# Espresso
#
#
# 1042
# Cortado
#
#
# 1043
# Cocoa
#
#
# 1044
# Latte
#
#
# 1045
# Americano with Milk
#
#
# 1046
# Espresso
#
#
# 1047
# Cortado
#
#
# 1048
# Cortado
#
#
# 1049
# Latte
#
#
# 1050
# Latte
#
#
# 1051
# Americano with Milk
#
#
# 1052
# Americano with Milk
#
#
# 1053
# Cappuccino
#
#
# 1054
# Cappuccino
#
#
# 1055
# Latte
#
#
# 1056
# Americano
#
#
# 1057
# Cappuccino
#
#
# 1058
# Latte
#
#
# 1059
# Americano with Milk
#
#
# 1060
# Cappuccino
#
#
# 1061
# Americano with Milk
#
#
# 1062
# Americano with Milk
#
#
# 1063
# Espresso
#
#
# 1064
# Americano with Milk
#
#
# 1065
# Espresso
#
#
# 1066
# Latte
#
#
# 1067
# Cappuccino
#
#
# 1068
# Cappuccino
#
#
# 1069
# Americano with Milk
#
#
# 1070
# Americano with Milk
#
#
# 1071
# Latte
#
#
# 1072
# Cappuccino
#
#
# 1073
# Espresso
#
#
# 1074
# Americano with Milk
#
#
# 1075
# Latte
#
#
# 1076
# Latte
#
#
# 1077
# Americano
#
#
# 1078
# Americano with Milk
#
#
# 1079
# Americano
#
#
# 1080
# Americano with Milk
#
#
# 1081
# Cappuccino
#
#
# 1082
# Hot Chocolate
#
#
# 1083
# Hot Chocolate
#
#
# 1084
# Cappuccino
#
#
# 1085
# Americano
#
#
# 1086
# Cocoa
#
#
# 1087
# Americano with Milk
#
#
# 1088
# Cortado
#
#
# 1089
# Cappuccino
#
#
# 1090
# Americano with Milk
#
#
# 1091
# Cortado
#
#
# 1092
# Americano with Milk
#
#
# 1093
# Latte
#
#
# 1094
# Americano
#
#
# 1095
# Espresso
#
#
# 1096
# Americano with Milk
#
#
# 1097
# Americano with Milk
#
#
# 1098
# Americano with Milk
#
#
# 1099
# Americano with Milk
#
#
# 1100
# Latte
#
#
# 1101
# Americano with Milk
#
#
# 1102
# Cortado
#
#
# 1103
# Americano with Milk
#
#
# 1104
# Espresso
#
#
# 1105
# Americano with Milk
#
#
# 1106
# Americano with Milk
#
#
# 1107
# Americano with Milk
#
#
# 1108
# Latte
#
#
# 1109
# Americano
#
#
# 1110
# Cappuccino
#
#
# 1111
# Americano with Milk
#
#
# 1112
# Americano with Milk
#
#
# 1113
# Americano with Milk
#
#
# 1114
# Americano
#
#
# 1115
# Americano
#
#
# 1116
# Americano with Milk
#
#
# 1117
# Cocoa
#
#
# 1118
# Latte
#
#
# 1119
# Americano with Milk
#
#
# 1120
# Cortado
#
#
# 1121
# Latte
#
#
# 1122
# Cortado
#
#
# 1123
# Latte
#
#
# 1124
# Cocoa
#
#
# 1125
# Cortado
#
#
# 1126
# Latte
#
#
# 1127
# Cappuccino
#
#
# 1128
# Cortado
#
#
# 1129
# Americano with Milk
#
#
# 1130
# Latte
#
#
# 1131
# Latte
#
#
# 1132
# Latte
#
#
# 1133
# Americano with Milk
#
#
# 1134
# Americano with Milk
#
#
# 1135
# Americano with Milk
#
#
# 1136
# Americano with Milk
#
#
# 1137
# Cortado
#
#
# 1138
# Cappuccino
#
#
# 1139
# Cappuccino
#
#
# 1140
# Americano with Milk
#
#
# 1141
# Americano with Milk
#
#
# 1142
# Americano
#
#
# 1143
# Americano
#
#
# 1144
# Cappuccino
#
#
# 1145
# Americano with Milk
#
#
# 1146
# Americano with Milk
#
#
# 1147
# Cortado
#
#
# 1148
# Americano with Milk
#
#
# 1149
# Latte
#
#
# 1150
# Americano with Milk
#
#
# 1151
# Americano with Milk
#
#
# 1152
# Americano with Milk
#
#
# 1153
# Americano with Milk
#
#
# 1154
# Cortado
#
#
# 1155
# Cortado
#
#
# 1156
# Espresso
#
#
# 1157
# Americano with Milk
#
#
# 1158
# Americano with Milk
#
#
# 1159
# Americano with Milk
#
#
# 1160
# Cappuccino
#
#
# 1161
# Latte
#
#
# 1162
# Latte
#
#
# 1163
# Cappuccino
#
#
# 1164
# Americano with Milk
#
#
# 1165
# Cappuccino
#
#
# 1166
# Americano with Milk
#
#
# 1167
# Cappuccino
#
#
# 1168
# Cappuccino
#
#
# 1169
# Cortado
#
#
# 1170
# Americano with Milk
#
#
# 1171
# Cortado
#
#
# 1172
# Cappuccino
#
#
# 1173
# Latte
#
#
# 1174
# Latte
#
#
# 1175
# Latte
#
#
# 1176
# Americano with Milk
#
#
# 1177
# Latte
#
#
# 1178
# Latte
#
#
# 1179
# Cocoa
#
#
# 1180
# Cocoa
#
#
# 1181
# Americano with Milk
#
#
# 1182
# Cortado
#
#
# 1183
# Hot Chocolate
#
#
# 1184
# Cappuccino
#
#
# 1185
# Latte
#
#
# 1186
# Cocoa
#
#
# 1187
# Latte
#
#
# 1188
# Americano with Milk
#
#
# 1189
# Latte
#
#
# 1190
# Americano with Milk
#
#
# 1191
# Americano
#
#
# 1192
# Americano
#
#
# 1193
# Espresso
#
#
# 1194
# Americano
#
#
# 1195
# Latte
#
#
# 1196
# Cocoa
#
#
# 1197
# Cappuccino
#
#
# 1198
# Latte
#
#
# 1199
# Latte
#
#
# 1200
# Espresso
#
#
# 1201
# Cortado
#
#
# 1202
# Americano with Milk
#
#
# 1203
# Cortado
#
#
# 1204
# Cortado
#
#
# 1205
# Cappuccino
#
#
# 1206
# Cappuccino
#
#
# 1207
# Americano with Milk
#
#
# 1208
# Latte
#
#
# 1209
# Americano
#
#
# 1210
# Cortado
#
#
# 1211
# Americano with Milk
#
#
# 1212
# Latte
#
#
# 1213
# Americano
#
#
# 1214
# Americano
#
#
# 1215
# Hot Chocolate
#
#
# 1216
# Cappuccino
#
#
# 1217
# Americano with Milk
#
#
# 1218
# Cortado
#
#
# 1219
# Cortado
#
#
# 1220
# Americano
#
#
# 1221
# Latte
#
#
# 1222
# Americano with Milk
#
#
# 1223
# Latte
#
#
# 1224
# Cocoa
#
#
# 1225
# Cocoa
#
#
# 1226
# Cocoa
#
#
# 1227
# Latte
#
#
# 1228
# Latte
#
#
# 1229
# Americano with Milk
#
#
# 1230
# Cappuccino
#
#
# 1231
# Americano with Milk
#
#
# 1232
# Cortado
#
#
# 1233
# Latte
#
#
# 1234
# Americano with Milk
#
#
# 1235
# Cocoa
#
#
# 1236
# Cappuccino
#
#
# 1237
# Espresso
#
#
# 1238
# Cortado
#
#
# 1239
# Latte
#
#
# 1240
# Latte
#
#
# 1241
# Cappuccino
#
#
# 1242
# Hot Chocolate
#
#
# 1243
# Americano with Milk
#
#
# 1244
# Americano
#
#
# 1245
# Latte
#
#
# 1246
# Latte
#
#
# 1247
# Espresso
#
#
# 1248
# Americano with Milk
#
#
# 1249
# Americano with Milk
#
#
# 1250
# Americano with Milk
#
#
# 1251
# Americano with Milk
#
#
# 1252
# Latte
#
#
# 1253
# Cappuccino
#
#
# 1254
# Cappuccino
#
#
# 1255
# Americano with Milk
#
#
# 1256
# Americano with Milk
#
#
# 1257
# Americano with Milk
#
#
# 1258
# Cortado
#
#
# 1259
# Latte
#
#
# 1260
# Americano with Milk
#
#
# 1261
# Latte
#
#
# 1262
# Cappuccino
#
#
# 1263
# Americano with Milk
#
#
# 1264
# Latte
#
#
# 1265
# Cocoa
#
#
# 1266
# Cappuccino
#
#
# 1267
# Cortado
#
#
# 1268
# Latte
#
#
# 1269
# Cappuccino
#
#
# 1270
# Cortado
#
#
# 1271
# Espresso
#
#
# 1272
# Americano
#
#
# 1273
# Americano
#
#
# 1274
# Latte
#
#
# 1275
# Americano
#
#
# 1276
# Cortado
#
#
# 1277
# Americano with Milk
#
#
# 1278
# Latte
#
#
# 1279
# Cortado
#
#
# 1280
# Latte
#
#
# 1281
# Cortado
#
#
# 1282
# Cappuccino
#
#
# 1283
# Hot Chocolate
#
#
# 1284
# Latte
#
#
# 1285
# Latte
#
#
# 1286
# Latte
#
#
# 1287
# Americano
#
#
# 1288
# Espresso
#
#
# 1289
# Americano with Milk
#
#
# 1290
# Hot Chocolate
#
#
# 1291
# Americano with Milk
#
#
# 1292
# Americano with Milk
#
#
# 1293
# Americano
#
#
# 1294
# Cappuccino
#
#
# 1295
# Espresso
#
#
# 1296
# Americano with Milk
#
#
# 1297
# Latte
#
#
# 1298
# Americano
#
#
# 1299
# Americano with Milk
#
#
# 1300
# Espresso
#
#
# 1301
# Espresso
#
#
# 1302
# Americano with Milk
#
#
# 1303
# Cappuccino
#
#
# 1304
# Americano with Milk
#
#
# 1305
# Cortado
#
#
# 1306
# Cortado
#
#
# 1307
# Americano with Milk
#
#
# 1308
# Cortado
#
#
# 1309
# Latte
#
#
# 1310
# Cappuccino
#
#
# 1311
# Americano with Milk
#
#
# 1312
# Latte
#
#
# 1313
# Cappuccino
#
#
# 1314
# Cappuccino
#
#
# 1315
# Cortado
#
#
# 1316
# Americano with Milk
#
#
# 1317
# Cappuccino
#
#
# 1318
# Americano with Milk
#
#
# 1319
# Americano with Milk
#
#
# 1320
# Americano with Milk
#
#
# 1321
# Americano
#
#
# 1322
# Americano
#
#
# 1323
# Americano with Milk
#
#
# 1324
# Americano with Milk
#
#
# 1325
# Latte
#
#
# 1326
# Cocoa
#
#
# 1327
# Cortado
#
#
# 1328
# Latte
#
#
# 1329
# Espresso
#
#
# 1330
# Cortado
#
#
# 1331
# Americano with Milk
#
#
# 1332
# Americano
#
#
# 1333
# Americano
#
#
# 1334
# Americano
#
#
# 1335
# Latte
#
#
# 1336
# Latte
#
#
# 1337
# Latte
#
#
# 1338
# Latte
#
#
# 1339
# Latte
#
#
# 1340
# Americano with Milk
#
#
# 1341
# Cortado
#
#
# 1342
# Americano
#
#
# 1343
# Americano with Milk
#
#
# 1344
# Cortado
#
#
# 1345
# Latte
#
#
# 1346
# Latte
#
#
# 1347
# Cortado
#
#
# 1348
# Americano with Milk
#
#
# 1349
# Americano with Milk
#
#
# 1350
# Latte
#
#
# 1351
# Latte
#
#
# 1352
# Cappuccino
#
#
# 1353
# Americano
#
#
# 1354
# Latte
#
#
# 1355
# Cortado
#
#
# 1356
# Latte
#
#
# 1357
# Americano
#
#
# 1358
# Americano
#
#
# 1359
# Americano with Milk
#
#
# 1360
# Cocoa
#
#
# 1361
# Americano
#
#
# 1362
# Cortado
#
#
# 1363
# Hot Chocolate
#
#
# 1364
# Americano
#
#
# 1365
# Americano
#
#
# 1366
# Latte
#
#
# 1367
# Cortado
#
#
# 1368
# Cortado
#
#
# 1369
# Cortado
#
#
# 1370
# Espresso
#
#
# 1371
# Espresso
#
#
# 1372
# Americano
#
#
# 1373
# Cortado
#
#
# 1374
# Americano
#
#
# 1375
# Americano
#
#
# 1376
# Cappuccino
#
#
# 1377
# Cappuccino
#
#
# 1378
# Latte
#
#
# 1379
# Cortado
#
#
# 1380
# Americano
#
#
# 1381
# Americano
#
#
# 1382
# Americano with Milk
#
#
# 1383
# Latte
#
#
# 1384
# Cappuccino
#
#
# 1385
# Americano
#
#
# 1386
# Americano
#
#
# 1387
# Americano with Milk
#
#
# 1388
# Latte
#
#
# 1389
# Americano with Milk
#
#
# 1390
# Latte
#
#
# 1391
# Americano with Milk
#
#
# 1392
# Cappuccino
#
#
# 1393
# Americano
#
#
# 1394
# Americano with Milk
#
#
# 1395
# Americano
#
#
# 1396
# Latte
#
#
# 1397
# Americano with Milk
#
#
# 1398
# Americano with Milk
#
#
# 1399
# Cortado
#
#
# 1400
# Americano with Milk
#
#
# 1401
# Espresso
#
#
# 1402
# Americano with Milk
#
#
# 1403
# Cortado
#
#
# 1404
# Cortado
#
#
# 1405
# Cortado
#
#
# 1406
# Cappuccino
#
#
# 1407
# Americano with Milk
#
#
# 1408
# Americano
#
#
# 1409
# Americano with Milk
#
#
# 1410
# Latte
#
#
# 1411
# Americano with Milk
#
#
# 1412
# Latte
#
#
# 1413
# Latte
#
#
# 1414
# Latte
#
#
# 1415
# Latte
#
#
# 1416
# Americano with Milk
#
#
# 1417
# Latte
#
#
# 1418
# Americano with Milk
#
#
# 1419
# Cappuccino
#
#
# 1420
# Cocoa
#
#
# 1421
# Americano
#
#
# 1422
# Americano
#
#
# 1423
# Cocoa
#
#
# 1424
# Cappuccino
#
#
# 1425
# Latte
#
#
# 1426
# Americano with Milk
#
#
# 1427
# Cappuccino
#
#
# 1428
# Cocoa
#
#
# 1429
# Cocoa
#
#
# 1430
# Americano with Milk
#
#
# 1431
# Americano with Milk
#
#
# 1432
# Latte
#
#
# 1433
# Cocoa
#
#
# 1434
# Cortado
#
#
# 1435
# Americano with Milk
#
#
# 1436
# Americano with Milk
#
#
# 1437
# Americano with Milk
#
#
# 1438
# Latte
#
#
# 1439
# Americano with Milk
#
#
# 1440
# Americano with Milk
#
#
# 1441
# Latte
#
#
# 1442
# Americano
#
#
# 1443
# Americano with Milk
#
#
# 1444
# Latte
#
#
# 1445
# Latte
#
#
# 1446
# Americano with Milk
#
#
# 1447
# Cappuccino
#
#
# 1448
# Americano with Milk
#
#
# 1449
# Latte
#
#
# 1450
# Americano with Milk
#
#
# 1451
# Americano with Milk
#
#
# 1452
# Americano
#
#
# 1453
# Latte
#
#
# 1454
# Latte
#
#
# 1455
# Americano
#
#
# 1456
# Americano with Milk
#
#
# 1457
# Cappuccino
#
#
# 1458
# Cappuccino
#
#
# 1459
# Cappuccino
#
#
# 1460
# Americano
#
#
# 1461
# Cappuccino
#
#
# 1462
# Americano with Milk
#
#
# 1463
# Americano with Milk
#
#
# 1464
# Cappuccino
#
#
# 1465
# Latte
#
#
# 1466
# Americano
#
#
# 1467
# Espresso
#
#
# 1468
# Latte
#
#
# 1469
# Hot Chocolate
#
#
# 1470
# Espresso
#
#
# 1471
# Espresso
#
#
# 1472
# Latte
#
#
# 1473
# Latte
#
#
# 1474
# Latte
#
#
# 1475
# Cortado
#
#
# 1476
# Cortado
#
#
# 1477
# Cortado
#
#
# 1478
# Americano with Milk
#
#
# 1479
# Americano with Milk
#
#
# 1480
# Cortado
#
#
# 1481
# Americano
#
#
# 1482
# Espresso
#
#
# 1483
# Espresso
#
#
# 1484
# Latte
#
#
# 1485
# Americano with Milk
#
#
# 1486
# Americano
#
#
# 1487
# Espresso
#
#
# 1488
# Latte
#
#
# 1489
# Americano
#
#
# 1490
# Espresso
#
#
# 1491
# Cocoa
#
#
# 1492
# Latte
#
#
# 1493
# Latte
#
#
# 1494
# Latte
#
#
# 1495
# Latte
#
#
# 1496
# Cortado
#
#
# 1497
# Cortado
#
#
# 1498
# Cortado
#
#
# 1499
# Cortado
#
#
# 1500
# Cortado
#
#
# 1501
# Americano
#
#
# 1502
# Latte
#
#
# 1503
# Cappuccino
#
#
# 1504
# Americano with Milk
#
#
# 1505
# Latte
#
#
# 1506
# Latte
#
#
# 1507
# Hot Chocolate
#
#
# 1508
# Latte
#
#
# 1509
# Americano with Milk
#
#
# 1510
# Americano with Milk
#
#
# 1511
# Latte
#
#
# 1512
# Espresso
#
#
# 1513
# Latte
#
#
# 1514
# Americano
#
#
# 1515
# Latte
#
#
# 1516
# Latte
#
#
# 1517
# Cappuccino
#
#
# 1518
# Latte
#
#
# 1519
# Hot Chocolate
#
#
# 1520
# Cappuccino
#
#
# 1521
# Cortado
#
#
# 1522
# Cortado
#
#
# 1523
# Cappuccino
#
#
# 1524
# Americano with Milk
#
#
# 1525
# Latte
#
#
# 1526
# Latte
#
#
# 1527
# Americano with Milk
#
#
# 1528
# Americano
#
#
# 1529
# Latte
#
#
# 1530
# Americano with Milk
#
#
# 1531
# Latte
#
#
# 1532
# Cappuccino
#
#
# 1533
# Americano with Milk
#
#
# 1534
# Latte
#
#
# 1535
# Latte
#
#
# 1536
# Cortado
#
#
# 1537
# Espresso
#
#
# 1538
# Americano with Milk
#
#
# 1539
# Americano with Milk
#
#
# 1540
# Cappuccino
#
#
# 1541
# Cortado
#
#
# 1542
# Cortado
#
#
# 1543
# Cortado
#
#
# 1544
# Cortado
#
#
# 1545
# Latte
#
#
# 1546
# Americano
#
#
# 1547
# Cappuccino
#
#
# 1548
# Cortado
#
#
# 1549
# Latte
#
#
# 1550
# Latte
#
#
# 1551
# Latte
#
#
# 1552
# Latte
#
#
# 1553
# Americano with Milk
#
#
# 1554
# Americano with Milk
#
#
# 1555
# Cappuccino
#
#
# 1556
# Cappuccino
#
#
# 1557
# Espresso
#
#
# 1558
# Americano with Milk
#
#
# 1559
# Americano
#
#
# 1560
# Cortado
#
#
# 1561
# Cortado
#
#
# 1562
# Cappuccino
#
#
# 1563
# Latte
#
#
# 1564
# Americano with Milk
#
#
# 1565
# Latte
#
#
# 1566
# Americano with Milk
#
#
# 1567
# Latte
#
#
# 1568
# Latte
#
#
# 1569
# Latte
#
#
# 1570
# Americano with Milk
#
#
# 1571
# Latte
#
#
# 1572
# Americano with Milk
#
#
# 1573
# Americano with Milk
#
#
# 1574
# Cortado
#
#
# 1575
# Latte
#
#
# 1576
# Americano with Milk
#
#
# 1577
# Cortado
#
#
# 1578
# Cappuccino
#
#
# 1579
# Americano with Milk
#
#
# 1580
# Americano with Milk
#
#
# 1581
# Espresso
#
#
# 1582
# Americano with Milk
#
#
# 1583
# Latte
#
#
# 1584
# Americano with Milk
#
#
# 1585
# Cortado
#
#
# 1586
# Cappuccino
#
#
# 1587
# Latte
#
#
# 1588
# Hot Chocolate
#
#
# 1589
# Americano with Milk
#
#
# 1590
# Americano with Milk
#
#
# 1591
# Latte
#
#
# 1592
# Americano with Milk
#
#
# 1593
# Americano with Milk
#
#
# 1594
# Americano with Milk
#
#
# 1595
# Hot Chocolate
#
#
# 1596
# Hot Chocolate
#
#
# 1597
# Latte
#
#
# 1598
# Latte
#
#
# 1599
# Americano with Milk
#
#
# 1600
# Americano with Milk
#
#
# 1601
# Americano with Milk
#
#
# 1602
# Cortado
#
#
# 1603
# Latte
#
#
# 1604
# Americano
#
#
# 1605
# Americano with Milk
#
#
# 1606
# Cortado
#
#
# 1607
# Americano with Milk
#
#
# 1608
# Americano with Milk
#
#
# 1609
# Americano with Milk
#
#
# 1610
# Latte
#
#
# 1611
# Americano
#
#
# 1612
# Americano with Milk
#
#
# 1613
# Americano with Milk
#
#
# 1614
# Latte
#
#
# 1615
# Cocoa
#
#
# 1616
# Cortado
#
#
# 1617
# Cortado
#
#
# 1618
# Cappuccino
#
#
# 1619
# Latte
#
#
# 1620
# Latte
#
#
# 1621
# Latte
#
#
# 1622
# Americano
#
#
# 1623
# Americano
#
#
# 1624
# Latte
#
#
# 1625
# Latte
#
#
# 1626
# Americano with Milk
#
#
# 1627
# Americano
#
#
# 1628
# Americano
#
#
# 1629
# Americano
#
#
# 1630
# Americano with Milk
#
#
# 1631
# Latte
#
#
# 1632
# Cortado
#
#
# 1633
# Cortado
#
#
# 1634
# Americano with Milk
#
#
# 1635
# Americano
#
#
# 1636
# Americano with Milk
#
#
# 1637
# Americano with Milk
#
#
# 1638
# Americano with Milk
#
#
# 1639
# Americano with Milk
#
#
# 1640
# Latte
#
#
# 1641
# Americano with Milk
#
#
# 1642
# Cocoa
#
#
# 1643
# Latte
#
#
# 1644
# Cappuccino
#
#
# 1645
# Americano with Milk
#
#
# 1646
# Americano with Milk
#
#
# 1647
# Americano with Milk
#
#
# 1648
# Americano with Milk
#
#
# 1649
# Hot Chocolate
#
#
# 1650
# Hot Chocolate
#
#
# 1651
# Americano
#
#
# 1652
# Americano with Milk
#
#
# 1653
# Americano with Milk
#
#
# 1654
# Cortado
#
#
# 1655
# Americano
#
#
# 1656
# Americano with Milk
#
#
# 1657
# Cappuccino
#
#
# 1658
# Americano
#
#
# 1659
# Latte
#
#
# 1660
# Cappuccino
#
#
# 1661
# Americano with Milk
#
#
# 1662
# Americano with Milk
#
#
# 1663
# Americano with Milk
#
#
# 1664
# Latte
#
#
# 1665
# Latte
#
#
# 1666
# Latte
#
#
# 1667
# Latte
#
#
# 1668
# Latte
#
#
# 1669
# Cortado
#
#
# 1670
# Cappuccino
#
#
# 1671
# Latte
#
#
# 1672
# Americano
#
#
# 1673
# Americano
#
#
# 1674
# Hot Chocolate
#
#
# 1675
# Latte
#
#
# 1676
# Americano with Milk
#
#
# 1677
# Americano with Milk
#
#
# 1678
# Cappuccino
#
#
# 1679
# Cortado
#
#
# 1680
# Americano with Milk
#
#
# 1681
# Latte
#
#
# 1682
# Americano with Milk
#
#
# 1683
# Americano with Milk
#
#
# 1684
# Americano with Milk
#
#
# 1685
# Americano with Milk
#
#
# 1686
# Americano
#
#
# 1687
# Americano with Milk
#
#
# 1688
# Latte
#
#
# 1689
# Americano with Milk
#
#
# 1690
# Espresso
#
#
# 1691
# Cappuccino
#
#
# 1692
# Latte
#
#
# 1693
# Latte
#
#
# 1694
# Latte
#
#
# 1695
# Cortado
#
#
# 1696
# Americano with Milk
#
#
# 1697
# Americano with Milk
#
#
# 1698
# Cortado
#
#
# 1699
# Cappuccino
#
#
# 1700
# Americano with Milk
#
#
# 1701
# Americano with Milk
#
#
# 1702
# Cappuccino
#
#
# 1703
# Cappuccino
#
#
# 1704
# Americano
#
#
# 1705
# Americano with Milk
#
#
# 1706
# Latte
#
#
# 1707
# Latte
#
#
# 1708
# Cappuccino
#
#
# 1709
# Cappuccino
#
#
# 1710
# Cappuccino
#
#
# 1711
# Cappuccino
#
#
# 1712
# Americano with Milk
#
#
# 1713
# Americano with Milk
#
#
# 1714
# Americano with Milk
#
#
# 1715
# Latte
#
#
# 1716
# Latte
#
#
# 1717
# Americano with Milk
#
#
# 1718
# Latte
#
#
# 1719
# Latte
#
#
# 1720
# Cappuccino
#
#
# 1721
# Cocoa
#
#
# 1722
# Cortado
#
#
# 1723
# Hot Chocolate
#
#
# 1724
# Americano
#
#
# 1725
# Cappuccino
#
#
# 1726
# Cappuccino
#
#
# 1727
# Cappuccino
#
#
# 1728
# Americano with Milk
#
#
# 1729
# Latte
#
#
# 1730
# Cortado
#
#
# 1731
# Latte
#
#
# 1732
# Latte
#
#
# 1733
# Cappuccino
#
#
# 1734
# Latte
#
#
# 1735
# Cortado
#
#
# 1736
# Cortado
#
#
# 1737
# Hot Chocolate
#
#
# 1738
# Americano with Milk
#
#
# 1739
# Cortado
#
#
# 1740
# Americano with Milk
#
#
# 1741
# Americano with Milk
#
#
# 1742
# Latte
#
#
# 1743
# Americano with Milk
#
#
# 1744
# Cortado
#
#
# 1745
# Latte
#
#
# 1746
# Americano with Milk
#
#
# 1747
# Americano with Milk
#
#
# 1748
# Americano with Milk
#
#
# 1749
# Latte
#
#
# 1750
# Americano with Milk
#
#
# 1751
# Americano with Milk
#
#
# 1752
# Americano with Milk
#
#
# 1753
# Americano with Milk
#
#
# 1754
# Americano with Milk
#
#
# 1755
# Americano with Milk
#
#
# 1756
# Americano
#
#
# 1757
# Americano with Milk
#
#
# 1758
# Hot Chocolate
#
#
# 1759
# Americano
#
#
# 1760
# Latte
#
#
# 1761
# Latte
#
#
# 1762
# Hot Chocolate
#
#
# 1763
# Hot Chocolate
#
#
# 1764
# Latte
#
#
# 1765
# Cortado
#
#
# 1766
# Americano with Milk
#
#
# 1767
# Latte
#
#
# 1768
# Americano with Milk
#
#
# 1769
# Cappuccino
#
#
# 1770
# Cappuccino
#
#
# 1771
# Hot Chocolate
#
#
# 1772
# Hot Chocolate
#
#
# 1773
# Hot Chocolate
#
#
# 1774
# Hot Chocolate
#
#
# 1775
# Cocoa
#
#
# 1776
# Americano with Milk
#
#
# 1777
# Cortado
#
#
# 1778
# Hot Chocolate
#
#
# 1779
# Hot Chocolate
#
#
# 1780
# Hot Chocolate
#
#
# 1781
# Cappuccino
#
#
# 1782
# Hot Chocolate
#
#
# 1783
# Americano
#
#
# 1784
# Americano
#
#
# 1785
# Americano with Milk
#
#
# 1786
# Americano
#
#
# 1787
# Cortado
#
#
# 1788
# Cortado
#
#
# 1789
# Latte
#
#
# 1790
# Hot Chocolate
#
#
# 1791
# Cocoa
#
#
# 1792
# Cortado
#
#
# 1793
# Cortado
#
#
# 1794
# Cocoa
#
#
# 1795
# Cappuccino
#
#
# 1796
# Americano
#
#
# 1797
# Americano
#
#
# 1798
# Cortado
#
#
# 1799
# Cappuccino
#
#
# 1800
# Cortado
#
#
# 1801
# Latte
#
#
# 1802
# Latte
#
#
# 1803
# Cappuccino
#
#
# 1804
# Americano with Milk
#
#
# 1805
# Americano
#
#
# 1806
# Cappuccino
#
#
# 1807
# Americano with Milk
#
#
# 1808
# Latte
#
#
# 1809
# Cappuccino
#
#
# 1810
# Cappuccino
#
#
# 1811
# Espresso
#
#
# 1812
# Americano with Milk
#
#
# 1813
# Hot Chocolate
#
#
# 1814
# Hot Chocolate
#
#
# 1815
# Hot Chocolate
#
#
# 1816
# Hot Chocolate
#
#
# 1817
# Latte
#
#
# 1818
# Latte
#
#
# 1819
# Latte
#
#
# 1820
# Americano with Milk
#
#
# 1821
# Cocoa
#
#
# 1822
# Latte
#
#
# 1823
# Americano with Milk
#
#
# 1824
# Americano
#
#
# 1825
# Americano
#
#
# 1826
# Latte
#
#
# 1827
# Hot Chocolate
#
#
# 1828
# Hot Chocolate
#
#
# 1829
# Latte
#
#
# 1830
# Latte
#
#
# 1831
# Americano with Milk
#
#
# 1832
# Americano
#
#
# 1833
# Latte
#
#
# 1834
# Latte
#
#
# 1835
# Americano
#
#
# 1836
# Americano
#
#
# 1837
# Latte
#
#
# 1838
# Latte
#
#
# 1839
# Latte
#
#
# 1840
# Latte
#
#
# 1841
# Americano
#
#
# 1842
# Americano with Milk
#
#
# 1843
# Hot Chocolate
#
#
# 1844
# Cappuccino
#
#
# 1845
# Latte
#
#
# 1846
# Americano with Milk
#
#
# 1847
# Americano with Milk
#
#
# 1848
# Latte
#
#
# 1849
# Americano with Milk
#
#
# 1850
# Americano with Milk
#
#
# 1851
# Latte
#
#
# 1852
# Espresso
#
#
# 1853
# Americano
#
#
# 1854
# Latte
#
#
# 1855
# Americano with Milk
#
#
# 1856
# Cappuccino
#
#
# 1857
# Americano
#
#
# 1858
# Espresso
#
#
# 1859
# Cappuccino
#
#
# 1860
# Americano
#
#
# 1861
# Americano with Milk
#
#
# 1862
# Hot Chocolate
#
#
# 1863
# Latte
#
#
# 1864
# Cortado
#
#
# 1865
# Cortado
#
#
# 1866
# Latte
#
#
# 1867
# Latte
#
#
# 1868
# Cappuccino
#
#
# 1869
# Latte
#
#
# 1870
# Americano
#
#
# 1871
# Americano with Milk
#
#
# 1872
# Latte
#
#
# 1873
# Hot Chocolate
#
#
# 1874
# Hot Chocolate
#
#
# 1875
# Americano with Milk
#
#
# 1876
# Latte
#
#
# 1877
# Cortado
#
#
# 1878
# Latte
#
#
# 1879
# Cocoa
#
#
# 1880
# Cocoa
#
#
# 1881
# Americano with Milk
#
#
# 1882
# Hot Chocolate
#
#
# 1883
# Americano with Milk
#
#
# 1884
# Cortado
#
#
# 1885
# Americano
#
#
# 1886
# Americano
#
#
# 1887
# Americano with Milk
#
#
# 1888
# Latte
#
#
# 1889
# Americano
#
#
# 1890
# Americano
#
#
# 1891
# Cocoa
#
#
# 1892
# Americano
#
#
# 1893
# Cappuccino
#
#
# 1894
# Latte
#
#
# 1895
# Hot Chocolate
#
#
# 1896
# Hot Chocolate
#
#
# 1897
# Latte
#
#
# 1898
# Americano with Milk
#
#
# 1899
# Hot Chocolate
#
#
# 1900
# Hot Chocolate
#
#
# 1901
# Cortado
#
#
# 1902
# Cortado
#
#
# 1903
# Cortado
#
#
# 1904
# Latte
#
#
# 1905
# Americano with Milk
#
#
# 1906
# Cappuccino
#
#
# 1907
# Latte
#
#
# 1908
# Cortado
#
#
# 1909
# Americano with Milk
#
#
# 1910
# Cortado
#
#
# 1911
# Espresso
#
#
# 1912
# Cortado
#
#
# 1913
# Latte
#
#
# 1914
# Latte
#
#
# 1915
# Cappuccino
#
#
# 1916
# Cappuccino
#
#
# 1917
# Americano with Milk
#
#
# 1918
# Cocoa
#
#
# 1919
# Cortado
#
#
# 1920
# Latte
#
#
# 1921
# Latte
#
#
# 1922
# Cappuccino
#
#
# 1923
# Americano
#
#
# 1924
# Americano
#
#
# 1925
# Latte
#
#
# 1926
# Latte
#
#
# 1927
# Americano
#
#
# 1928
# Latte
#
#
# 1929
# Cappuccino
#
#
# 1930
# Latte
#
#
# 1931
# Latte
#
#
# 1932
# Latte
#
#
# 1933
# Cortado
#
#
# 1934
# Espresso
#
#
# 1935
# Hot Chocolate
#
#
# 1936
# Latte
#
#
# 1937
# Hot Chocolate
#
#
# 1938
# Latte
#
#
# 1939
# Americano with Milk
#
#
# 1940
# Latte
#
#
# 1941
# Americano
#
#
# 1942
# Espresso
#
#
# 1943
# Hot Chocolate
#
#
# 1944
# Americano
#
#
# 1945
# Cocoa
#
#
# 1946
# Latte
#
#
# 1947
# Latte
#
#
# 1948
# Hot Chocolate
#
#
# 1949
# Hot Chocolate
#
#
# 1950
# Latte
#
#
# 1951
# Americano with Milk
#
#
# 1952
# Hot Chocolate
#
#
# 1953
# Latte
#
#
# 1954
# Americano with Milk
#
#
# 1955
# Americano with Milk
#
#
# 1956
# Americano with Milk
#
#
# 1957
# Americano
#
#
# 1958
# Americano with Milk
#
#
# 1959
# Americano
#
#
# 1960
# Latte
#
#
# 1961
# Americano with Milk
#
#
# 1962
# Americano with Milk
#
#
# 1963
# Americano with Milk
#
#
# 1964
# Hot Chocolate
#
#
# 1965
# Latte
#
#
# 1966
# Latte
#
#
# 1967
# Americano with Milk
#
#
# 1968
# Latte
#
#
# 1969
# Hot Chocolate
#
#
# 1970
# Americano with Milk
#
#
# 1971
# Latte
#
#
# 1972
# Americano
#
#
# 1973
# Hot Chocolate
#
#
# 1974
# Hot Chocolate
#
#
# 1975
# Latte
#
#
# 1976
# Hot Chocolate
#
#
# 1977
# Hot Chocolate
#
#
# 1978
# Cappuccino
#
#
# 1979
# Hot Chocolate
#
#
# 1980
# Latte
#
#
# 1981
# Americano with Milk
#
#
# 1982
# Latte
#
#
# 1983
# Latte
#
#
# 1984
# Latte
#
#
# 1985
# Hot Chocolate
#
#
# 1986
# Cocoa
#
#
# 1987
# Cocoa
#
#
# 1988
# Cocoa
#
#
# 1989
# Cocoa
#
#
# 1990
# Cappuccino
#
#
# 1991
# Cappuccino
#
#
# 1992
# Latte
#
#
# 1993
# Cappuccino
#
#
# 1994
# Americano
#
#
# 1995
# Latte
#
#
# 1996
# Hot Chocolate
#
#
# 1997
# Cocoa
#
#
# 1998
# Cocoa
#
#
# 1999
# Americano with Milk
#
#
# 2000
# Latte
#
#
# 2001
# Americano with Milk
#
#
# 2002
# Latte
#
#
# 2003
# Cappuccino
#
#
# 2004
# Hot Chocolate
#
#
# 2005
# Latte
#
#
# 2006
# Latte
#
#
# 2007
# Latte
#
#
# 2008
# Cocoa
#
#
# 2009
# Cappuccino
#
#
# 2010
# Latte
#
#
# 2011
# Cocoa
#
#
# 2012
# Latte
#
#
# 2013
# Hot Chocolate
#
#
# 2014
# Cortado
#
#
# 2015
# Americano with Milk
#
#
# 2016
# Latte
#
#
# 2017
# Latte
#
#
# 2018
# Latte
#
#
# 2019
# Cocoa
#
#
# 2020
# Cocoa
#
#
# 2021
# Hot Chocolate
#
#
# 2022
# Cortado
#
#
# 2023
# Cocoa
#
#
# 2024
# Latte
#
#
# 2025
# Cappuccino
#
#
# 2026
# Latte
#
#
# 2027
# Latte
#
#
# 2028
# Americano with Milk
#
#
# 2029
# Latte
#
#
# 2030
# Americano
#
#
# 2031
# Cortado
#
#
# 2032
# Cortado
#
#
# 2033
# Espresso
#
#
# 2034
# Cappuccino
#
#
# 2035
# Latte
#
#
# 2036
# Latte
#
#
# 2037
# Americano with Milk
#
#
# 2038
# Cortado
#
#
# 2039
# Cocoa
#
#
# 2040
# Latte
#
#
# 2041
# Hot Chocolate
#
#
# 2042
# Latte
#
#
# 2043
# Cocoa
#
#
# 2044
# Hot Chocolate
#
#
# 2045
# Latte
#
#
# 2046
# Cappuccino
#
#
# 2047
# Americano with Milk
#
#
# 2048
# Cortado
#
#
# 2049
# Espresso
#
#
# 2050
# Cortado
#
#
# 2051
# Americano
#
#
# 2052
# Hot Chocolate
#
#
# 2053
# Latte
#
#
# 2054
# Latte
#
#
# 2055
# Americano with Milk
#
#
# 2056
# Cortado
#
#
# 2057
# Americano with Milk
#
#
# 2058
# Americano with Milk
#
#
# 2059
# Americano with Milk
#
#
# 2060
# Cappuccino
#
#
# 2061
# Espresso
#
#
# 2062
# Cocoa
#
#
# 2063
# Cappuccino
#
#
# 2064
# Americano with Milk
#
#
# 2065
# Hot Chocolate
#
#
# 2066
# Latte
#
#
# 2067
# Americano
#
#
# 2068
# Cappuccino
#
#
# 2069
# Cappuccino
#
#
# 2070
# Hot Chocolate
#
#
# 2071
# Latte
#
#
# 2072
# Latte
#
#
# 2073
# Latte
#
#
# 2074
# Americano
#
#
# 2075
# Americano
#
#
# 2076
# Latte
#
#
# 2077
# Americano
#
#
# 2078
# Hot Chocolate
#
#
# 2079
# Hot Chocolate
#
#
# 2080
# Hot Chocolate
#
#
# 2081
# Cappuccino
#
#
# 2082
# Cappuccino
#
#
# 2083
# Espresso
#
#
# 2084
# Cocoa
#
#
# 2085
# Latte
#
#
# 2086
# Cocoa
#
#
# 2087
# Americano
#
#
# 2088
# Americano
#
#
# 2089
# Americano with Milk
#
#
# 2090
# Cocoa
#
#
# 2091
# Cocoa
#
#
# 2092
# Cortado
#
#
# 2093
# Latte
#
#
# 2094
# Cappuccino
#
#
# 2095
# Hot Chocolate
#
#
# 2096
# Espresso
#
#
# 2097
# Cappuccino
#
#
# 2098
# Cortado
#
#
# 2099
# Cappuccino
#
#
# 2100
# Americano
#
#
# 2101
# Cocoa
#
#
# 2102
# Latte
#
#
# 2103
# Latte
#
#
# 2104
# Americano with Milk
#
#
# 2105
# Cortado
#
#
# 2106
# Cortado
#
#
# 2107
# Latte
#
#
# 2108
# Latte
#
#
# 2109
# Americano with Milk
#
#
# 2110
# Americano with Milk
#
#
# 2111
# Cappuccino
#
#
# 2112
# Americano with Milk
#
#
# 2113
# Americano with Milk
#
#
# 2114
# Latte
#
#
# 2115
# Americano with Milk
#
#
# 2116
# Cappuccino
#
#
# 2117
# Latte
#
#
# 2118
# Cappuccino
#
#
# 2119
# Americano
#
#
# 2120
# Latte
#
#
# 2121
# Americano with Milk
#
#
# 2122
# Latte
#
#
# 2123
# Latte
#
#
# 2124
# Hot Chocolate
#
#
# 2125
# Americano with Milk
#
#
# 2126
# Cappuccino
#
#
# 2127
# Americano with Milk
#
#
# 2128
# Americano with Milk
#
#
# 2129
# Americano with Milk
#
#
# 2130
# Latte
#
#
# 2131
# Cocoa
#
#
# 2132
# Cocoa
#
#
# 2133
# Cappuccino
#
#
# 2134
# Americano with Milk
#
#
# 2135
# Americano with Milk
#
#
# 2136
# Latte
#
#
# 2137
# Latte
#
#
# 2138
# Latte
#
#
# 2139
# Americano with Milk
#
#
# 2140
# Espresso
#
#
# 2141
# Cortado
#
#
# 2142
# Cortado
#
#
# 2143
# Cappuccino
#
#
# 2144
# Hot Chocolate
#
#
# 2145
# Cocoa
#
#
# 2146
# Cocoa
#
#
# 2147
# Americano with Milk
#
#
# 2148
# Americano with Milk
#
#
# 2149
# Americano with Milk
#
#
# 2150
# Cappuccino
#
#
# 2151
# Hot Chocolate
#
#
# 2152
# Latte
#
#
# 2153
# Latte
#
#
# 2154
# Latte
#
#
# 2155
# Americano with Milk
#
#
# 2156
# Americano with Milk
#
#
# 2157
# Latte
#
#
# 2158
# Latte
#
#
# 2159
# Latte
#
#
# 2160
# Latte
#
#
# 2161
# Americano
#
#
# 2162
# Americano with Milk
#
#
# 2163
# Americano
#
#
# 2164
# Latte
#
#
# 2165
# Latte
#
#
# 2166
# Americano with Milk
#
#
# 2167
# Hot Chocolate
#
#
# 2168
# Americano with Milk
#
#
# 2169
# Americano with Milk
#
#
# 2170
# Latte
#
#
# 2171
# Latte
#
#
# 2172
# Americano with Milk
#
#
# 2173
# Latte
#
#
# 2174
# Americano with Milk
#
#
# 2175
# Cocoa
#
#
# 2176
# Americano
#
#
# 2177
# Latte
#
#
# 2178
# Cocoa
#
#
# 2179
# Cocoa
#
#
# 2180
# Cortado
#
#
# 2181
# Americano with Milk
#
#
# 2182
# Cortado
#
#
# 2183
# Cocoa
#
#
# 2184
# Americano with Milk
#
#
# 2185
# Americano with Milk
#
#
# 2186
# Hot Chocolate
#
#
# 2187
# Latte
#
#
# 2188
# Latte
#
#
# 2189
# Americano with Milk
#
#
# 2190
# Americano
#
#
# 2191
# Cortado
#
#
# 2192
# Americano with Milk
#
#
# 2193
# Americano with Milk
#
#
# 2194
# Latte
#
#
# 2195
# Americano with Milk
#
#
# 2196
# Cocoa
#
#
# 2197
# Americano
#
#
# 2198
# Americano with Milk
#
#
# 2199
# Hot Chocolate
#
#
# 2200
# Hot Chocolate
#
#
# 2201
# Americano
#
#
# 2202
# Americano
#
#
# 2203
# Cocoa
#
#
# 2204
# Latte
#
#
# 2205
# Latte
#
#
# 2206
# Americano with Milk
#
#
# 2207
# Americano
#
#
# 2208
# Americano with Milk
#
#
# 2209
# Cocoa
#
#
# 2210
# Cocoa
#
#
# 2211
# Cocoa
#
#
# 2212
# Americano with Milk
#
#
# 2213
# Cappuccino
#
#
# 2214
# Americano with Milk
#
#
# 2215
# Americano with Milk
#
#
# 2216
# Cocoa
#
#
# 2217
# Latte
#
#
# 2218
# Latte
#
#
# 2219
# Latte
#
#
# 2220
# Cappuccino
#
#
# 2221
# Cappuccino
#
#
# 2222
# Cappuccino
#
#
# 2223
# Cocoa
#
#
# 2224
# Cocoa
#
#
# 2225
# Hot Chocolate
#
#
# 2226
# Hot Chocolate
#
#
# 2227
# Americano with Milk
#
#
# 2228
# Latte
#
#
# 2229
# Espresso
#
#
# 2230
# Americano
#
#
# 2231
# Cappuccino
#
#
# 2232
# Latte
#
#
# 2233
# Cappuccino
#
#
# 2234
# Hot Chocolate
#
#
# 2235
# Hot Chocolate
#
#
# 2236
# Latte
#
#
# 2237
# Americano
#
#
# 2238
# Americano
#
#
# 2239
# Cocoa
#
#
# 2240
# Hot Chocolate
#
#
# 2241
# Latte
#
#
# 2242
# Latte
#
#
# 2243
# Americano with Milk
#
#
# 2244
# Americano
#
#
# 2245
# Americano
#
#
# 2246
# Cappuccino
#
#
# 2247
# Latte
#
#
# 2248
# Latte
#
#
# 2249
# Americano with Milk
#
#
# 2250
# Americano with Milk
#
#
# 2251
# Hot Chocolate
#
#
# 2252
# Hot Chocolate
#
#
# 2253
# Hot Chocolate
#
#
# 2254
# Latte
#
#
# 2255
# Americano with Milk
#
#
# 2256
# Cortado
#
#
# 2257
# Cortado
#
#
# 2258
# Latte
#
#
# 2259
# Hot Chocolate
#
#
# 2260
# Hot Chocolate
#
#
# 2261
# Hot Chocolate
#
#
# 2262
# Hot Chocolate
#
#
# 2263
# Americano
#
#
# 2264
# Americano with Milk
#
#
# 2265
# Latte
#
#
# 2266
# Cocoa
#
#
# 2267
# Americano
#
#
# 2268
# Latte
#
#
# 2269
# Cocoa
#
#
# 2270
# Americano
#
#
# 2271
# Americano
#
#
# 2272
# Americano
#
#
# 2273
# Cocoa
#
#
# 2274
# Hot Chocolate
#
#
# 2275
# Hot Chocolate
#
#
# 2276
# Cappuccino
#
#
# 2277
# Cappuccino
#
#
# 2278
# Cappuccino
#
#
# 2279
# Americano with Milk
#
#
# 2280
# Cortado
#
#
# 2281
# Cappuccino
#
#
# 2282
# Hot Chocolate
#
#
# 2283
# Cappuccino
#
#
# 2284
# Latte
#
#
# 2285
# Hot Chocolate
#
#
# 2286
# Latte
#
#
# 2287
# Latte
#
#
# 2288
# Latte
#
#
# 2289
# Latte
#
#
# 2290
# Latte
#
#
# 2291
# Hot Chocolate
#
#
# 2292
# Hot Chocolate
#
#
# 2293
# Cocoa
#
#
# 2294
# Cappuccino
#
#
# 2295
# Latte
#
#
# 2296
# Cocoa
#
#
# 2297
# Americano with Milk
#
#
# 2298
# Latte
#
#
# 2299
# Americano with Milk
#
#
# 2300
# Americano with Milk
#
#
# 2301
# Americano with Milk
#
#
# 2302
# Latte
#
#
# 2303
# Latte
#
#
# 2304
# Americano
#
#
# 2305
# Espresso
#
#
# 2306
# Cappuccino
#
#
# 2307
# Latte
#
#
# 2308
# Cappuccino
#
#
# 2309
# Americano with Milk
#
#
# 2310
# Cappuccino
#
#
# 2311
# Hot Chocolate
#
#
# 2312
# Hot Chocolate
#
#
# 2313
# Cocoa
#
#
# 2314
# Hot Chocolate
#
#
# 2315
# Latte
#
#
# 2316
# Latte
#
#
# 2317
# Americano with Milk
#
#
# 2318
# Americano with Milk
#
#
# 2319
# Cocoa
#
#
# 2320
# Cocoa
#
#
# 2321
# Latte
#
#
# 2322
# Americano
#
#
# 2323
# Americano with Milk
#
#
# 2324
# Latte
#
#
# 2325
# Hot Chocolate
#
#
# 2326
# Americano with Milk
#
#
# 2327
# Americano with Milk
#
#
# 2328
# Cortado
#
#
# 2329
# Cortado
#
#
# 2330
# Hot Chocolate
#
#
# 2331
# Latte
#
#
# 2332
# Americano
#
#
# 2333
# Cappuccino
#
#
# 2334
# Americano with Milk
#
#
# 2335
# Latte
#
#
# 2336
# Latte
#
#
# 2337
# Americano with Milk
#
#
# 2338
# Latte
#
#
# 2339
# Latte
#
#
# 2340
# Americano with Milk
#
#
# 2341
# Americano with Milk
#
#
# 2342
# Americano with Milk
#
#
# 2343
# Americano
#
#
# 2344
# Americano with Milk
#
#
# 2345
# Latte
#
#
# 2346
# Latte
#
#
# 2347
# Hot Chocolate
#
#
# 2348
# Hot Chocolate
#
#
# 2349
# Hot Chocolate
#
#
# 2350
# Americano with Milk
#
#
# 2351
# Americano with Milk
#
#
# 2352
# Latte
#
#
# 2353
# Latte
#
#
# 2354
# Latte
#
#
# 2355
# Latte
#
#
# 2356
# Cocoa
#
#
# 2357
# Americano with Milk
#
#
# 2358
# Latte
#
#
# 2359
# Espresso
#
#
# 2360
# Latte
#
#
# 2361
# Americano with Milk
#
#
# 2362
# Latte
#
#
# 2363
# Cocoa
#
#
# 2364
# Cocoa
#
#
# 2365
# Cappuccino
#
#
# 2366
# Cappuccino
#
#
# 2367
# Americano with Milk
#
#
# 2368
# Latte
#
#
# 2369
# Cappuccino
#
#
# 2370
# Hot Chocolate
#
#
# 2371
# Cortado
#
#
# 2372
# Latte
#
#
# 2373
# Cocoa
#
#
# 2374
# Cocoa
#
#
# 2375
# Latte
#
#
# 2376
# Americano with Milk
#
#
# 2377
# Cortado
#
#
# 2378
# Hot Chocolate
#
#
# 2379
# Latte
#
#
# 2380
# Cappuccino
#
#
# 2381
# Latte
#
#
# 2382
# Cocoa
#
#
# 2383
# Hot Chocolate
#
#
# 2384
# Latte
#
#
# 2385
# Cortado
#
#
# 2386
# Cortado
#
#
# 2387
# Latte
#
#
# 2388
# Cappuccino
#
#
# 2389
# Americano
#
#
# 2390
# Americano
#
#
# 2391
# Hot Chocolate
#
#
# 2392
# Latte
#
#
# 2393
# Latte
#
#
# 2394
# Cappuccino
#
#
# 2395
# Latte
#
#
# 2396
# Americano with Milk
#
#
# 2397
# Cortado
#
#
# 2398
# Latte
#
#
# 2399
# Latte
#
#
# 2400
# Hot Chocolate
#
#
# 2401
# Americano with Milk
#
#
# 2402
# Hot Chocolate
#
#
# 2403
# Hot Chocolate
#
#
# 2404
# Cappuccino
#
#
# 2405
# Latte
#
#
# 2406
# Cocoa
#
#
# 2407
# Americano
#
#
# 2408
# Cocoa
#
#
# 2409
# Cocoa
#
#
# 2410
# Latte
#
#
# 2411
# Latte
#
#
# 2412
# Americano
#
#
# 2413
# Americano with Milk
#
#
# 2414
# Cocoa
#
#
# 2415
# Cappuccino
#
#
# 2416
# Americano with Milk
#
#
# 2417
# Americano with Milk
#
#
# 2418
# Latte
#
#
# 2419
# Latte
#
#
# 2420
# Cappuccino
#
#
# 2421
# Cocoa
#
#
# 2422
# Latte
#
#
# 2423
# Americano with Milk
#
#
# 2424
# Americano with Milk
#
#
# 2425
# Americano with Milk
#
#
# 2426
# Latte
#
#
# 2427
# Cocoa
#
#
# 2428
# Cocoa
#
#
# 2429
# Americano
#
#
# 2430
# Hot Chocolate
#
#
# 2431
# Cocoa
#
#
# 2432
# Americano with Milk
#
#
# 2433
# Americano with Milk
#
#
# 2434
# Americano with Milk
#
#
# 2435
# Americano with Milk
#
#
# 2436
# Americano with Milk
#
#
# 2437
# Americano with Milk
#
#
# 2438
# Cocoa
#
#
# 2439
# Cocoa
#
#
# 2440
# Cappuccino
#
#
# 2441
# Latte
#
#
# 2442
# Latte
#
#
# 2443
# Latte
#
#
# 2444
# Latte
#
#
# 2445
# Americano with Milk
#
#
# 2446
# Americano with Milk
#
#
# 2447
# Americano with Milk
#
#
# 2448
# Latte
#
#
# 2449
# Americano
#
#
# 2450
# Americano with Milk
#
#
# 2451
# Cocoa
#
#
# 2452
# Cortado
#
#
# 2453
# Espresso
#
#
# 2454
# Cappuccino
#
#
# 2455
# Americano
#
#
# 2456
# Cappuccino
#
#
# 2457
# Latte
#
#
# 2458
# Americano with Milk
#
#
# 2459
# Americano with Milk
#
#
# 2460
# Americano
#
#
# 2461
# Americano with Milk
#
#
# 2462
# Americano with Milk
#
#
# 2463
# Americano with Milk
#
#
# 2464
# Cocoa
#
#
# 2465
# Latte
#
#
# 2466
# Cappuccino
#
#
# 2467
# Hot Chocolate
#
#
# 2468
# Americano with Milk
#
#
# 2469
# Cappuccino
#
#
# 2470
# Cortado
#
#
# 2471
# Latte
#
#
# 2472
# Latte
#
#
# 2473
# Americano
#
#
# 2474
# Americano with Milk
#
#
# 2475
# Americano with Milk
#
#
# 2476
# Americano with Milk
#
#
# 2477
# Hot Chocolate
#
#
# 2478
# Americano with Milk
#
#
# 2479
# Hot Chocolate
#
#
# 2480
# Americano
#
#
# 2481
# Cortado
#
#
# 2482
# Americano with Milk
#
#
# 2483
# Americano with Milk
#
#
# 2484
# Latte
#
#
# 2485
# Americano
#
#
# 2486
# Cappuccino
#
#
# 2487
# Latte
#
#
# 2488
# Latte
#
#
# 2489
# Latte
#
#
# 2490
# Hot Chocolate
#
#
# 2491
# Latte
#
#
# 2492
# Hot Chocolate
#
#
# 2493
# Americano with Milk
#
#
# 2494
# Americano
#
#
# 2495
# Latte
#
#
# 2496
# Cappuccino
#
#
# 2497
# Americano with Milk
#
#
# 2498
# Americano
#
#
# 2499
# Cortado
#
#
# 2500
# Latte
#
#
# 2501
# Cappuccino
#
#
# 2502
# Cortado
#
#
# 2503
# Americano with Milk
#
#
# 2504
# Americano with Milk
#
#
# 2505
# Cappuccino
#
#
# 2506
# Espresso
#
#
# 2507
# Cappuccino
#
#
# 2508
# Americano with Milk
#
#
# 2509
# Americano with Milk
#
#
# 2510
# Cappuccino
#
#
# 2511
# Americano
#
#
# 2512
# Americano with Milk
#
#
# 2513
# Cortado
#
#
# 2514
# Cocoa
#
#
# 2515
# Cortado
#
#
# 2516
# Hot Chocolate
#
#
# 2517
# Latte
#
#
# 2518
# Cortado
#
#
# 2519
# Hot Chocolate
#
#
# 2520
# Espresso
#
#
# 2521
# Cocoa
#
#
# 2522
# Latte
#
#
# 2523
# Latte
#
#
# 2524
# Americano with Milk
#
#
# 2525
# Americano
#
#
# 2526
# Espresso
#
#
# 2527
# Espresso
#
#
# 2528
# Americano
#
#
# 2529
# Cocoa
#
#
# 2530
# Cocoa
#
#
# 2531
# Americano
#
#
# 2532
# Americano
#
#
# 2533
# Hot Chocolate
#
#
# 2534
# Hot Chocolate
#
#
# 2535
# Cocoa
#
#
# 2536
# Cappuccino
#
#
# 2537
# Cappuccino
#
#
# 2538
# Latte
#
#
# 2539
# Americano with Milk
#
#
# 2540
# Cocoa
#
#
# 2541
# Cappuccino
#
#
# 2542
# Americano
#
#
# 2543
# Latte
#
#
# 2544
# Cocoa
#
#
# 2545
# Americano
#
#
# 2546
# Americano
#
#
# 2547
# Americano
#
#
# 2548
# Americano
#
#
# 2549
# Americano with Milk
#
#
# 2550
# Latte
#
#
# 2551
# Cocoa
#
#
# 2552
# Hot Chocolate
#
#
# 2553
# Latte
#
#
# 2554
# Hot Chocolate
#
#
# 2555
# Cocoa
#
#
# 2556
# Americano with Milk
#
#
# 2557
# Latte
#
#
# 2558
# Hot Chocolate
#
#
# 2559
# Latte
#
#
# 2560
# Americano with Milk
#
#
# 2561
# Cortado
#
#
# 2562
# Cappuccino
#
#
# 2563
# Americano with Milk
#
#
# 2564
# Americano
#
#
# 2565
# Cocoa
#
#
# 2566
# Cappuccino
#
#
# 2567
# Cocoa
#
#
# 2568
# Latte
#
#
# 2569
# Americano with Milk
#
#
# 2570
# Latte
#
#
# 2571
# Cappuccino
#
#
# 2572
# Hot Chocolate
#
#
# 2573
# Americano with Milk
#
#
# 2574
# Espresso
#
#
# 2575
# Hot Chocolate
#
#
# 2576
# Cappuccino
#
#
# 2577
# Cappuccino
#
#
# 2578
# Americano with Milk
#
#
# 2579
# Hot Chocolate
#
#
# 2580
# Latte
#
#
# 2581
# Cappuccino
#
#
# 2582
# Cortado
#
#
# 2583
# Americano with Milk
#
#
# 2584
# Cappuccino
#
#
# 2585
# Cortado
#
#
# 2586
# Espresso
#
#
# 2587
# Americano with Milk
#
#
# 2588
# Cortado
#
#
# 2589
# Cappuccino
#
#
# 2590
# Cappuccino
#
#
# 2591
# Cappuccino
#
#
# 2592
# Latte
#
#
# 2593
# Americano
#
#
# 2594
# Hot Chocolate
#
#
# 2595
# Latte
#
#
# 2596
# Americano with Milk
#
#
# 2597
# Latte
#
#
# 2598
# Cocoa
#
#
# 2599
# Hot Chocolate
#
#
# 2600
# Cortado
#
#
# 2601
# Americano with Milk
#
#
# 2602
# Cortado
#
#
# 2603
# Cortado
#
#
# 2604
# Latte
#
#
# 2605
# Cortado
#
#
# 2606
# Cappuccino
#
#
# 2607
# Cappuccino
#
#
# 2608
# Hot Chocolate
#
#
# 2609
# Hot Chocolate
#
#
# 2610
# Hot Chocolate
#
#
# 2611
# Cocoa
#
#
# 2612
# Cortado
#
#
# 2613
# Cortado
#
#
# 2614
# Americano with Milk
#
#
# 2615
# Americano with Milk
#
#
# 2616
# Cappuccino
#
#
# 2617
# Latte
#
#
# 2618
# Americano with Milk
#
#
# 2619
# Latte
#
#
# 2620
# Cortado
#
#
# 2621
# Latte
#
#
# 2622
# Cortado
#
#
# 2623
# Americano with Milk
#
#
# 2624
# Hot Chocolate
#
#
# 2625
# Cortado
#
#
# 2626
# Hot Chocolate
#
#
# 2627
# Latte
#
#
# 2628
# Espresso
#
#
# 2629
# Cappuccino
#
#
# 2630
# Latte
#
#
# 2631
# Latte
#
#
# 2632
# Americano with Milk
#
#
# 2633
# Americano
#
#
# 2634
# Americano with Milk
#
#
# 2635
# Americano
#
#
# 2636
# Cappuccino
#
#
# 2637
# Cocoa
#
#
# 2638
# Cocoa
#
#
# 2639
# Latte
#
#
# 2640
# Cappuccino
#
#
# 2641
# Americano with Milk
#
#
# 2642
# Cappuccino
#
#
# 2643
# Espresso
#
#
# 2644
# Americano
#
#
# 2645
# Cortado
#
#
# 2646
# Cortado
#
#
# 2647
# Americano with Milk
#
#
# 2648
# Latte
#
#
# 2649
# Americano
#
#
# 2650
# Americano with Milk
#
#
# 2651
# Cocoa
#
#
# 2652
# Cortado
#
#
# 2653
# Cortado
#
#
# 2654
# Americano with Milk
#
#
# 2655
# Latte
#
#
# 2656
# Cappuccino
#
#
# 2657
# Hot Chocolate
#
#
# 2658
# Latte
#
#
# 2659
# Cappuccino
#
#
# 2660
# Cortado
#
#
# 2661
# Espresso
#
#
# 2662
# Americano
#
#
# 2663
# Cortado
#
#
# 2664
# ...
# Latte
#
#
# 3084
# Americano
#
#
# 3085
# Hot Chocolate
#
#
# 3086
# Americano
#
#
# 3087
# Espresso
#
#
# 3088
# Americano with Milk
#
#
# 3089
# Cappuccino
#
#
# 3090
# Cappuccino
#
#
# 3091
# Latte
#
#
# 3092
# Hot Chocolate
#
#
# 3093
# Cappuccino
#
#
# 3094
# Americano
#
#
# 3095
# Cocoa
#
#
# 3096
# Espresso
#
#
# 3097
# Americano with Milk
#
#
# 3098
# Americano
#
#
# 3099
# Cappuccino
#
#
# 3100
# Cappuccino
#
#
# 3101
# Americano
#
#
# 3102
# Americano with Milk
#
#
# 3103
# Americano with Milk
#
#
# 3104
# Cappuccino
#
#
# 3105
# Americano
#
#
# 3106
# Hot Chocolate
#
#
# 3107
# Hot Chocolate
#
#
# 3108
# Americano
#
#
# 3109
# Americano
#
#
# 3110
# Americano with Milk
#
#
# 3111
# Hot Chocolate
#
#
# 3112
# Americano
#
#
# 3113
# Hot Chocolate
#
#
# 3114
# Latte
#
#
# 3115
# Hot Chocolate
#
#
# 3116
# Americano with Milk
#
#
# 3117
# Americano with Milk
#
#
# 3118
# Cappuccino
#
#
# 3119
# Americano
#
#
# 3120
# Americano
#
#
# 3121
# Americano with Milk
#
#
# 3122
# Hot Chocolate
#
#
# 3123
# Americano with Milk
#
#
# 3124
# Americano
#
#
# 3125
# Americano with Milk
#
#
# 3126
# Espresso
#
#
# 3127
# Cappuccino
#
#
# 3128
# Latte
#
#
# 3129
# Americano with Milk
#
#
# 3130
# Latte
#
#
# 3131
# Espresso
#
#
# 3132
# Americano
#
#
# 3133
# Americano with Milk
#
#
# 3134
# Americano
#
#
# 3135
# Americano
#
#
# 3136
# Americano
#
#
# 3137
# Latte
#
#
# 3138
# Americano
#
#
# 3139
# Americano
#
#
# 3140
# Americano
#
#
# 3141
# Americano
#
#
# 3142
# Americano with Milk
#
#
# 3143
# Americano with Milk
#
#
# 3144
# Cocoa
#
#
# 3145
# Americano
#
#
# 3146
# Americano with Milk
#
#
# 3147
# Hot Chocolate
#
#
# 3148
# Americano with Milk
#
#
# 3149
# Espresso
#
#
# 3150
# Cocoa
#
#
# 3151
# Cocoa
#
#
# 3152
# Cocoa
#
#
# 3153
# Cocoa
#
#
# 3154
# Hot Chocolate
#
#
# 3155
# Americano with Milk
#
#
# 3156
# Cappuccino
#
#
# 3157
# Americano
#
#
# 3158
# Americano
#
#
# 3159
# Cappuccino
#
#
# 3160
# Americano
#
#
# 3161
# Hot Chocolate
#
#
# 3162
# Americano with Milk
#
#
# 3163
# Americano
#
#
# 3164
# Cocoa
#
#
# 3165
# Americano
#
#
# 3166
# Cappuccino
#
#
# 3167
# Americano
#
#
# 3168
# Cappuccino
#
#
# 3169
# Americano with Milk
#
#
# 3170
# Cappuccino
#
#
# 3171
# Latte
#
#
# 3172
# Cocoa
#
#
# 3173
# Hot Chocolate
#
#
# 3174
# Latte
#
#
# 3175
# Cocoa
#
#
# 3176
# Cappuccino
#
#
# 3177
# Americano
#
#
# 3178
# Cappuccino
#
#
# 3179
# Americano
#
#
# 3180
# Americano
#
#
# 3181
# Americano
#
#
# 3182
# Americano with Milk
#
#
# 3183
# Latte
#
#
# 3184
# Americano
#
#
# 3185
# Americano
#
#
# 3186
# Espresso
#
#
# 3187
# Cappuccino
#
#
# 3188
# Cappuccino
#
#
# 3189
# Hot Chocolate
#
#
# 3190
# Americano
#
#
# 3191
# Americano
#
#
# 3192
# Hot Chocolate
#
#
# 3193
# Cocoa
#
#
# 3194
# Latte
#
#
# 3195
# Americano
#
#
# 3196
# Latte
#
#
# 3197
# Cappuccino
#
#
# 3198
# Espresso
#
#
# 3199
# Americano
#
#
# 3200
# Americano with Milk
#
#
# 3201
# Americano
#
#
# 3202
# Americano
#
#
# 3203
# Americano
#
#
# 3204
# Americano
#
#
# 3205
# Americano
#
#
# 3206
# Americano
#
#
# 3207
# Cappuccino
#
#
# 3208
# Americano
#
#
# 3209
# Americano
#
#
# 3210
# Americano
#
#
# 3211
# Cocoa
#
#
# 3212
# Latte
#
#
# 3213
# Hot Chocolate
#
#
# 3214
# Latte
#
#
# 3215
# Cocoa
#
#
# 3216
# Cocoa
#
#
# 3217
# Cappuccino
#
#
# 3218
# Hot Chocolate
#
#
# 3219
# Americano
#
#
# 3220
# Americano
#
#
# 3221
# Espresso
#
#
# 3222
# Americano with Milk
#
#
# 3223
# Americano with Milk
#
#
# 3224
# Americano with Milk
#
#
# 3225
# Americano with Milk
#
#
# 3226
# Cappuccino
#
#
# 3227
# Cocoa
#
#
# 3228
# Americano
#
#
# 3229
# Americano with Milk
#
#
# 3230
# Latte
#
#
# 3231
# Americano
#
#
# 3232
# Americano with Milk
#
#
# 3233
# Americano with Milk
#
#
# 3234
# Cocoa
#
#
# 3235
# Latte
#
#
# 3236
# Cocoa
#
#
# 3237
# Americano with Milk
#
#
# 3238
# Cocoa
#
#
# 3239
# Cappuccino
#
#
# 3240
# Latte
#
#
# 3241
# Americano
#
#
# 3242
# Americano
#
#
# 3243
# Americano with Milk
#
#
# 3244
# Americano with Milk
#
#
# 3245
# Latte
#
#
# 3246
# Americano with Milk
#
#
# 3247
# Hot Chocolate
#
#
# 3248
# Latte
#
#
# 3249
# Cocoa
#
#
# 3250
# Cocoa
#
#
# 3251
# Americano with Milk
#
#
# 3252
# Americano
#
#
# 3253
# Americano with Milk
#
#
# 3254
# Espresso
#
#
# 3255
# Americano
#
#
# 3256
# Americano
#
#
# 3257
# Cappuccino
#
#
# 3258
# Cappuccino
#
#
# 3259
# Americano
#
#
# 3260
# Americano
#
#
# 3261
# Cocoa
#
#
# 3262
# Cappuccino
#
#
# 3263
# Americano
#
#
# 3264
# Americano with Milk
#
#
# 3265
# Americano with Milk
#
#
# 3266
# Hot Chocolate
#
#
# 3267
# Cocoa
#
#
# 3268
# Latte
#
#
# 3269
# Americano
#
#
# 3270
# Americano
#
#
# 3271
# Cortado
#
#
# 3272
# Hot Chocolate
#
#
# 3273
# Americano
#
#
# 3274
# Americano
#
#
# 3275
# Latte
#
#
# 3276
# Hot Chocolate
#
#
# 3277
# Latte
#
#
# 3278
# Americano with Milk
#
#
# 3279
# Latte
#
#
# 3280
# Cappuccino
#
#
# 3281
# Cappuccino
#
#
# 3282
# Cappuccino
#
#
# 3283
# Espresso
#
#
# 3284
# Cocoa
#
#
# 3285
# Cocoa
#
#
# 3286
# Americano with Milk
#
#
# 3287
# Americano
#
#
# 3288
# Latte
#
#
# 3289
# Americano
#
#
# 3290
# Americano
#
#
# 3291
# Americano
#
#
# 3292
# Americano
#
#
# 3293
# Latte
#
#
# 3294
# Latte
#
#
# 3295
# Cappuccino
#
#
# 3296
# Cocoa
#
#
# 3297
# Cocoa
#
#
# 3298
# Latte
#
#
# 3299
# Cappuccino
#
#
# 3300
# Americano with Milk
#
#
# 3301
# Americano with Milk
#
#
# 3302
# Cappuccino
#
#
# 3303
# Espresso
#
#
# 3304
# Americano with Milk
#
#
# 3305
# Americano
#
#
# 3306
# Americano
#
#
# 3307
# Americano
#
#
# 3308
# Latte
#
#
# 3309
# Americano
#
#
# 3310
# Cocoa
#
#
# 3311
# Americano
#
#
# 3312
# Latte
#
#
# 3313
# Americano with Milk
#
#
# 3314
# Americano
#
#
# 3315
# Americano
#
#
# 3316
# Latte
#
#
# 3317
# Cappuccino
#
#
# 3318
# Americano
#
#
# 3319
# Americano
#
#
# 3320
# Latte
#
#
# 3321
# Americano
#
#
# 3322
# Americano with Milk
#
#
# 3323
# Cappuccino
#
#
# 3324
# Americano
#
#
# 3325
# Cocoa
#
#
# 3326
# Latte
#
#
# 3327
# Americano with Milk
#
#
# 3328
# Americano with Milk
#
#
# 3329
# Americano
#
#
# 3330
# Americano
#
#
# 3331
# Cappuccino
#
#
# 3332
# Cocoa
#
#
# 3333
# Latte
#
#
# 3334
# Hot Chocolate
#
#
# 3335
# Hot Chocolate
#
#
# 3336
# Cappuccino
#
#
# 3337
# Latte
#
#
# 3338
# Americano
#
#
# 3339
# Cocoa
#
#
# 3340
# Latte
#
#
# 3341
# Latte
#
#
# 3342
# Cappuccino
#
#
# 3343
# Cappuccino
#
#
# 3344
# Americano
#
#
# 3345
# Americano with Milk
#
#
# 3346
# Americano
#
#
# 3347
# Hot Chocolate
#
#
# 3348
# Americano
#
#
# 3349
# Hot Chocolate
#
#
# 3350
# Hot Chocolate
#
#
# 3351
# Americano with Milk
#
#
# 3352
# Latte
#
#
# 3353
# Cappuccino
#
#
# 3354
# Americano
#
#
# 3355
# Americano with Milk
#
#
# 3356
# Americano
#
#
# 3357
# Americano
#
#
# 3358
# Americano
#
#
# 3359
# Americano with Milk
#
#
# 3360
# Americano
#
#
# 3361
# Americano
#
#
# 3362
# Americano
#
#
# 3363
# Americano
#
#
# 3364
# Cocoa
#
#
# 3365
# Americano
#
#
# 3366
# Cocoa
#
#
# 3367
# Latte
#
#
# 3368
# Latte
#
#
# 3369
# Americano with Milk
#
#
# 3370
# Americano
#
#
# 3371
# Americano
#
#
# 3372
# Americano
#
#
# 3373
# Cappuccino
#
#
# 3374
# Americano with Milk
#
#
# 3375
# Cappuccino
#
#
# 3376
# Cocoa
#
#
# 3377
# Americano
#
#
# 3378
# Americano
#
#
# 3379
# Americano
#
#
# 3380
# Latte
#
#
# 3381
# Latte
#
#
# 3382
# Hot Chocolate
#
#
# 3383
# Americano with Milk
#
#
# 3384
# Espresso
#
#
# 3385
# Latte
#
#
# 3386
# Cappuccino
#
#
# 3387
# Cocoa
#
#
# 3388
# Hot Chocolate
#
#
# 3389
# Espresso
#
#
# 3390
# Americano with Milk
#
#
# 3391
# Americano
#
#
# 3392
# Americano
#
#
# 3393
# Americano
#
#
# 3394
# Cappuccino
#
#
# 3395
# Latte
#
#
# 3396
# Americano with Milk
#
#
# 3397
# Cocoa
#
#
# 3398
# Cappuccino
#
#
# 3399
# Americano with Milk
#
#
# 3400
# Cappuccino
#
#
# 3401
# Americano
#
#
# 3402
# Americano
#
#
# 3403
# Americano
#
#
# 3404
# Hot Chocolate
#
#
# 3405
# Americano with Milk
#
#
# 3406
# Americano with Milk
#
#
# 3407
# Cocoa
#
#
# 3408
# Cocoa
#
#
# 3409
# Americano with Milk
#
#
# 3410
# Hot Chocolate
#
#
# 3411
# Americano
#
#
# 3412
# Cappuccino
#
#
# 3413
# Latte
#
#
# 3414
# Latte
#
#
# 3415
# Latte
#
#
# 3416
# Hot Chocolate
#
#
# 3417
# Americano with Milk
#
#
# 3418
# Americano with Milk
#
#
# 3419
# Americano
#
#
# 3420
# Americano
#
#
# 3421
# Americano
#
#
# 3422
# Americano with Milk
#
#
# 3423
# Americano
#
#
# 3424
# Cappuccino
#
#
# 3425
# Espresso
#
#
# 3426
# Americano with Milk
#
#
# 3427
# Cappuccino
#
#
# 3428
# Americano
#
#
# 3429
# Cappuccino
#
#
# 3430
# Americano
#
#
# 3431
# Americano with Milk
#
#
# 3432
# Cocoa
#
#
# 3433
# Americano
#
#
# 3434
# Latte
#
#
# 3435
# Americano with Milk
#
#
# 3436
# Hot Chocolate
#
#
# 3437
# Cocoa
#
#
# 3438
# Hot Chocolate
#
#
# 3439
# Americano
#
#
# 3440
# Americano
#
#
# 3441
# Hot Chocolate
#
#
# 3442
# Latte
#
#
# 3443
# Latte
#
#
# 3444
# Cappuccino
#
#
# 3445
# Americano with Milk
#
#
# 3446
# Americano
#
#
# 3447
# Latte
#
#
# 3448
# Latte
#
#
# 3449
# Americano with Milk
#
#
# 3450
# Americano
#
#
# 3451
# Cappuccino
#
#
# 3452
# Latte
#
#
# 3453
# Americano
#
#
# 3454
# Americano
#
#
# 3455
# Americano
#
#
# 3456
# Hot Chocolate
#
#
# 3457
# Cocoa
#
#
# 3458
# Hot Chocolate
#
#
# 3459
# Cappuccino
#
#
# 3460
# Americano with Milk
#
#
# 3461
# Latte
#
#
# 3462
# Cocoa
#
#
# 3463
# Cocoa
#
#
# 3464
# Americano with Milk
#
#
# 3465
# Cappuccino
#
#
# 3466
# Americano
#
#
# 3467
# Americano
#
#
# 3468
# Americano
#
#
# 3469
# Hot Chocolate
#
#
# 3470
# Latte
#
#
# 3471
# Latte
#
#
# 3472
# Cappuccino
#
#
# 3473
# Latte
#
#
# 3474
# Latte
#
#
# 3475
# Americano
#
#
# 3476
# Cocoa
#
#
# 3477
# Americano
#
#
# 3478
# Cappuccino
#
#
# 3479
# Americano
#
#
# 3480
# Cappuccino
#
#
# 3481
# Americano with Milk
#
#
# 3482
# Americano with Milk
#
#
# 3483
# Latte
#
#
# 3484
# Espresso
#
#
# 3485
# Americano
#
#
# 3486
# Americano with Milk
#
#
# 3487
# Americano
#
#
# 3488
# Latte
#
#
# 3489
# Americano with Milk
#
#
# 3490
# Americano
#
#
# 3491
# Cappuccino
#
#
# 3492
# Americano
#
#
# 3493
# Americano with Milk
#
#
# 3494
# Americano
#
#
# 3495
# Latte
#
#
# 3496
# Espresso
#
#
# 3497
# Americano
#
#
# 3498
# Americano
#
#
# 3499
# Latte
#
#
# 3500
# Cappuccino
#
#
# 3501
# Americano
#
#
# 3502
# Latte
#
#
# 3503
# Latte
#
#
# 3504
# Latte
#
#
# 3505
# Americano
#
#
# 3506
# Cocoa
#
#
# 3507
# Cocoa
#
#
# 3508
# Cocoa
#
#
# 3509
# Americano
#
#
# 3510
# Americano
#
#
# 3511
# Latte
#
#
# 3512
# Latte
#
#
# 3513
# Americano
#
#
# 3514
# Americano
#
#
# 3515
# Americano with Milk
#
#
# 3516
# Cappuccino
#
#
# 3517
# Americano
#
#
# 3518
# Cappuccino
#
#
# 3519
# Americano with Milk
#
#
# 3520
# Americano with Milk
#
#
# 3521
# Cappuccino
#
#
# 3522
# Cappuccino
#
#
# 3523
# Americano with Milk
#
#
# 3524
# Latte
#
#
# 3525
# Hot Chocolate
#
#
# 3526
# Americano
#
#
# 3527
# Americano
#
#
# 3528
# Americano
#
#
# 3529
# Americano
#
#
# 3530
# Americano with Milk
#
#
# 3531
# Americano
#
#
# 3532
# Americano
#
#
# 3533
# Cocoa
#
#
# 3534
# Cocoa
#
#
# 3535
# Latte
#
#
# 3536
# Cappuccino
#
#
# 3537
# Latte
#
#
# 3538
# Latte
#
#
# 3539
# Americano
#
#
# 3540
# Americano with Milk
#
#
# 3541
# Latte
#
#
# 3542
# Latte
#
#
# 3543
# Americano
#
#
# 3544
# Hot Chocolate
#
#
# 3545
# Hot Chocolate
#
#
# 3546
# Americano with Milk
#
#
# 3547
# Americano
#
#
# 3548
# Americano with Milk
#
#
# 3549
# Americano
#
#
# 3550
# Latte
#
#
# 3551
# Espresso
#
#
# 3552
# Cocoa
#
#
# 3553
# Cocoa
#
#
# 3554
# Cocoa
#
#
# 3555
# Cocoa
#
#
# 3556
# Latte
#
#
# 3557
# Americano
#
#
# 3558
# Americano
#
#
# 3559
# Cappuccino
#
#
# 3560
# Americano
#
#
# 3561
# Hot Chocolate
#
#
# 3562
# Americano
#
#
# 3563
# Americano
#
#
# 3564
# Latte
#
#
# 3565
# Latte
#
#
# 3566
# Latte
#
#
# 3567
# Americano
#
#
# 3568
# Cappuccino
#
#
# 3569
# Cappuccino
#
#
# 3570
# Americano
#
#
# 3571
# Americano
#
#
# 3572
# Cocoa
#
#
# 3573
# Americano with Milk
#
#
# 3574
# Americano with Milk
#
#
# 3575
# Cortado
#
#
# 3576
# Espresso
#
#
# 3577
# Espresso
#
#
# 3578
# Americano with Milk
#
#
# 3579
# Americano with Milk
#
#
# 3580
# Americano with Milk
#
#
# 3581
# Americano
#
#
# 3582
# Americano
#
#
# 3583
# Americano
#
#
# 3584
# Americano
#
#
# 3585
# Americano
#
#
# 3586
# Espresso
#
#
# 3587
# Cortado
#
#
# 3588
# Cappuccino
#
#
# 3589
# Cappuccino
#
#
# 3590
# Americano
#
#
# 3591
# Americano
#
#
# 3592
# Cappuccino
#
#
# 3593
# Americano
#
#
# 3594
# Hot Chocolate
#
#
# 3595
# Cocoa
#
#
# 3596
# Cappuccino
#
#
# 3597
# Latte
#
#
# 3598
# Americano with Milk
#
#
# 3599
# Americano with Milk
#
#
# 3600
# Americano
#
#
# 3601
# Americano
#
#
# 3602
# Americano
#
#
# 3603
# Cappuccino
#
#
# 3604
# Americano
#
#
# 3605
# Latte
#
#
# 3606
# Americano
#
#
# 3607
# Latte
#
#
# 3608
# Cappuccino
#
#
# 3609
# Cappuccino
#
#
# 3610
# Americano
#
#
# 3611
# Latte
#
#
# 3612
# Cappuccino
#
#
# 3613
# Hot Chocolate
#
#
# 3614
# Latte
#
#
# 3615
# Latte
#
#
# 3616
# Latte
#
#
# 3617
# Americano
#
#
# 3618
# Americano with Milk
#
#
# 3619
# Americano with Milk
#
#
# 3620
# Hot Chocolate
#
#
# 3621
# Cocoa
#
#
# 3622
# Americano with Milk
#
#
# 3623
# Americano
#
#
# 3624
# Americano
#
#
# 3625
# Americano with Milk
#
#
# 3626
# Espresso
#
#
# 3627
# Latte
#
#
# 3628
# Americano with Milk
#
#
# 3629
# Americano with Milk
#
#
# 3630
# Latte
#
#
# 3631
# Cappuccino
#
#
# 3632
# Cocoa
#
#
# 3633
# Cocoa
#
#
# 3634
# Americano
#
#
# 3635
# Latte
#
#
# 3636
# Tea
#
#
# 3637
# Tea
#
#
# 3638
# Espresso
#
#
# 3639
# Chocolate with coffee
#
#
# 3640
# Chocolate with milk
#
#
# 3641
# Espresso
#
#
# 3642
# Coffee with Irish whiskey
#
#
# 3643
# Irish whiskey with milk
#
#
# 3644
# Double Irish whiskey
#
#
# 3645
# Chocolate with coffee
#
#
# 3646
# Double espresso
#
#
# 3647
# Americano with milk
#
#
# 3648
# Espresso
#
#
# 3649
# Cappuccino
#
#
# 3650
# Double espresso with milk
#
#
# 3651
# Double Irish whiskey
#
#
# 3652
# Caramel with Irish whiskey
#
#
# 3653
# Latte
#
#
# 3654
# Latte
#
#
# 3655
# Americano with milk
#
#
# 3656
# Latte
#
#
# 3657
# Tea
#
#
# 3658
# Caramel with Irish whiskey
#
#
# 3659
# Coffee with Irish whiskey
#
#
# 3660
# Americano
#
#
# 3661
# Americano
#
#
# 3662
# Chocolate with milk
#
#
# 3663
# Tea
#
#
# 3664
# Americano
#
#
# 3665
# Chocolate with milk
#
#
# 3666
# Latte
#
#
# 3667
# Double espresso with milk
#
#
# 3668
# Cappuccino
#
#
# 3669
# Americano with milk
#
#
# 3670
# Espresso
#
#
# 3671
# Espresso
#
#
# 3672
# Double Irish whiskey
#
#
# 3673
# Espresso
#
#
# 3674
# Espresso
#
#
# 3675
# Chocolate with milk
#
#
# 3676
# Coffee with Irish whiskey
#
#
# 3677
# Super chocolate
#
#
# 3678
# Double Irish whiskey
#
#
# 3679
# Americano
#
#
# 3680
# Double vanilla
#
#
# 3681
# Mochaccino
#
#
# 3682
# Irish whiskey with milk
#
#
# 3683
# Tea
#
#
# 3684
# Americano with milk
#
#
# 3685
# Americano with milk
#
#
# 3686
# Latte
#
#
# 3687
# Caramel with chocolate
#
#
# 3688
# Irish whiskey
#
#
# 3689
# Double vanilla
#
#
# 3690
# Latte
#
#
# 3691
# Coffee with Irish whiskey
#
#
# 3692
# Cappuccino
#
#
# 3693
# Caramel coffee
#
#
# 3694
# Espresso
#
#
# 3695
# Cappuccino
#
#
# 3696
# Caramel with Irish whiskey
#
#
# 3697
# Americano with milk
#
#
# 3698
# Espresso
#
#
# 3699
# Cappuccino
#
#
# 3700
# Coffee with Irish whiskey
#
#
# 3701
# Americano with milk
#
#
# 3702
# Vanilla with Irish whiskey
#
#
# 3703
# Americano with milk
#
#
# 3704
# Cappuccino
#
#
# 3705
# Americano with milk
#
#
# 3706
# Americano
#
#
# 3707
# Americano
#
#
# 3708
# Americano with milk
#
#
# 3709
# Espresso
#
#
# 3710
# Cappuccino
#
#
# 3711
# Mochaccino
#
#
# 3712
# Coffee with Irish whiskey
#
#
# 3713
# Americano with milk
#
#
# 3714
# Espresso
#
#
# 3715
# Latte
#
#
# 3716
# Cappuccino
#
#
# 3717
# Chocolate
#
#
# 3718
# Americano with milk
#
#
# 3719
# Americano with milk
#
#
# 3720
# Double Irish whiskey
#
#
# 3721
# Irish whiskey
#
#
# 3722
# Mochaccino
#
#
# 3723
# Irish whiskey
#
#
# 3724
# Americano with milk
#
#
# 3725
# Americano with milk
#
#
# 3726
# Double Irish whiskey
#
#
# 3727
# Espresso
#
#
# 3728
# Latte
#
#
# 3729
# Americano with milk
#
#
# 3730
# Latte
#
#
# 3731
# Tea
#
#
# 3732
# Caramel with chocolate
#
#
# 3733
# Latte
#
#
# 3734
# Americano with milk
#
#
# 3735
# Coffee with Irish whiskey
#
#
# 3736
# Double Irish whiskey
#
#
# 3737
# Americano
#
#
# 3738
# Americano with milk
#
#
# 3739
# Double Irish whiskey
#
#
# 3740
# Tea
#
#
# 3741
# Caramel with Irish whiskey
#
#
# 3742
# Caramel with Irish whiskey
#
#
# 3743
# Caramel with milk
#
#
# 3744
# Coffee with Irish whiskey
#
#
# 3745
# Latte
#
#
# 3746
# Americano with milk
#
#
# 3747
# Americano with milk
#
#
# 3748
# Irish whiskey
#
#
# 3749
# Latte
#
#
# 3750
# Irish whiskey with milk
#
#
# 3751
# Tea
#
#
# 3752
# Espresso
#
#
# 3753
# Tea
#
#
# 3754
# Tea
#
#
# 3755
# Tea
#
#
# 3756
# Tea
#
#
# 3757
# Latte
#
#
# 3758
# Latte
#
#
# 3759
# Irish whiskey with milk
#
#
# 3760
# Coffee with Irish whiskey
#
#
# 3761
# Caramel with milk
#
#
# 3762
# Caramel with chocolate
#
#
# 3763
# Americano with milk
#
#
# 3764
# Tea
#
#
# 3765
# Americano with milk
#
#
# 3766
# Espresso
#
#
# 3767
# Latte
#
#
# 3768
# Latte
#
#
# 3769
# Cappuccino
#
#
# 3770
# Americano with milk
#
#
# 3771
# Super chocolate
#
#
# 3772
# Double Irish whiskey
#
#
# 3773
# Americano with milk
#
#
# 3774
# Cappuccino
#
#
# 3775
# Americano with milk
#
#
# 3776
# Tea
#
#
# 3777
# Chocolate with milk
#
#
# 3778
# Irish whiskey with milk
#
#
# 3779
# Americano with milk
#
#
# 3780
# Cappuccino
#
#
# 3781
# Caramel coffee
#
#
# 3782
# Coffee with chocolate
#
#
# 3783
# Cappuccino
#
#
# 3784
# Super chocolate
#
#
# 3785
# Irish whiskey
#
#
# 3786
# Chocolate with milk
#
#
# 3787
# Irish whiskey with milk
#
#
# 3788
# Latte
#
#
# 3789
# Caramel with milk
#
#
# 3790
# Americano with milk
#
#
# 3791
# Irish whiskey
#
#
# 3792
# Irish whiskey
#
#
# 3793
# Irish with chocolate
#
#
# 3794
# Caramel with Irish whiskey
#
#
# 3795
# Americano with milk
#
#
# 3796
# Irish whiskey
#
#
# 3797
# Vanilla coffee
#
#
# 3798
# Espresso
#
#
# 3799
# Americano
#
#
# 3800
# Irish whiskey with milk
#
#
# 3801
# Latte
#
#
# 3802
# Americano with milk
#
#
# 3803
# Americano
#
#
# 3804
# Double ristretto
#
#
# 3805
# Americano with milk
#
#
# 3806
# Irish with chocolate
#
#
# 3807
# Irish whiskey
#
#
# 3808
# Chocolate with milk
#
#
# 3809
# Americano with milk
#
#
# 3810
# Espresso
#
#
# 3811
# Hot milkshake
#
#
# 3812
# Caramel with chocolate
#
#
# 3813
# Americano
#
#
# 3814
# Americano
#
#
# 3815
# Americano
#
#
# 3816
# Mochaccino
#
#
# 3817
# Americano
#
#
# 3818
# Vanilla with Irish whiskey
#
#
# 3819
# Irish whiskey with milk
#
#
# 3820
# Chocolate with milk
#
#
# 3821
# Americano
#
#
# 3822
# Irish whiskey with milk
#
#
# 3823
# Irish whiskey with milk
#
#
# 3824
# Cappuccino
#
#
# 3825
# Cappuccino
#
#
# 3826
# Chocolate with milk
#
#
# 3827
# Super chocolate
#
#
# 3828
# Irish with chocolate
#
#
# 3829
# Irish with chocolate
#
#
# 3830
# Latte
#
#
# 3831
# Americano
#
#
# 3832
# Americano with milk
#
#
# 3833
# Double Irish whiskey
#
#
# 3834
# Americano with milk
#
#
# 3835
# Americano with milk
#
#
# 3836
# Irish whiskey with milk
#
#
# 3837
# Irish whiskey with milk
#
#
# 3838
# Americano with milk
#
#
# 3839
# Double Irish whiskey
#
#
# 3840
# Latte
#
#
# 3841
# Irish whiskey with milk
#
#
# 3842
# Tea
#
#
# 3843
# Espresso
#
#
# 3844
# Irish whiskey
#
#
# 3845
# Irish whiskey
#
#
# 3846
# Irish whiskey with milk
#
#
# 3847
# Chocolate with milk
#
#
# 3848
# Caramel with Irish whiskey
#
#
# 3849
# Irish whiskey
#
#
# 3850
# Americano with milk
#
#
# 3851
# Latte
#
#
# 3852
# Cappuccino
#
#
# 3853
# Americano with milk
#
#
# 3854
# Americano with milk
#
#
# 3855
# Americano with milk
#
#
# 3856
# Coffee with Irish whiskey
#
#
# 3857
# Coffee with Irish whiskey
#
#
# 3858
# Irish whiskey
#
#
# 3859
# Latte
#
#
# 3860
# Coffee with Irish whiskey
#
#
# 3861
# Coffee with Irish whiskey
#
#
# 3862
# Coffee with Irish whiskey
#
#
# 3863
# Double Irish whiskey
#
#
# 3864
# Espresso
#
#
# 3865
# Irish whiskey
#
#
# 3866
# Chocolate with coffee
#
#
# 3867
# Chocolate with coffee
#
#
# 3868
# Irish whiskey
#
#
# 3869
# Chocolate with milk
#
#
# 3870
# Mochaccino
#
#
# 3871
# Latte
#
#
# 3872
# Double chocolate
#
#
# 3873
# Irish whiskey
#
#
# 3874
# Latte
#
#
# 3875
# Chocolate with coffee
#
#
# 3876
# Irish whiskey
#
#
# 3877
# Chocolate with milk
#
#
# 3878
# Super chocolate
#
#
# 3879
# Americano with milk
#
#
# 3880
# Irish whiskey with milk
#
#
# 3881
# Irish with chocolate
#
#
# 3882
# Irish whiskey
#
#
# 3883
# Tea
#
#
# 3884
# Irish whiskey
#
#
# 3885
# Caramel with Irish whiskey
#
#
# 3886
# Caramel
#
#
# 3887
# Americano with milk
#
#
# 3888
# Americano with milk
#
#
# 3889
# Coffee with Irish whiskey
#
#
# 3890
# Irish whiskey
#
#
# 3891
# Americano with milk
#
#
# 3892
# Americano with milk
#
#
# 3893
# Cappuccino
#
#
# 3894
# Irish whiskey
#
#
# 3895
# Super chocolate
#
#
# 3896
# Vanilla with Irish whiskey
#
#
# 3897
# Coffee with Irish whiskey

# %%
sort_col = [('money', 'sum'), 
            ('coffee_name', 'count')]
sort_or = [True, False]

cdfs_table = cdfs.loc[(cdfs['money'] > 38) & 
(cdfs['month'] == 3), :].groupby('coffee_name').agg(
    {'money': ['sum','median'], 'coffee_name': 'count'}
).sort_values(by=sort_col, ascending=sort_or)

cdfs_table.columns = ['_'.join(
    col).strip() for col in cdfs_table.columns]

cdfs_table.reset_index(inplace=True)

    #BARAN BU NE MK

# Orders that cost more than 38$ and were made in March
# Grouped by coffee name and sorted by sum and count

# %%
#cdfs_table = cdfs_table.reset_index()
cdfs_table
# Out:
#      coffee_name  money_sum  money_median  coffee_name_count
# 0          Cocoa      232.2          38.7                  6
# 1     Cappuccino      780.5          38.7                 20
# 2  Hot Chocolate      854.0          38.7                 22
# 3          Latte     1874.5          38.7                 48

# %%
# Filtering on groupby object
cdfs_table[cdfs_table['coffee_name'] == 'Cappuccino']
# Out:
#   coffee_name  money_sum  money_median  coffee_name_count
# 1  Cappuccino      780.5          38.7                 20

# %% [markdown]
# ----------

# %% [markdown]
# ##### Splitting the columns inside

# %%
cdfs_new = cdfs.copy()

# %%
# Taking the first name of the coffee name column
# If we want to take the second name, we can use str[1]
cdfs_new['f_name'] = cdfs[
    'coffee_name'].str.split(' ').str[0]

cdfs_new[['f_name','money']]
# Out:
#           f_name  money
# 0          Latte   38.7
# 1            Hot   38.7
# 2            Hot   38.7
# 3      Americano   28.9
# 4          Latte   38.7
# ...          ...    ...
# 3893  Cappuccino   30.0
# 3894       Irish   25.0
# 3895       Super   28.0
# 3896     Vanilla   28.0
# 3897      Coffee   29.0
#
# [3898 rows x 2 columns]

# %%
# If we want to save the data to a csv file
# Index = False will not add another index column while saving IMPORTANT
cdfs_new.to_csv("cdfs_new.csv", index=False)

# %% [markdown]
# #### Adding/Removing Columns

# %%
cdfs['section'] = cdfs['money'].apply(lambda x: 'cheap' if x < 19.99 else (
    'normal' if x < 29.99 else 'expensive'))

# %%
cdfs['section'].value_counts()
# Out:
# section
# expensive    2475
# normal       1371
# cheap          52
# Name: count, dtype: int64

# %%
# We can also create function

def typeof_customer(row):
    if row['cash_type'] == 'card' and row ['money'] > 29.99:
        return 'rich'
    elif row['cash_type'] == 'card' and row ['money'] > 19.99:
        return 'middle class'
    else:
        return 'poor'

cdfs['typeof_customer'] = cdfs.apply(typeof_customer, axis=1)
cdfs.groupby('typeof_customer').count()
# Out:
#                  date  htime  cash_type  card  money  coffee_name  month  \
# typeof_customer
# middle class     1298   1298       1298  1166   1298         1298   1298
# poor              215    215        215    36    215          215    215
# rich             2385   2385       2385  2345   2385         2385   2385
#
#                  section
# typeof_customer
# middle class        1298
# poor                 215
# rich                2385

# %%
# MORE EFFICIENT WAY! 

conditions = [
    (cdfs['cash_type'] == 'card') & (cdfs['money'] > 29.99),
    (cdfs['cash_type'] == 'card') & (cdfs['money'] > 10.99),
]

choices = ["rich", "middle class"]

cdfs['typeof_customer'] = np.select(
    conditions,
    choices,
    default="poor"
    )

# %%
# Preparing for ML Ops - Encoding

type_number = {
    'poor' : 1,
    'middle class' : 2,
    'rich' : 3
}

cdfs['typeof_customer'] = cdfs['typeof_customer'].map(type_number)
cdfs[['coffee_name','money','typeof_customer']]
# Out:
#                      coffee_name  money  typeof_customer
# 0                          Latte   38.7                3
# 1                  Hot Chocolate   38.7                3
# 2                  Hot Chocolate   38.7                3
# 3                      Americano   28.9                2
# 4                          Latte   38.7                3
# ...                          ...    ...              ...
# 3893                  Cappuccino   30.0                1
# 3894               Irish whiskey   25.0                2
# 3895             Super chocolate   28.0                2
# 3896  Vanilla with Irish whiskey   28.0                2
# 3897   Coffee with Irish whiskey   29.0                2
#
# [3898 rows x 3 columns]

# %%
cdfs['milk'] = np.where(cdfs['coffee_name'].str.contains('with milk'), 'yes','no')

# %%
cdfs[cdfs['milk'] == 'yes'].groupby('section').agg({
    'money': 'sum','coffee_name':'count'})
# Out:
#             money  coffee_name
# section
# expensive    64.0            2
# normal     1904.0           74

# %%
cdfs[(cdfs['milk'] == 'no') &
(cdfs['section'] == 'expensive') |
(cdfs['section'] == 'cheap')].groupby(cdfs['coffee_name'])[
    ['money','milk']].agg({'money':'sum'})
# Out:
#                           money
# coffee_name
# Americano                180.00
# Americano with Milk    19070.88
# Cappuccino             18514.14
# Chocolate with coffee    150.00
# Cocoa                   8678.16
# Cortado                  150.00
# Espresso                 685.32
# Hot Chocolate          10172.46
# Hot milkshake             30.00
# Latte                  28658.30
# Mochaccino               150.00
# Tea                      240.00

# %% [markdown]
# -----------

# %% [markdown]
# #### Merge/Join/Concat

# %%
data_rezervasyon = {
    'rezervasyon_id': [1, 2, 3, 4],
    'musteri_id': [101, 102, 103, 101], # 101 tekrar ediyor, 103 sadece burada var
    'otel_tipi': ['City', 'Resort', 'City', 'Resort'],
    'adr': [120.5, 95.0, 150.0, 110.0]
}

df_rezervasyon = pd.DataFrame(data_rezervasyon)

# --- Veri Seti 2: Müşteri Profili (Sağ Tablo) ---
# Müşteriye ait genel bilgiler (Bu bilgiler rezervasyonda yok).
data_profil = {
    'musteri_id': [101, 102, 104, 105], # 104 ve 105 sadece burada var
    'ulke': ['TR', 'DE', 'FR', 'TR'],
    'sadakat_seviyesi': ['Gold', 'Silver', 'Bronze', 'Gold']
}

df_musteri_profil = pd.DataFrame(data_profil)

# %%
pd.merge(
    df_rezervasyon, df_musteri_profil,
    left_on = 'musteri_id', 
    right_on = 'musteri_id', 
    how = 'inner')
# Out:
#    rezervasyon_id  musteri_id otel_tipi    adr ulke sadakat_seviyesi
# 0               1         101      City  120.5   TR             Gold
# 1               2         102    Resort   95.0   DE           Silver
# 2               4         101    Resort  110.0   TR             Gold

# %% [markdown]
# ----------------

# %%
pd.merge(
    df_rezervasyon, df_musteri_profil,
    left_on = 'musteri_id', 
    right_on = 'musteri_id', 
    how = 'outer')
# Out:
#    rezervasyon_id  musteri_id otel_tipi    adr ulke sadakat_seviyesi
# 0             1.0         101      City  120.5   TR             Gold
# 1             4.0         101    Resort  110.0   TR             Gold
# 2             2.0         102    Resort   95.0   DE           Silver
# 3             3.0         103      City  150.0  NaN              NaN
# 4             NaN         104       NaN    NaN   FR           Bronze
# 5             NaN         105       NaN    NaN   TR             Gold

# %%
# Everything on the LEFT DF and INNER of RIGHT DF
pd.merge(
    df_rezervasyon, df_musteri_profil,
    left_on = 'musteri_id', 
    right_on = 'musteri_id', 
    how = 'left')
# Out:
#    rezervasyon_id  musteri_id otel_tipi    adr ulke sadakat_seviyesi
# 0               1         101      City  120.5   TR             Gold
# 1               2         102    Resort   95.0   DE           Silver
# 2               3         103      City  150.0  NaN              NaN
# 3               4         101    Resort  110.0   TR             Gold

# %%
# Everything on the RIGHT DF and INNER with according to RIGHT and LEFT DF

pd.merge(
    df_rezervasyon, df_musteri_profil,
    left_on = 'musteri_id', 
    right_on = 'musteri_id', 
    how = 'right')
# Out:
#    rezervasyon_id  musteri_id otel_tipi    adr ulke sadakat_seviyesi
# 0             1.0         101      City  120.5   TR             Gold
# 1             4.0         101    Resort  110.0   TR             Gold
# 2             2.0         102    Resort   95.0   DE           Silver
# 3             NaN         104       NaN    NaN   FR           Bronze
# 4             NaN         105       NaN    NaN   TR             Gold

# %%
# Joining on INDEXES is better than JOINING on COLUMNS
df_rezervasyon.set_index('musteri_id').join(
    df_musteri_profil.set_index('musteri_id'), 
    lsuffix='_rezervasyon', 
    rsuffix='_musteri', 
    how='outer'
)
# Out:
#             rezervasyon_id otel_tipi    adr ulke sadakat_seviyesi
# musteri_id
# 101                    1.0      City  120.5   TR             Gold
# 101                    4.0    Resort  110.0   TR             Gold
# 102                    2.0    Resort   95.0   DE           Silver
# 103                    3.0      City  150.0  NaN              NaN
# 104                    NaN       NaN    NaN   FR           Bronze
# 105                    NaN       NaN    NaN   TR             Gold

# %%
pd.concat([df_rezervasyon,df_musteri_profil], axis=0, join='outer')
# Out:
#    rezervasyon_id  musteri_id otel_tipi    adr ulke sadakat_seviyesi
# 0             1.0         101      City  120.5  NaN              NaN
# 1             2.0         102    Resort   95.0  NaN              NaN
# 2             3.0         103      City  150.0  NaN              NaN
# 3             4.0         101    Resort  110.0  NaN              NaN
# 0             NaN         101       NaN    NaN   TR             Gold
# 1             NaN         102       NaN    NaN   DE           Silver
# 2             NaN         104       NaN    NaN   FR           Bronze
# 3             NaN         105       NaN    NaN   TR             Gold

# %% [markdown]
# -------------------

# %% [markdown]
# ### Null Values

# %%
# Fill missing values with the mean of the column 'money'
cdfs['money'].fillna(cdfs['money'].mean(), inplace=True)
# Out:
# /var/folders/b2/qc1xpbnn1wxdq6xmj3kvxxvw0000gn/T/ipykernel_3634/3229119168.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cdfs['money'].fillna(cdfs['money'].mean(), inplace=True)

# %%
# Fill missing values with interpolated values
# interpolate() is a method in pandas that fills missing values with 
# interpolated values based on the values of the surrounding data points.
cdfs.fillna(cdfs['money'].interpolate(), inplace=True)

# %%
# Subsetting is important for drop na otherwise 
# it will drop all rows if there is a missing value in any column
cdfs.dropna(subset=["money"], inplace=True)

# %%
cdfs[cdfs['money'].notna()].sample(1)
# Out:
#            date     htime cash_type                 card  money coffee_name  \
# 1024 2024-07-24  09:54:37      card  ANON-0000-0000-0402  18.12    Espresso
#
#       month section  typeof_customer milk
# 1024      7   cheap                2   no

# %%
cdfs[cdfs['card'].isna()]
# Out:
#            date     htime cash_type card  money                 coffee_name  \
# 12   2024-03-02  10:30:35      cash  NaN   40.0                       Latte
# 18   2024-03-03  10:10:43      cash  NaN   40.0                       Latte
# 41   2024-03-06  12:30:27      cash  NaN   35.0         Americano with Milk
# 46   2024-03-07  10:08:58      cash  NaN   40.0                       Latte
# 49   2024-03-07  11:25:43      cash  NaN   40.0                       Latte
# ...         ...       ...       ...  ...    ...                         ...
# 3893 2025-03-23  14:55:46      cash  NaN   30.0                  Cappuccino
# 3894 2025-03-23  15:15:36      card  NaN   25.0               Irish whiskey
# 3895 2025-03-23  17:59:25      card  NaN   28.0             Super chocolate
# 3896 2025-03-23  18:01:33      card  NaN   28.0  Vanilla with Irish whiskey
# 3897 2025-03-23  21:23:11      card  NaN   29.0   Coffee with Irish whiskey
#
#       month    section  typeof_customer milk
# 12        3  expensive                1   no
# 18        3  expensive                1   no
# 41        3  expensive                1   no
# 46        3  expensive                1   no
# 49        3  expensive                1   no
# ...     ...        ...              ...  ...
# 3893      3  expensive                1   no
# 3894      3     normal                2   no
# 3895      3     normal                2   no
# 3896      3     normal                2   no
# 3897      3     normal                2   no
#
# [351 rows x 10 columns]

# %% [markdown]
# #### Quick Filtering

# %%
cdfs.loc[
    cdfs['coffee_name'] == 'Americano',
    ['money','cash_type']
    ].count()
# Out:
# money        593
# cash_type    593
# dtype: int64

# %%
cdfs[cdfs['money'] == 25]['coffee_name'].value_counts()
# Out:
# coffee_name
# Americano with milk    44
# Irish whiskey          21
# Americano              15
# Espresso                4
# Caramel with milk       3
# Chocolate               1
# Double chocolate        1
# Name: count, dtype: int64

# %%
cdfs['milk'] = np.where(
    cdfs['coffee_name'].str.contains('with milk', na=False), 
    'yes',
    'no'
    )

# %%
cdfs.loc[:, 'milk'].value_counts()
# Out:
# milk
# no     3822
# yes      76
# Name: count, dtype: int64

# %%
pivot_table = cdfs.pivot_table(
    index='coffee_name',        
    columns='section',  
    values='money',    
    aggfunc='mean'      # If there are multiple values for the 
                        # same index and column, use the mean
)

pivot_table.fillna('Not Sold', inplace=True)
pivot_table
# Out:
# /var/folders/b2/qc1xpbnn1wxdq6xmj3kvxxvw0000gn/T/ipykernel_3634/1135055064.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Sold' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   pivot_table.fillna('Not Sold', inplace=True)
# section                        cheap  expensive     normal
# coffee_name
# Americano                   Not Sold       30.0  25.991925
# Americano with Milk         Not Sold  31.679203      27.92
# Americano with milk         Not Sold   Not Sold       25.0
# Cappuccino                  Not Sold  35.810716   Not Sold
# Caramel                     Not Sold   Not Sold       22.0
# Caramel coffee              Not Sold   Not Sold       28.0
# Caramel with Irish whiskey  Not Sold   Not Sold       28.0
# Caramel with chocolate      Not Sold   Not Sold       28.0
# Caramel with milk           Not Sold   Not Sold       25.0
# Chocolate                   Not Sold   Not Sold       25.0
# Chocolate with coffee       Not Sold       30.0   Not Sold
# Chocolate with milk         Not Sold   Not Sold       27.0
# Cocoa                       Not Sold  35.712593   Not Sold
# Coffee with Irish whiskey   Not Sold   Not Sold       29.0
# Coffee with chocolate       Not Sold   Not Sold       28.0
# Cortado                     Not Sold       30.0   25.73122
# Double Irish whiskey        Not Sold   Not Sold       28.0
# Double chocolate            Not Sold   Not Sold       25.0
# Double espresso             Not Sold   Not Sold       27.0
# Double espresso with milk   Not Sold       32.0   Not Sold
# Double ristretto            Not Sold   Not Sold       27.0
# Double vanilla              Not Sold   Not Sold       23.5
# Espresso                       18.12       33.0  21.756174
# Hot Chocolate               Not Sold  36.072553   Not Sold
# Hot milkshake               Not Sold       30.0   Not Sold
# Irish whiskey               Not Sold   Not Sold       25.0
# Irish whiskey with milk     Not Sold   Not Sold       27.0
# Irish with chocolate        Not Sold   Not Sold       27.0
# Latte                       Not Sold  35.556203   Not Sold
# Mochaccino                  Not Sold       30.0   Not Sold
# Super chocolate             Not Sold   Not Sold       28.0
# Tea                             15.0   Not Sold   Not Sold
# Vanilla coffee              Not Sold   Not Sold       27.0
# Vanilla with Irish whiskey  Not Sold   Not Sold       28.0

# %%
cdfs_day = cdfs['date'].dt.day

# %%
cdfs['day'] = cdfs['date'].dt.day

# %%
cdfs['year'] = cdfs['date'].dt.year

# %% [markdown]
# ### Numpy and Pandas

# %% [markdown]
# * np.where() - if else (condition, value if true, value if false)
# * np.select() - if elif else (list of conditions, list of values and default value)
#
#
# * mapping : a = {0: 'zero', 1: 'one', 2: 'two'} | df['column'].map(a)
# * np.log(df['column']), np.exp(df['column']), np.sqrt(df['column'])

# %% [markdown]
# ### NaN Values - Masking

# %% [markdown]
# Conditional :
# * a = (df['column_name'].isna()) & (df['column_name2'] == 'value')
#
# * Debugging : missing_all_values = df['column_name'].isna().any(axis=1)
#
# * Targeted Modification : df.loc[a, 'column_name'] = 'value'

# %% [markdown]
# ---------

# %% [markdown]
# .shift(), .rank(), .rolling(), .cumsum(), .diff()

# %%
cdfs['money'].diff(1)
# Out:
# 0       NaN
# 1       0.0
# 2       0.0
# 3      -9.8
# 4       9.8
#        ...
# 3893    5.0
# 3894   -5.0
# 3895    3.0
# 3896    0.0
# 3897    1.0
# Name: money, Length: 3898, dtype: float64

# %%
a = cdfs.groupby(['month','day','coffee_name', 'year']).agg({
    'money':'sum'}).reset_index()

# %%
for a1 in range(1, 12):
  aylık_toplam = a.loc[(a['month'] == a1) & (a['year'] == 2024)]
  toplam_sat = aylık_toplam['money'].sum()
  print(f"{a1}. ay toplam satış: {toplam_sat}")
# Out:
# 1. ay toplam satış: 0.0
# 2. ay toplam satış: 0.0
# 3. ay toplam satış: 7050.2
# 4. ay toplam satış: 6720.5599999999995
# 5. ay toplam satış: 9063.42
# 6. ay toplam satış: 7758.76
# 7. ay toplam satış: 6915.9400000000005
# 8. ay toplam satış: 7613.84
# 9. ay toplam satış: 9988.64
# 10. ay toplam satış: 13891.159999999998
# 11. ay toplam satış: 8590.54

# %%
c = cdfs.groupby(['year', 'month']).agg({'money':'mean'}).reset_index()

# %%
aylar = list(range(1,12))
c[(c['year'] == 2024)&(c['month'].isin(aylar))].sum()
# Out:
# year     18216.000000
# month       63.000000
# money      288.624245
# dtype: float64

# %%
cdfs.select_dtypes(include=['float64']).cumsum()
# Out:
#           money
# 0         38.70
# 1         77.40
# 2        116.10
# 3        145.00
# 4        183.70
# ...         ...
# 3893  122211.58
# 3894  122236.58
# 3895  122264.58
# 3896  122292.58
# 3897  122321.58
#
# [3898 rows x 1 columns]
