# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Coffee 2025-2024 Performance Analysis

# %%
cdf = pd.read_csv('index_1.csv')
cdf2 = pd.read_csv('index_2.csv')

# %%
cdfs =pd.concat([cdf, cdf2], axis=0)

# %%
cdfs['date'] = pd.to_datetime(cdfs['date'])
cdfs['time'] = cdfs['datetime'].str.split(' ').str[1]
cdfs['ztime'] = cdfs['time'].str.split('.').str[0]
cdfs.drop('datetime', axis=1, inplace=True)
cdfs.drop('time', axis=1, inplace=True)

# %%
cdfst = cdfs['ztime']
cdfs.insert(1,'htime',cdfst)
cdfs.drop('ztime', axis=1, inplace=True)

# %%
cdfs.loc[:,'date':'card'] #Rows,Columns
# Out:
#           date     htime cash_type                 card
# 0   2024-03-01  10:15:50      card  ANON-0000-0000-0001
# 1   2024-03-01  12:19:22      card  ANON-0000-0000-0002
# 2   2024-03-01  12:20:18      card  ANON-0000-0000-0002
# 3   2024-03-01  13:46:33      card  ANON-0000-0000-0003
# 4   2024-03-01  13:48:14      card  ANON-0000-0000-0004
# ..         ...       ...       ...                  ...
# 257 2025-03-23  14:55:46      cash                  NaN
# 258 2025-03-23  15:15:36      card                  NaN
# 259 2025-03-23  17:59:25      card                  NaN
# 260 2025-03-23  18:01:33      card                  NaN
# 261 2025-03-23  21:23:11      card                  NaN
#
# [3898 rows x 4 columns]

# %%
cdfs.loc[:,['date','money','cash_type']].groupby(
    ['date','cash_type']).sum()
# Out:
#                        money
# date       cash_type
# 2024-03-01 card       396.30
# 2024-03-02 card       188.10
#            cash        40.00
# 2024-03-03 card       309.10
#            cash        40.00
# ...                      ...
# 2025-03-21 card       741.80
# 2025-03-22 card       566.42
#            cash        47.00
# 2025-03-23 card       314.76
#            cash       105.00
#
# [470 rows x 1 columns]

# %%
cdfs.loc[:,['coffee_name','money']].groupby(
    'coffee_name').agg(
        {'money':'sum','coffee_name':'count'})
# Out:
#                                money  coffee_name
# coffee_name
# Americano                   15437.26          593
# Americano with Milk         25269.12          824
# Americano with milk          1100.00           44
# Cappuccino                  18514.14          517
# Caramel                        22.00            1
# Caramel coffee                 56.00            2
# Caramel with Irish whiskey    224.00            8
# Caramel with chocolate        112.00            4
# Caramel with milk              75.00            3
# Chocolate                      25.00            1
# Chocolate with coffee         150.00            5
# Chocolate with milk           324.00           12
# Cocoa                        8678.16          243
# Coffee with Irish whiskey     464.00           16
# Coffee with chocolate          28.00            1
# Cortado                      7534.86          292
# Double Irish whiskey          336.00           12
# Double chocolate               25.00            1
# Double espresso                27.00            1
# Double espresso with milk      64.00            2
# Double ristretto               27.00            1
# Double vanilla                 47.00            2
# Espresso                     3187.28          152
# Hot Chocolate               10172.46          282
# Hot milkshake                  30.00            1
# Irish whiskey                 525.00           21
# Irish whiskey with milk       405.00           15
# Irish with chocolate          135.00            5
# Latte                       28658.30          806
# Mochaccino                    150.00            5
# Super chocolate               168.00            6
# Tea                           240.00           16
# Vanilla coffee                 27.00            1
# Vanilla with Irish whiskey     84.00            3

# %%
cdfs['month'] = cdfs['date'].dt.month

# %%
cdfs.index = cdfs['month']
# Resetted index as month

# %%
cdfs.loc[3, ['coffee_name', 'money']].sum()
# Give me the coffee_name and money records of the 
# 3rd of the months
# Out:
# coffee_name    LatteHot ChocolateHot ChocolateAmericanoLatteA...
# money                                                   20337.64
# dtype: object

# %%
cdfs[cdfs['coffee_name'].str.contains(
    '^A.*o$')].count() #Total count of americanos
# Out:
# date           593
# htime          593
# cash_type      593
# card           564
# money          593
# coffee_name    593
# month          593
# dtype: int64

# %%
cdfs[cdfs['cash_type'].isin(['card']) & 
(cdfs['coffee_name'].str.contains('Americano')) &
(cdfs['money'] >= 33 ) &
(cdfs['cash_type'] == 'card')
].count() # Americanos which are paid with card and cost more than 33
# Out:
# date           51
# htime          51
# cash_type      51
# card           51
# money          51
# coffee_name    51
# month          51
# dtype: int64

# %%
cdfs.query('coffee_name == "Espresso"'
 and 'cash_type == "card"')
# Out:
#             date     htime cash_type                 card  money  \
# month
# 3     2024-03-01  10:15:50      card  ANON-0000-0000-0001   38.7
# 3     2024-03-01  12:19:22      card  ANON-0000-0000-0002   38.7
# 3     2024-03-01  12:20:18      card  ANON-0000-0000-0002   38.7
# 3     2024-03-01  13:46:33      card  ANON-0000-0000-0003   28.9
# 3     2024-03-01  13:48:14      card  ANON-0000-0000-0004   38.7
# ...          ...       ...       ...                  ...    ...
# 3     2025-03-22  22:23:39      card                  NaN   29.0
# 3     2025-03-23  15:15:36      card                  NaN   25.0
# 3     2025-03-23  17:59:25      card                  NaN   28.0
# 3     2025-03-23  18:01:33      card                  NaN   28.0
# 3     2025-03-23  21:23:11      card                  NaN   29.0
#
#                       coffee_name  month
# month
# 3                           Latte      3
# 3                   Hot Chocolate      3
# 3                   Hot Chocolate      3
# 3                       Americano      3
# 3                           Latte      3
# ...                           ...    ...
# 3       Coffee with Irish whiskey      3
# 3                   Irish whiskey      3
# 3                 Super chocolate      3
# 3      Vanilla with Irish whiskey      3
# 3       Coffee with Irish whiskey      3
#
# [3729 rows x 7 columns]

# %%
sorti_col = [('money','sum'),
            ('coffee_name','count')]
order = [True,False]

cdfs_monthly = cdfs.loc[(cdfs['date'].dt.year == 2024) &
(cdfs['date'].dt.month == 5) &
(cdfs['money'] > 1)].groupby('coffee_name').agg(
    {'money': ['sum','median'],
    'coffee_name': 'count'}).sort_values(
        by=sorti_col, ascending=order)
cdfs_monthly.columns = ['_'.join(column).strip() for 
column in cdfs_monthly.columns]
cdfs_monthly
# Out:
#                      money_sum  money_median  coffee_name_count
# coffee_name
# Espresso                185.14         23.02                  8
# Cocoa                   340.76         37.72                  9
# Cortado                 474.64         27.92                 17
# Hot Chocolate           529.36         37.72                 14
# Americano              1348.80         27.92                 48
# Americano with Milk    1908.28         32.82                 58
# Cappuccino             2078.44         37.72                 55
# Latte                  2198.00         37.72                 58

# %%
cdfs.isnull().sum()
# Out:
# date             0
# htime            0
# cash_type        0
# card           351
# money            0
# coffee_name      0
# month            0
# dtype: int64

# %%
# Creating a mask for NaN values
cdfs_nan_mask = cdfs.isna().any(axis=1)
cdfs_nan = cdfs.loc[cdfs_nan_mask]

# %%
cdfs_nan.drop('card', axis=1, inplace=True)
# Out:
# /var/folders/b2/qc1xpbnn1wxdq6xmj3kvxxvw0000gn/T/ipykernel_19122/188055965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdfs_nan.drop('card', axis=1, inplace=True)

# %%
# Dividing them into card and cash payments 
cdfs_card = cdfs_nan[cdfs_nan['cash_type'] == 'card']
cdfs_cash = cdfs_nan[cdfs_nan['cash_type'] == 'cash']

# %%
cdfs_card.groupby('coffee_name')['money'].agg(
    {'sum', 'median','count'}).sort_values('count', ascending=False)
# Out:
#                             count  median    sum
# coffee_name
# Americano with milk            28    25.0  700.0
# Latte                          20    33.0  660.0
# Irish whiskey                  16    25.0  400.0
# Coffee with Irish whiskey      13    29.0  377.0
# Irish whiskey with milk        12    27.0  324.0
# Cappuccino                     11    30.0  330.0
# Tea                            10    15.0  150.0
# Double Irish whiskey           10    28.0  280.0
# Espresso                        9    20.0  193.0
# Americano                       9    25.0  225.0
# Caramel with Irish whiskey      8    28.0  224.0
# Chocolate with milk             5    27.0  135.0
# Irish with chocolate            5    27.0  135.0
# Super chocolate                 4    28.0  112.0
# Caramel with chocolate          4    28.0  112.0
# Chocolate with coffee           3    30.0   90.0
# Mochaccino                      2    30.0   60.0
# Vanilla with Irish whiskey      2    28.0   56.0
# Double espresso with milk       2    32.0   64.0
# Caramel with milk               2    25.0   50.0
# Caramel coffee                  2    28.0   56.0
# Hot milkshake                   1    30.0   30.0
# Double vanilla                  1    27.0   27.0
# Chocolate                       1    25.0   25.0
# Vanilla coffee                  1    27.0   27.0
# Double ristretto                1    27.0   27.0

# %%
cdfs_cash_grouped_year = cdfs_cash.groupby(['coffee_name',
cdfs_cash['date'].dt.year])['money'].agg(['median','sum','count'])
###
cdfs_card_grouped_year = cdfs_card.groupby(['coffee_name',
cdfs_card['date'].dt.year])['money'].agg(['median','sum','count'])

# %%
cdfs_cash_grouped_year.loc[('Americano',2024),:]
# Out:
# median     29.0
# sum       412.0
# count      14.0
# Name: (Americano, 2024), dtype: float64

# %%
cdfs_cash_grouped_month = cdfs_cash.groupby(['coffee_name',
cdfs_cash['date'].dt.month])['money'].agg(['median','sum','count'])
########
cdfs_card_grouped_month = cdfs_card.groupby(['coffee_name',
cdfs_card['date'].dt.month])['money'].agg(['median','sum','count'])

# %%
a = cdfs.groupby(['coffee_name', 
cdfs['date'].dt.month, 'money']).agg(
    {'coffee_name': 'count', 'money': 'sum'})

# %%
# indexing on groupby objects
a.loc[('Americano',2),:]
# Out:
#        coffee_name    money
# money
# 25.00            7   175.00
# 25.96          117  3037.32

# %%
# First sorting by money then if money is same for different dates,
# sorting by date with ascending order    
cdfs.sort_values(by = ['money','date'], 
ascending=True)
# Out:
#             date     htime cash_type card  money    coffee_name  month
# month
# 2     2025-02-08  14:26:04      cash  NaN   15.0            Tea      2
# 2     2025-02-08  14:28:26      cash  NaN   15.0            Tea      2
# 2     2025-02-09  18:01:22      card  NaN   15.0            Tea      2
# 2     2025-02-11  09:49:22      card  NaN   15.0            Tea      2
# 2     2025-02-15  15:33:24      card  NaN   15.0            Tea      2
# ...          ...       ...       ...  ...    ...            ...    ...
# 4     2024-04-10  17:55:07      cash  NaN   40.0  Hot Chocolate      4
# 4     2024-04-13  15:06:52      cash  NaN   40.0  Hot Chocolate      4
# 4     2024-04-13  15:07:55      cash  NaN   40.0  Hot Chocolate      4
# 4     2024-04-14  10:55:27      cash  NaN   40.0          Latte      4
# 4     2024-04-17  16:13:24      cash  NaN   40.0     Cappuccino      4
#
# [3898 rows x 7 columns]

# %%
cdfs.sort_values(by = ['money','date'], 
ascending=[False, True])
# Money is descending, date is ascending order sorted
# Out:
#             date     htime cash_type card  money    coffee_name  month
# month
# 3     2024-03-02  10:30:35      cash  NaN   40.0          Latte      3
# 3     2024-03-03  10:10:43      cash  NaN   40.0          Latte      3
# 3     2024-03-07  10:08:58      cash  NaN   40.0          Latte      3
# 3     2024-03-07  11:25:43      cash  NaN   40.0          Latte      3
# 3     2024-03-09  11:49:37      cash  NaN   40.0  Hot Chocolate      3
# ...          ...       ...       ...  ...    ...            ...    ...
# 2     2025-02-26  12:22:20      card  NaN   15.0            Tea      2
# 2     2025-02-27  17:04:29      cash  NaN   15.0            Tea      2
# 3     2025-03-01  12:48:46      cash  NaN   15.0            Tea      3
# 3     2025-03-15  13:12:26      card  NaN   15.0            Tea      3
# 3     2025-03-22  16:59:05      card  NaN   15.0            Tea      3
#
# [3898 rows x 7 columns]

# %%
# Iterating over rows by index 
# also can navigate by column name in the loop
for index, row in cdfs.iterrows():
    print(index)
    print(row.iloc[5]) # or row['column_name']
    print("\n")
# Out:
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Cocoa
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Cortado
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cocoa
#
#
# 3
# Cortado
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Hot Chocolate
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Espresso
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cocoa
#
#
# 3
# Hot Chocolate
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cortado
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Cortado
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Cortado
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Espresso
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Cortado
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with Milk
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cappuccino
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Espresso
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Cortado
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Cortado
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Cortado
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Cortado
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Espresso
#
#
# 3
# Americano with Milk
#
#
# 3
# Espresso
#
#
# 3
# Espresso
#
#
# 3
# Espresso
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cortado
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Espresso
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Espresso
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cortado
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Cortado
#
#
# 3
# Cortado
#
#
# 3
# Cortado
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Cortado
#
#
# 3
# Cortado
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cortado
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cortado
#
#
# 3
# Latte
#
#
# 3
# Cortado
#
#
# 3
# Cappuccino
#
#
# 3
# Cocoa
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Cortado
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Cortado
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Espresso
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Cocoa
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Cortado
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Cocoa
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Cortado
#
#
# 3
# Americano
#
#
# 3
# Cortado
#
#
# 3
# Cortado
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cortado
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Cortado
#
#
# 3
# Latte
#
#
# 3
# Cortado
#
#
# 3
# Cortado
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 4
# Americano
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Americano with Milk
#
#
# 4
# Hot Chocolate
#
#
# 4
# Latte
#
#
# 4
# Americano
#
#
# 4
# Cortado
#
#
# 4
# Cappuccino
#
#
# 4
# Cortado
#
#
# 4
# Americano
#
#
# 4
# Cappuccino
#
#
# 4
# Cortado
#
#
# 4
# Latte
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Cortado
#
#
# 4
# Latte
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Cortado
#
#
# 4
# Americano with Milk
#
#
# 4
# Latte
#
#
# 4
# Cortado
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Cocoa
#
#
# 4
# Espresso
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Latte
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Cortado
#
#
# 4
# Espresso
#
#
# 4
# Hot Chocolate
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Cappuccino
#
#
# 4
# Espresso
#
#
# 4
# Americano with Milk
#
#
# 4
# Latte
#
#
# 4
# Americano
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Latte
#
#
# 4
# Hot Chocolate
#
#
# 4
# Hot Chocolate
#
#
# 4
# Espresso
#
#
# 4
# Hot Chocolate
#
#
# 4
# Espresso
#
#
# 4
# Cappuccino
#
#
# 4
# Latte
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Americano with Milk
#
#
# 4
# Hot Chocolate
#
#
# 4
# Cortado
#
#
# 4
# Latte
#
#
# 4
# Americano
#
#
# 4
# Hot Chocolate
#
#
# 4
# Hot Chocolate
#
#
# 4
# Cappuccino
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Cortado
#
#
# 4
# Cortado
#
#
# 4
# Americano with Milk
#
#
# 4
# Cortado
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Cappuccino
#
#
# 4
# Cortado
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Espresso
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Cocoa
#
#
# 4
# Cortado
#
#
# 4
# Americano
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Cocoa
#
#
# 4
# Americano
#
#
# 4
# Espresso
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Cortado
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Americano with Milk
#
#
# 4
# Cortado
#
#
# 4
# Cappuccino
#
#
# 4
# Latte
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Hot Chocolate
#
#
# 4
# Hot Chocolate
#
#
# 4
# Latte
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Hot Chocolate
#
#
# 4
# Cappuccino
#
#
# 4
# Cocoa
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano
#
#
# 4
# Americano with Milk
#
#
# 4
# Hot Chocolate
#
#
# 4
# Cappuccino
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Cocoa
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Latte
#
#
# 4
# Latte
#
#
# 4
# Americano
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Americano with Milk
#
#
# 4
# Latte
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Latte
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Latte
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Latte
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Cortado
#
#
# 4
# Americano
#
#
# 4
# Hot Chocolate
#
#
# 4
# Cocoa
#
#
# 4
# Cappuccino
#
#
# 4
# Latte
#
#
# 4
# Cappuccino
#
#
# 4
# Americano
#
#
# 4
# Americano
#
#
# 4
# Latte
#
#
# 4
# Cortado
#
#
# 4
# Americano
#
#
# 4
# Cortado
#
#
# 4
# Cortado
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Cappuccino
#
#
# 4
# Latte
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano with Milk
#
#
# 4
# Americano
#
#
# 4
# Americano with Milk
#
#
# 4
# Cappuccino
#
#
# 4
# Americano with Milk
#
#
# 4
# Latte
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Americano
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Cortado
#
#
# 5
# Americano
#
#
# 5
# Cortado
#
#
# 5
# Americano
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Cocoa
#
#
# 5
# Cortado
#
#
# 5
# Cortado
#
#
# 5
# Cocoa
#
#
# 5
# Americano
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Cocoa
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Hot Chocolate
#
#
# 5
# Latte
#
#
# 5
# Espresso
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Cortado
#
#
# 5
# Cortado
#
#
# 5
# Espresso
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Hot Chocolate
#
#
# 5
# Latte
#
#
# 5
# Hot Chocolate
#
#
# 5
# Latte
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Cappuccino
#
#
# 5
# Espresso
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Espresso
#
#
# 5
# Hot Chocolate
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Cocoa
#
#
# 5
# Cortado
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Cocoa
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Espresso
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Cortado
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Hot Chocolate
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Espresso
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Cortado
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Hot Chocolate
#
#
# 5
# Cortado
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Hot Chocolate
#
#
# 5
# Cortado
#
#
# 5
# Cortado
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Cortado
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Hot Chocolate
#
#
# 5
# Hot Chocolate
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Hot Chocolate
#
#
# 5
# Cappuccino
#
#
# 5
# Cortado
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Americano
#
#
# 5
# Americano with Milk
#
#
# 5
# Cocoa
#
#
# 5
# Americano
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Cappuccino
#
#
# 5
# Cappuccino
#
#
# 5
# Cocoa
#
#
# 5
# Cortado
#
#
# 5
# Cappuccino
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Hot Chocolate
#
#
# 5
# Americano
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Cortado
#
#
# 5
# Latte
#
#
# 5
# Hot Chocolate
#
#
# 5
# Cocoa
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Americano with Milk
#
#
# 5
# Espresso
#
#
# 5
# Espresso
#
#
# 5
# Cappuccino
#
#
# 5
# Latte
#
#
# 5
# Hot Chocolate
#
#
# 5
# Americano with Milk
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Hot Chocolate
#
#
# 5
# Cocoa
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Latte
#
#
# 5
# Cappuccino
#
#
# 5
# Americano with Milk
#
#
# 5
# Cortado
#
#
# 6
# Cortado
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Cocoa
#
#
# 6
# Cocoa
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Cortado
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Hot Chocolate
#
#
# 6
# Latte
#
#
# 6
# Cortado
#
#
# 6
# Cappuccino
#
#
# 6
# Hot Chocolate
#
#
# 6
# Cappuccino
#
#
# 6
# Cortado
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Americano
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Cocoa
#
#
# 6
# Cortado
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Americano
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Espresso
#
#
# 6
# Americano with Milk
#
#
# 6
# Cortado
#
#
# 6
# Cortado
#
#
# 6
# Cortado
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Cortado
#
#
# 6
# Espresso
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Cortado
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Hot Chocolate
#
#
# 6
# Hot Chocolate
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Hot Chocolate
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Hot Chocolate
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Hot Chocolate
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Cortado
#
#
# 6
# Americano with Milk
#
#
# 6
# Hot Chocolate
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Espresso
#
#
# 6
# Espresso
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Cortado
#
#
# 6
# Americano
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Espresso
#
#
# 6
# Cocoa
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Hot Chocolate
#
#
# 6
# Hot Chocolate
#
#
# 6
# Americano with Milk
#
#
# 6
# Espresso
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Hot Chocolate
#
#
# 6
# Hot Chocolate
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano
#
#
# 6
# Cortado
#
#
# 6
# Cortado
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Americano
#
#
# 6
# Americano
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Cortado
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Cortado
#
#
# 6
# Americano
#
#
# 6
# Latte
#
#
# 6
# Cocoa
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Americano
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Espresso
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Americano
#
#
# 6
# Americano with Milk
#
#
# 6
# Cortado
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Latte
#
#
# 6
# Espresso
#
#
# 6
# Americano
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Cortado
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Cortado
#
#
# 6
# Espresso
#
#
# 6
# Americano with Milk
#
#
# 6
# Latte
#
#
# 6
# Cappuccino
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Americano with Milk
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Cappuccino
#
#
# 6
# Hot Chocolate
#
#
# 6
# Latte
#
#
# 6
# Latte
#
#
# 6
# Espresso
#
#
# 6
# Hot Chocolate
#
#
# 6
# Americano with Milk
#
#
# 7
# Espresso
#
#
# 7
# Cappuccino
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Cappuccino
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Espresso
#
#
# 7
# Cappuccino
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano
#
#
# 7
# Cocoa
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Espresso
#
#
# 7
# Americano
#
#
# 7
# Espresso
#
#
# 7
# Americano
#
#
# 7
# Americano
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Cappuccino
#
#
# 7
# Cappuccino
#
#
# 7
# Hot Chocolate
#
#
# 7
# Cocoa
#
#
# 7
# Latte
#
#
# 7
# Cappuccino
#
#
# 7
# Hot Chocolate
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Hot Chocolate
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Cortado
#
#
# 7
# Hot Chocolate
#
#
# 7
# Hot Chocolate
#
#
# 7
# Hot Chocolate
#
#
# 7
# Hot Chocolate
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Cappuccino
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Latte
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Hot Chocolate
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Espresso
#
#
# 7
# Americano
#
#
# 7
# Americano
#
#
# 7
# Cortado
#
#
# 7
# Latte
#
#
# 7
# Cappuccino
#
#
# 7
# Latte
#
#
# 7
# Hot Chocolate
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Cocoa
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Latte
#
#
# 7
# Cocoa
#
#
# 7
# Cappuccino
#
#
# 7
# Cortado
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Cocoa
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Espresso
#
#
# 7
# Cappuccino
#
#
# 7
# Latte
#
#
# 7
# Espresso
#
#
# 7
# Latte
#
#
# 7
# Cappuccino
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano
#
#
# 7
# Americano
#
#
# 7
# Americano
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano
#
#
# 7
# Cappuccino
#
#
# 7
# Cappuccino
#
#
# 7
# Cortado
#
#
# 7
# Espresso
#
#
# 7
# Cortado
#
#
# 7
# Cocoa
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Espresso
#
#
# 7
# Cortado
#
#
# 7
# Cortado
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Cappuccino
#
#
# 7
# Cappuccino
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Cappuccino
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Espresso
#
#
# 7
# Americano with Milk
#
#
# 7
# Espresso
#
#
# 7
# Latte
#
#
# 7
# Cappuccino
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Cappuccino
#
#
# 7
# Espresso
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Cappuccino
#
#
# 7
# Hot Chocolate
#
#
# 7
# Hot Chocolate
#
#
# 7
# Cappuccino
#
#
# 7
# Americano
#
#
# 7
# Cocoa
#
#
# 7
# Americano with Milk
#
#
# 7
# Cortado
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Cortado
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Espresso
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Cortado
#
#
# 7
# Americano with Milk
#
#
# 7
# Espresso
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Americano
#
#
# 7
# Cappuccino
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano with Milk
#
#
# 7
# Americano
#
#
# 7
# Americano
#
#
# 7
# Americano with Milk
#
#
# 7
# Cocoa
#
#
# 7
# Latte
#
#
# 7
# Americano with Milk
#
#
# 7
# Cortado
#
#
# 7
# Latte
#
#
# 7
# Cortado
#
#
# 7
# Latte
#
#
# 7
# Cocoa
#
#
# 7
# Cortado
#
#
# 7
# Latte
#
#
# 7
# Cappuccino
#
#
# 7
# Cortado
#
#
# 7
# Americano with Milk
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 7
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Cappuccino
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Cortado
#
#
# 8
# Espresso
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Cappuccino
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Cappuccino
#
#
# 8
# Cappuccino
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Cappuccino
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Cocoa
#
#
# 8
# Cocoa
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Hot Chocolate
#
#
# 8
# Cappuccino
#
#
# 8
# Latte
#
#
# 8
# Cocoa
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Espresso
#
#
# 8
# Americano
#
#
# 8
# Latte
#
#
# 8
# Cocoa
#
#
# 8
# Cappuccino
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Espresso
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Cortado
#
#
# 8
# Cappuccino
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Americano
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Hot Chocolate
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Cortado
#
#
# 8
# Americano
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Cocoa
#
#
# 8
# Cocoa
#
#
# 8
# Cocoa
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Cocoa
#
#
# 8
# Cappuccino
#
#
# 8
# Espresso
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Hot Chocolate
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Espresso
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Cocoa
#
#
# 8
# Cappuccino
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Cortado
#
#
# 8
# Espresso
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Latte
#
#
# 8
# Americano
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Cortado
#
#
# 8
# Cappuccino
#
#
# 8
# Hot Chocolate
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Americano
#
#
# 8
# Espresso
#
#
# 8
# Americano with Milk
#
#
# 8
# Hot Chocolate
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano
#
#
# 8
# Cappuccino
#
#
# 8
# Espresso
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Americano
#
#
# 8
# Americano with Milk
#
#
# 8
# Espresso
#
#
# 8
# Espresso
#
#
# 8
# Americano with Milk
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Cappuccino
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Cappuccino
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Cocoa
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Espresso
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Americano
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Americano
#
#
# 8
# Latte
#
#
# 8
# Cortado
#
#
# 8
# Latte
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Americano with Milk
#
#
# 8
# Cocoa
#
#
# 8
# Americano
#
#
# 8
# Cortado
#
#
# 8
# Hot Chocolate
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Latte
#
#
# 8
# Cortado
#
#
# 8
# Cortado
#
#
# 8
# Cortado
#
#
# 8
# Espresso
#
#
# 8
# Espresso
#
#
# 8
# Americano
#
#
# 8
# Cortado
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Cappuccino
#
#
# 8
# Cappuccino
#
#
# 8
# Latte
#
#
# 8
# Cortado
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Cappuccino
#
#
# 8
# Americano
#
#
# 8
# Americano
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Cappuccino
#
#
# 8
# Americano
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano
#
#
# 8
# Latte
#
#
# 8
# Americano with Milk
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Americano with Milk
#
#
# 8
# Espresso
#
#
# 8
# Americano with Milk
#
#
# 8
# Cortado
#
#
# 8
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Cocoa
#
#
# 9
# Americano
#
#
# 9
# Americano
#
#
# 9
# Cocoa
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Cocoa
#
#
# 9
# Cocoa
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Cocoa
#
#
# 9
# Cortado
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Americano
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Espresso
#
#
# 9
# Latte
#
#
# 9
# Hot Chocolate
#
#
# 9
# Espresso
#
#
# 9
# Espresso
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Americano
#
#
# 9
# Espresso
#
#
# 9
# Espresso
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano
#
#
# 9
# Espresso
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Espresso
#
#
# 9
# Cocoa
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Americano
#
#
# 9
# Latte
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Hot Chocolate
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Espresso
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Hot Chocolate
#
#
# 9
# Cappuccino
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cortado
#
#
# 9
# Espresso
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Cappuccino
#
#
# 9
# Cortado
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Espresso
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Espresso
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Hot Chocolate
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Hot Chocolate
#
#
# 9
# Hot Chocolate
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Cocoa
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Americano
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano
#
#
# 9
# Americano
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Cocoa
#
#
# 9
# Latte
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Hot Chocolate
#
#
# 9
# Hot Chocolate
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Americano
#
#
# 9
# Latte
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cortado
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Americano
#
#
# 9
# Americano
#
#
# 9
# Hot Chocolate
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Cortado
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Espresso
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cortado
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Americano
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cappuccino
#
#
# 9
# Cocoa
#
#
# 9
# Cortado
#
#
# 9
# Hot Chocolate
#
#
# 9
# Americano
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Cappuccino
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Cortado
#
#
# 9
# Latte
#
#
# 9
# Latte
#
#
# 9
# Cappuccino
#
#
# 9
# Latte
#
#
# 9
# Cortado
#
#
# 9
# Cortado
#
#
# 9
# Hot Chocolate
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Cortado
#
#
# 9
# Latte
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 9
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Cortado
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Cappuccino
#
#
# 10
# Cappuccino
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cocoa
#
#
# 10
# Americano with Milk
#
#
# 10
# Cortado
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cappuccino
#
#
# 10
# Hot Chocolate
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano
#
#
# 10
# Cortado
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cocoa
#
#
# 10
# Cortado
#
#
# 10
# Cortado
#
#
# 10
# Cocoa
#
#
# 10
# Cappuccino
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Cortado
#
#
# 10
# Cappuccino
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano
#
#
# 10
# Cappuccino
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Cappuccino
#
#
# 10
# Espresso
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Cocoa
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Espresso
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Cappuccino
#
#
# 10
# Americano
#
#
# 10
# Espresso
#
#
# 10
# Cappuccino
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Cortado
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Americano with Milk
#
#
# 10
# Cortado
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Cocoa
#
#
# 10
# Americano
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cortado
#
#
# 10
# Cortado
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Cortado
#
#
# 10
# Americano with Milk
#
#
# 10
# Cortado
#
#
# 10
# Espresso
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Cappuccino
#
#
# 10
# Americano with Milk
#
#
# 10
# Cocoa
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Cortado
#
#
# 10
# Espresso
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Espresso
#
#
# 10
# Hot Chocolate
#
#
# 10
# Americano
#
#
# 10
# Cocoa
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cappuccino
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Cappuccino
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Cocoa
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Cocoa
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cortado
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cortado
#
#
# 10
# Cocoa
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Cortado
#
#
# 10
# Cortado
#
#
# 10
# Espresso
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Cortado
#
#
# 10
# Cocoa
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Cocoa
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Americano with Milk
#
#
# 10
# Cortado
#
#
# 10
# Espresso
#
#
# 10
# Cortado
#
#
# 10
# Americano
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Cortado
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Cappuccino
#
#
# 10
# Espresso
#
#
# 10
# Cocoa
#
#
# 10
# Cappuccino
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Cappuccino
#
#
# 10
# Cappuccino
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cappuccino
#
#
# 10
# Cappuccino
#
#
# 10
# Espresso
#
#
# 10
# Cocoa
#
#
# 10
# Latte
#
#
# 10
# Cocoa
#
#
# 10
# Americano
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Hot Chocolate
#
#
# 10
# Espresso
#
#
# 10
# Cappuccino
#
#
# 10
# Cortado
#
#
# 10
# Cappuccino
#
#
# 10
# Americano
#
#
# 10
# Cocoa
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Cortado
#
#
# 10
# Cortado
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Cappuccino
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Cappuccino
#
#
# 10
# Latte
#
#
# 10
# Cappuccino
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Hot Chocolate
#
#
# 10
# Americano with Milk
#
#
# 10
# Cappuccino
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Cappuccino
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Espresso
#
#
# 10
# Cortado
#
#
# 10
# Cortado
#
#
# 10
# Cappuccino
#
#
# 10
# Hot Chocolate
#
#
# 10
# Cocoa
#
#
# 10
# Cocoa
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Cappuccino
#
#
# 10
# Hot Chocolate
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Hot Chocolate
#
#
# 10
# Americano with Milk
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 10
# Latte
#
#
# 10
# Americano with Milk
#
#
# 11
# Cocoa
#
#
# 11
# Americano
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Cortado
#
#
# 11
# Americano with Milk
#
#
# 11
# Cortado
#
#
# 11
# Cocoa
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano
#
#
# 11
# Cortado
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Cocoa
#
#
# 11
# Americano
#
#
# 11
# Americano with Milk
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Americano
#
#
# 11
# Americano
#
#
# 11
# Cocoa
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano
#
#
# 11
# Americano with Milk
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Americano with Milk
#
#
# 11
# Cappuccino
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Cocoa
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Cappuccino
#
#
# 11
# Cappuccino
#
#
# 11
# Cappuccino
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Espresso
#
#
# 11
# Americano
#
#
# 11
# Cappuccino
#
#
# 11
# Latte
#
#
# 11
# Cappuccino
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Americano
#
#
# 11
# Americano
#
#
# 11
# Cocoa
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano
#
#
# 11
# Americano
#
#
# 11
# Cappuccino
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Cortado
#
#
# 11
# Cortado
#
#
# 11
# Latte
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Americano
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Americano
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Americano
#
#
# 11
# Americano
#
#
# 11
# Americano
#
#
# 11
# Cocoa
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Cappuccino
#
#
# 11
# Cappuccino
#
#
# 11
# Cappuccino
#
#
# 11
# Americano with Milk
#
#
# 11
# Cortado
#
#
# 11
# Cappuccino
#
#
# 11
# Hot Chocolate
#
#
# 11
# Cappuccino
#
#
# 11
# Latte
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Cocoa
#
#
# 11
# Cappuccino
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano
#
#
# 11
# Espresso
#
#
# 11
# Cappuccino
#
#
# 11
# Latte
#
#
# 11
# Cappuccino
#
#
# 11
# Americano with Milk
#
#
# 11
# Cappuccino
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Cocoa
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Latte
#
#
# 11
# Americano
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Hot Chocolate
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Cortado
#
#
# 11
# Cortado
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Americano
#
#
# 11
# Cappuccino
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Espresso
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Cappuccino
#
#
# 11
# Cappuccino
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Cappuccino
#
#
# 11
# Hot Chocolate
#
#
# 11
# Cortado
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Cortado
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Cappuccino
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Cortado
#
#
# 11
# Cortado
#
#
# 11
# Latte
#
#
# 11
# Cappuccino
#
#
# 11
# Americano
#
#
# 11
# Americano
#
#
# 11
# Hot Chocolate
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Cappuccino
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Cortado
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Hot Chocolate
#
#
# 11
# Americano with Milk
#
#
# 11
# Hot Chocolate
#
#
# 11
# Hot Chocolate
#
#
# 11
# Cappuccino
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Americano
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Americano
#
#
# 11
# Americano with Milk
#
#
# 11
# Cocoa
#
#
# 11
# Cappuccino
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Latte
#
#
# 11
# Cappuccino
#
#
# 11
# Cocoa
#
#
# 11
# Latte
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 11
# Latte
#
#
# 11
# Cocoa
#
#
# 11
# Cocoa
#
#
# 11
# Americano
#
#
# 11
# Hot Chocolate
#
#
# 11
# Cocoa
#
#
# 11
# Americano with Milk
#
#
# 11
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Cocoa
#
#
# 12
# Cocoa
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Latte
#
#
# 12
# Latte
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Americano
#
#
# 12
# Americano with Milk
#
#
# 12
# Cocoa
#
#
# 12
# Cortado
#
#
# 12
# Espresso
#
#
# 12
# Cappuccino
#
#
# 12
# Americano
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Cocoa
#
#
# 12
# Latte
#
#
# 12
# Cappuccino
#
#
# 12
# Hot Chocolate
#
#
# 12
# Americano with Milk
#
#
# 12
# Cappuccino
#
#
# 12
# Cortado
#
#
# 12
# Latte
#
#
# 12
# Latte
#
#
# 12
# Americano
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Hot Chocolate
#
#
# 12
# Americano with Milk
#
#
# 12
# Hot Chocolate
#
#
# 12
# Americano
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Americano
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Latte
#
#
# 12
# Latte
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Hot Chocolate
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano
#
#
# 12
# Latte
#
#
# 12
# Cappuccino
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano
#
#
# 12
# Cortado
#
#
# 12
# Latte
#
#
# 12
# Cappuccino
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Cappuccino
#
#
# 12
# Espresso
#
#
# 12
# Cappuccino
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Cappuccino
#
#
# 12
# Americano
#
#
# 12
# Americano with Milk
#
#
# 12
# Cortado
#
#
# 12
# Cocoa
#
#
# 12
# Cortado
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Cortado
#
#
# 12
# Hot Chocolate
#
#
# 12
# Espresso
#
#
# 12
# Cocoa
#
#
# 12
# Latte
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano
#
#
# 12
# Espresso
#
#
# 12
# Espresso
#
#
# 12
# Americano
#
#
# 12
# Cocoa
#
#
# 12
# Cocoa
#
#
# 12
# Americano
#
#
# 12
# Americano
#
#
# 12
# Hot Chocolate
#
#
# 12
# Hot Chocolate
#
#
# 12
# Cocoa
#
#
# 12
# Cappuccino
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Cocoa
#
#
# 12
# Cappuccino
#
#
# 12
# Americano
#
#
# 12
# Latte
#
#
# 12
# Cocoa
#
#
# 12
# Americano
#
#
# 12
# Americano
#
#
# 12
# Americano
#
#
# 12
# Americano
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Cocoa
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Hot Chocolate
#
#
# 12
# Cocoa
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Cortado
#
#
# 12
# Cappuccino
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano
#
#
# 12
# Cocoa
#
#
# 12
# Cappuccino
#
#
# 12
# Cocoa
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Cappuccino
#
#
# 12
# Hot Chocolate
#
#
# 12
# Americano with Milk
#
#
# 12
# Espresso
#
#
# 12
# Hot Chocolate
#
#
# 12
# Cappuccino
#
#
# 12
# Cappuccino
#
#
# 12
# Americano with Milk
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Cappuccino
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Cappuccino
#
#
# 12
# Cortado
#
#
# 12
# Espresso
#
#
# 12
# Americano with Milk
#
#
# 12
# Cortado
#
#
# 12
# Cappuccino
#
#
# 12
# Cappuccino
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Americano
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Cocoa
#
#
# 12
# Hot Chocolate
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Cortado
#
#
# 12
# Cortado
#
#
# 12
# Latte
#
#
# 12
# Cortado
#
#
# 12
# Cappuccino
#
#
# 12
# Cappuccino
#
#
# 12
# Hot Chocolate
#
#
# 12
# Hot Chocolate
#
#
# 12
# Hot Chocolate
#
#
# 12
# Cocoa
#
#
# 12
# Cortado
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Cortado
#
#
# 12
# Latte
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Hot Chocolate
#
#
# 12
# Cortado
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Espresso
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano
#
#
# 12
# Cappuccino
#
#
# 12
# Cocoa
#
#
# 12
# Cocoa
#
#
# 12
# Latte
#
#
# 12
# Cappuccino
#
#
# 12
# Americano with Milk
#
#
# 12
# Cappuccino
#
#
# 12
# Espresso
#
#
# 12
# Americano
#
#
# 12
# Cortado
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Americano
#
#
# 12
# Americano with Milk
#
#
# 12
# Cocoa
#
#
# 12
# Cortado
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Cappuccino
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Cappuccino
#
#
# 12
# Cortado
#
#
# 12
# Espresso
#
#
# 12
# Americano
#
#
# 12
# Cortado
#
#
# 12
# Espresso
#
#
# 12
# Cortado
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Cortado
#
#
# 12
# Americano with Milk
#
#
# 12
# Latte
#
#
# 12
# Hot Chocolate
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano
#
#
# 12
# Cappuccino
#
#
# 12
# Cortado
#
#
# 12
# Cappuccino
#
#
# 12
# Cortado
#
#
# 12
# Cocoa
#
#
# 12
# Americano with Milk
#
#
# 12
# Americano with Milk
#
#
# 12
# Cappuccino
#
#
# 12
# Americano with Milk
#
#
# 12
# Espresso
#
#
# 12
# Americano
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Americano with Milk
#
#
# 12
# Cappuccino
#
#
# 12
# Latte
#
#
# 12
# Hot Chocolate
#
#
# 1
# Americano with Milk
#
#
# 1
# Cocoa
#
#
# 1
# Cocoa
#
#
# 1
# Cortado
#
#
# 1
# Cortado
#
#
# 1
# Americano
#
#
# 1
# Hot Chocolate
#
#
# 1
# Americano with Milk
#
#
# 1
# Cappuccino
#
#
# 1
# Cortado
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cappuccino
#
#
# 1
# Americano
#
#
# 1
# Americano
#
#
# 1
# Latte
#
#
# 1
# Cortado
#
#
# 1
# Americano
#
#
# 1
# Cappuccino
#
#
# 1
# Cocoa
#
#
# 1
# Americano with Milk
#
#
# 1
# Cappuccino
#
#
# 1
# Cappuccino
#
#
# 1
# Cortado
#
#
# 1
# Americano
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano
#
#
# 1
# Cappuccino
#
#
# 1
# Cocoa
#
#
# 1
# Cocoa
#
#
# 1
# Americano with Milk
#
#
# 1
# Latte
#
#
# 1
# Cortado
#
#
# 1
# Cappuccino
#
#
# 1
# Americano
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Espresso
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Cortado
#
#
# 1
# Americano with Milk
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cappuccino
#
#
# 1
# Hot Chocolate
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Hot Chocolate
#
#
# 1
# Americano
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Cortado
#
#
# 1
# Latte
#
#
# 1
# Cortado
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano
#
#
# 1
# Americano with Milk
#
#
# 1
# Hot Chocolate
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cortado
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Espresso
#
#
# 1
# Latte
#
#
# 1
# Cortado
#
#
# 1
# Americano with Milk
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cortado
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Cappuccino
#
#
# 1
# Hot Chocolate
#
#
# 1
# Hot Chocolate
#
#
# 1
# Cortado
#
#
# 1
# Cocoa
#
#
# 1
# Latte
#
#
# 1
# Cappuccino
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cocoa
#
#
# 1
# Cocoa
#
#
# 1
# Hot Chocolate
#
#
# 1
# Hot Chocolate
#
#
# 1
# Americano with Milk
#
#
# 1
# Hot Chocolate
#
#
# 1
# Latte
#
#
# 1
# Hot Chocolate
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cortado
#
#
# 1
# Americano
#
#
# 1
# Cortado
#
#
# 1
# Americano with Milk
#
#
# 1
# Hot Chocolate
#
#
# 1
# Cappuccino
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Cocoa
#
#
# 1
# Cortado
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano
#
#
# 1
# Hot Chocolate
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Americano
#
#
# 1
# Espresso
#
#
# 1
# Americano with Milk
#
#
# 1
# Cocoa
#
#
# 1
# Americano with Milk
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Americano with Milk
#
#
# 1
# Cappuccino
#
#
# 1
# Cortado
#
#
# 1
# Cocoa
#
#
# 1
# Americano
#
#
# 1
# Cocoa
#
#
# 1
# Hot Chocolate
#
#
# 1
# Latte
#
#
# 1
# Cappuccino
#
#
# 1
# Cappuccino
#
#
# 1
# Americano
#
#
# 1
# Americano
#
#
# 1
# Espresso
#
#
# 1
# Cortado
#
#
# 1
# Americano
#
#
# 1
# Cappuccino
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cortado
#
#
# 1
# Americano with Milk
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Americano
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano
#
#
# 1
# Cocoa
#
#
# 1
# Cortado
#
#
# 1
# Americano
#
#
# 1
# Latte
#
#
# 1
# Cappuccino
#
#
# 1
# Americano
#
#
# 1
# Americano
#
#
# 1
# Americano with Milk
#
#
# 1
# Espresso
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cortado
#
#
# 1
# Hot Chocolate
#
#
# 1
# Americano
#
#
# 1
# Americano with Milk
#
#
# 1
# Hot Chocolate
#
#
# 1
# Americano with Milk
#
#
# 1
# Cortado
#
#
# 1
# Americano
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Cocoa
#
#
# 1
# Cappuccino
#
#
# 1
# Cappuccino
#
#
# 1
# Latte
#
#
# 1
# Latte
#
#
# 1
# Cappuccino
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano with Milk
#
#
# 1
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Cortado
#
#
# 2
# Cortado
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with Milk
#
#
# 2
# Espresso
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Cortado
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cortado
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Espresso
#
#
# 2
# Espresso
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Hot Chocolate
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Hot Chocolate
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cappuccino
#
#
# 2
# Espresso
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Latte
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Cortado
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cortado
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cortado
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Cortado
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Cocoa
#
#
# 2
# Cortado
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Cocoa
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Cocoa
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano with Milk
#
#
# 2
# Espresso
#
#
# 2
# Latte
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Hot Chocolate
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Espresso
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano
#
#
# 2
# Espresso
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Espresso
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Hot Chocolate
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Espresso
#
#
# 2
# Cappuccino
#
#
# 2
# Latte
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Espresso
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Cocoa
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano with Milk
#
#
# 2
# Espresso
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Espresso
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Hot Chocolate
#
#
# 2
# Cocoa
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Espresso
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Cappuccino
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Espresso
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Cocoa
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Cocoa
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Cocoa
#
#
# 2
# Cappuccino
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Americano with Milk
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Espresso
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Cappuccino
#
#
# 2
# Americano
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Hot Chocolate
#
#
# 2
# Cocoa
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Cortado
#
#
# 2
# Hot Chocolate
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Hot Chocolate
#
#
# 2
# Latte
#
#
# 2
# Americano with Milk
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Cappuccino
#
#
# 2
# Espresso
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Cocoa
#
#
# 2
# Cocoa
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano with Milk
#
#
# 2
# Cappuccino
#
#
# 2
# Espresso
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Americano
#
#
# 2
# Cocoa
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 2
# Americano with Milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Cocoa
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Cocoa
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Cocoa
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cocoa
#
#
# 3
# Americano
#
#
# 3
# Cocoa
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Cocoa
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Espresso
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Cocoa
#
#
# 3
# Hot Chocolate
#
#
# 3
# Espresso
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Cocoa
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Americano with Milk
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Espresso
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Cocoa
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cocoa
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cocoa
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Cocoa
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Espresso
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Espresso
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Espresso
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cocoa
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Cortado
#
#
# 3
# Espresso
#
#
# 3
# Espresso
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Espresso
#
#
# 3
# Cortado
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cocoa
#
#
# 3
# Cappuccino
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Hot Chocolate
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Hot Chocolate
#
#
# 3
# Cocoa
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano with Milk
#
#
# 3
# Espresso
#
#
# 3
# Latte
#
#
# 3
# Americano with Milk
#
#
# 3
# Americano with Milk
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Cocoa
#
#
# 3
# Cocoa
#
#
# 3
# Americano
#
#
# 3
# Latte
#
#
# 2
# Tea
#
#
# 2
# Tea
#
#
# 2
# Espresso
#
#
# 2
# Chocolate with coffee
#
#
# 2
# Chocolate with milk
#
#
# 2
# Espresso
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Irish whiskey with milk
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Chocolate with coffee
#
#
# 2
# Double espresso
#
#
# 2
# Americano with milk
#
#
# 2
# Espresso
#
#
# 2
# Cappuccino
#
#
# 2
# Double espresso with milk
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Caramel with Irish whiskey
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Americano with milk
#
#
# 2
# Latte
#
#
# 2
# Tea
#
#
# 2
# Caramel with Irish whiskey
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Chocolate with milk
#
#
# 2
# Tea
#
#
# 2
# Americano
#
#
# 2
# Chocolate with milk
#
#
# 2
# Latte
#
#
# 2
# Double espresso with milk
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with milk
#
#
# 2
# Espresso
#
#
# 2
# Espresso
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Espresso
#
#
# 2
# Espresso
#
#
# 2
# Chocolate with milk
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Super chocolate
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Americano
#
#
# 2
# Double vanilla
#
#
# 2
# Mochaccino
#
#
# 2
# Irish whiskey with milk
#
#
# 2
# Tea
#
#
# 2
# Americano with milk
#
#
# 2
# Americano with milk
#
#
# 2
# Latte
#
#
# 2
# Caramel with chocolate
#
#
# 2
# Irish whiskey
#
#
# 2
# Double vanilla
#
#
# 2
# Latte
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Cappuccino
#
#
# 2
# Caramel coffee
#
#
# 2
# Espresso
#
#
# 2
# Cappuccino
#
#
# 2
# Caramel with Irish whiskey
#
#
# 2
# Americano with milk
#
#
# 2
# Espresso
#
#
# 2
# Cappuccino
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Americano with milk
#
#
# 2
# Vanilla with Irish whiskey
#
#
# 2
# Americano with milk
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with milk
#
#
# 2
# Americano
#
#
# 2
# Americano
#
#
# 2
# Americano with milk
#
#
# 2
# Espresso
#
#
# 2
# Cappuccino
#
#
# 2
# Mochaccino
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Americano with milk
#
#
# 2
# Espresso
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Chocolate
#
#
# 2
# Americano with milk
#
#
# 2
# Americano with milk
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Irish whiskey
#
#
# 2
# Mochaccino
#
#
# 2
# Irish whiskey
#
#
# 2
# Americano with milk
#
#
# 2
# Americano with milk
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Espresso
#
#
# 2
# Latte
#
#
# 2
# Americano with milk
#
#
# 2
# Latte
#
#
# 2
# Tea
#
#
# 2
# Caramel with chocolate
#
#
# 2
# Latte
#
#
# 2
# Americano with milk
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Americano
#
#
# 2
# Americano with milk
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Tea
#
#
# 2
# Caramel with Irish whiskey
#
#
# 2
# Caramel with Irish whiskey
#
#
# 2
# Caramel with milk
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Latte
#
#
# 2
# Americano with milk
#
#
# 2
# Americano with milk
#
#
# 2
# Irish whiskey
#
#
# 2
# Latte
#
#
# 2
# Irish whiskey with milk
#
#
# 2
# Tea
#
#
# 2
# Espresso
#
#
# 2
# Tea
#
#
# 2
# Tea
#
#
# 2
# Tea
#
#
# 2
# Tea
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Irish whiskey with milk
#
#
# 2
# Coffee with Irish whiskey
#
#
# 2
# Caramel with milk
#
#
# 2
# Caramel with chocolate
#
#
# 2
# Americano with milk
#
#
# 2
# Tea
#
#
# 2
# Americano with milk
#
#
# 2
# Espresso
#
#
# 2
# Latte
#
#
# 2
# Latte
#
#
# 2
# Cappuccino
#
#
# 2
# Americano with milk
#
#
# 2
# Super chocolate
#
#
# 2
# Double Irish whiskey
#
#
# 2
# Americano with milk
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with milk
#
#
# 3
# Tea
#
#
# 3
# Chocolate with milk
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Cappuccino
#
#
# 3
# Caramel coffee
#
#
# 3
# Coffee with chocolate
#
#
# 3
# Cappuccino
#
#
# 3
# Super chocolate
#
#
# 3
# Irish whiskey
#
#
# 3
# Chocolate with milk
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Latte
#
#
# 3
# Caramel with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Irish whiskey
#
#
# 3
# Irish whiskey
#
#
# 3
# Irish with chocolate
#
#
# 3
# Caramel with Irish whiskey
#
#
# 3
# Americano with milk
#
#
# 3
# Irish whiskey
#
#
# 3
# Vanilla coffee
#
#
# 3
# Espresso
#
#
# 3
# Americano
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Latte
#
#
# 3
# Americano with milk
#
#
# 3
# Americano
#
#
# 3
# Double ristretto
#
#
# 3
# Americano with milk
#
#
# 3
# Irish with chocolate
#
#
# 3
# Irish whiskey
#
#
# 3
# Chocolate with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Espresso
#
#
# 3
# Hot milkshake
#
#
# 3
# Caramel with chocolate
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Americano
#
#
# 3
# Mochaccino
#
#
# 3
# Americano
#
#
# 3
# Vanilla with Irish whiskey
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Chocolate with milk
#
#
# 3
# Americano
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Cappuccino
#
#
# 3
# Cappuccino
#
#
# 3
# Chocolate with milk
#
#
# 3
# Super chocolate
#
#
# 3
# Irish with chocolate
#
#
# 3
# Irish with chocolate
#
#
# 3
# Latte
#
#
# 3
# Americano
#
#
# 3
# Americano with milk
#
#
# 3
# Double Irish whiskey
#
#
# 3
# Americano with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Double Irish whiskey
#
#
# 3
# Latte
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Tea
#
#
# 3
# Espresso
#
#
# 3
# Irish whiskey
#
#
# 3
# Irish whiskey
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Chocolate with milk
#
#
# 3
# Caramel with Irish whiskey
#
#
# 3
# Irish whiskey
#
#
# 3
# Americano with milk
#
#
# 3
# Latte
#
#
# 3
# Cappuccino
#
#
# 3
# Americano with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Coffee with Irish whiskey
#
#
# 3
# Coffee with Irish whiskey
#
#
# 3
# Irish whiskey
#
#
# 3
# Latte
#
#
# 3
# Coffee with Irish whiskey
#
#
# 3
# Coffee with Irish whiskey
#
#
# 3
# Coffee with Irish whiskey
#
#
# 3
# Double Irish whiskey
#
#
# 3
# Espresso
#
#
# 3
# Irish whiskey
#
#
# 3
# Chocolate with coffee
#
#
# 3
# Chocolate with coffee
#
#
# 3
# Irish whiskey
#
#
# 3
# Chocolate with milk
#
#
# 3
# Mochaccino
#
#
# 3
# Latte
#
#
# 3
# Double chocolate
#
#
# 3
# Irish whiskey
#
#
# 3
# Latte
#
#
# 3
# Chocolate with coffee
#
#
# 3
# Irish whiskey
#
#
# 3
# Chocolate with milk
#
#
# 3
# Super chocolate
#
#
# 3
# Americano with milk
#
#
# 3
# Irish whiskey with milk
#
#
# 3
# Irish with chocolate
#
#
# 3
# Irish whiskey
#
#
# 3
# Tea
#
#
# 3
# Irish whiskey
#
#
# 3
# Caramel with Irish whiskey
#
#
# 3
# Caramel
#
#
# 3
# Americano with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Coffee with Irish whiskey
#
#
# 3
# Irish whiskey
#
#
# 3
# Americano with milk
#
#
# 3
# Americano with milk
#
#
# 3
# Cappuccino
#
#
# 3
# Irish whiskey
#
#
# 3
# Super chocolate
#
#
# 3
# Vanilla with Irish whiskey
#
#
# 3
# Coffee with Irish whiskey

# %%
sort_col = [('money', 'sum'), 
            ('coffee_name', 'count')]
sort_or = [True, False]

cdfs_table = cdfs.loc[(cdfs['money'] > 38) & 
(cdfs['month'] == 3), :].groupby('coffee_name').agg(
    {'money': ['sum','median'], 'coffee_name': 'count'}
).sort_values(by=sort_col, ascending=sort_or)

cdfs_table.columns = ['_'.join(
    col).strip() for col in cdfs_table.columns]

cdfs_table.reset_index(inplace=True)
# Orders that cost more than 38$ and were made in March
# Grouped by coffee name and sorted by sum and count

# %%
# Filtering on groupby object
cdfs_table[cdfs_table['coffee_name'] == 'Cappuccino']
# Out:
#   coffee_name  money_sum  money_median  coffee_name_count
# 1  Cappuccino      780.5          38.7                 20

# %% [markdown]
# Splitting the columns inside

# %%
cdfs_new = cdfs.copy()

# %%
# Taking the first name of the coffee name column
# If we want to take the second name, we can use str[1]
cdfs_new['f_name'] = cdfs[
    'coffee_name'].str.split(' ').str[0]

cdfs_new[['f_name','money']]
# Out:
#            f_name  money
# month
# 3           Latte   38.7
# 3             Hot   38.7
# 3             Hot   38.7
# 3       Americano   28.9
# 3           Latte   38.7
# ...           ...    ...
# 3      Cappuccino   30.0
# 3           Irish   25.0
# 3           Super   28.0
# 3         Vanilla   28.0
# 3          Coffee   29.0
#
# [3898 rows x 2 columns]

# %%
# If we want to save the data to a csv file
# Index = False will not add another index column while saving IMPORTANT
cdfs_new.to_csv("cdfs_new.csv", index=False)

# %% [markdown]
# Adding/Removing Columns

# %%
cdfs['section'] = cdfs['money'].apply(lambda x: 'cheap' if x < 19.99 else (
    'normal' if x < 29.99 else 'expensive'))

# %%
cdfs['section'].value_counts()
# Out:
# section
# expensive    2475
# normal       1371
# cheap          52
# Name: count, dtype: int64

# %%
# We can also create function

def typeof_customer(row):
    if row['cash_type'] == 'card' and row ['money'] > 29.99:
        return 'rich'
    elif row['cash_type'] == 'card' and row ['money'] > 19.99:
        return 'middle class'
    else:
        return 'poor'

cdfs['typeof_customer'] = cdfs.apply(typeof_customer, axis=1)
cdfs.groupby('typeof_customer').count()
# Out:
#                  date  htime  cash_type  card  money  coffee_name  month  \
# typeof_customer
# middle class     1298   1298       1298  1166   1298         1298   1298
# poor              215    215        215    36    215          215    215
# rich             2385   2385       2385  2345   2385         2385   2385
#
#                  section
# typeof_customer
# middle class        1298
# poor                 215
# rich                2385

# %%
# MORE EFFICIENT WAY! 

conditions = [
    (cdfs['cash_type'] == 'card') & (cdfs['money'] > 29.99),
    (cdfs['cash_type'] == 'card') & (cdfs['money'] > 10.99),
]

choices = ["rich", "middle class"]

cdfs['typeof_customer'] = np.select(
    conditions,
    choices,
    default="poor"
    )

# %%
# Preparing for ML Ops - Encoding

type_number = {
    'poor' : 1,
    'middle class' : 2,
    'rich' : 3
}

cdfs['typeof_customer'] = cdfs['typeof_customer'].map(type_number)
cdfs[['coffee_name','money','typeof_customer']]
# Out:
#                       coffee_name  money  typeof_customer
# month
# 3                           Latte   38.7                3
# 3                   Hot Chocolate   38.7                3
# 3                   Hot Chocolate   38.7                3
# 3                       Americano   28.9                2
# 3                           Latte   38.7                3
# ...                           ...    ...              ...
# 3                      Cappuccino   30.0                1
# 3                   Irish whiskey   25.0                2
# 3                 Super chocolate   28.0                2
# 3      Vanilla with Irish whiskey   28.0                2
# 3       Coffee with Irish whiskey   29.0                2
#
# [3898 rows x 3 columns]

# %%
cdfs.reset_index(drop=True, inplace=True)

# %%
cdfs['milk'] = np.where(cdfs['coffee_name'].str.contains('with milk'), 'yes','no')

# %%
cdfs[(cdfs['milk'] == 'no') &
(cdfs['section'] == 'expensive') |
(cdfs['section'] == 'cheap')].groupby(cdfs['coffee_name'])[
    ['money','milk']].agg({'money':'sum'})
# Out:
#                           money
# coffee_name
# Americano                180.00
# Americano with Milk    19070.88
# Cappuccino             18514.14
# Chocolate with coffee    150.00
# Cocoa                   8678.16
# Cortado                  150.00
# Espresso                 685.32
# Hot Chocolate          10172.46
# Hot milkshake             30.00
# Latte                  28658.30
# Mochaccino               150.00
# Tea                      240.00

# %%
cdfs['milk'].value_counts()
# Out:
# milk
# no     3822
# yes      76
# Name: count, dtype: int64

# %% [markdown]
# Null Values or NaN Values

# %%
cdfs.fillna(cdfs['money'].interpolate(), inplace=True)

# %%
cdfs.dropna(subset=["money"], inplace=True)

# %%
cdfs[cdfs['card'].isna()]
# Out:
#            date     htime cash_type card  money                 coffee_name  \
# 12   2024-03-02  10:30:35      cash  NaN   40.0                       Latte
# 18   2024-03-03  10:10:43      cash  NaN   40.0                       Latte
# 41   2024-03-06  12:30:27      cash  NaN   35.0         Americano with Milk
# 46   2024-03-07  10:08:58      cash  NaN   40.0                       Latte
# 49   2024-03-07  11:25:43      cash  NaN   40.0                       Latte
# ...         ...       ...       ...  ...    ...                         ...
# 3893 2025-03-23  14:55:46      cash  NaN   30.0                  Cappuccino
# 3894 2025-03-23  15:15:36      card  NaN   25.0               Irish whiskey
# 3895 2025-03-23  17:59:25      card  NaN   28.0             Super chocolate
# 3896 2025-03-23  18:01:33      card  NaN   28.0  Vanilla with Irish whiskey
# 3897 2025-03-23  21:23:11      card  NaN   29.0   Coffee with Irish whiskey
#
#       month    section  typeof_customer milk
# 12        3  expensive                1   no
# 18        3  expensive                1   no
# 41        3  expensive                1   no
# 46        3  expensive                1   no
# 49        3  expensive                1   no
# ...     ...        ...              ...  ...
# 3893      3  expensive                1   no
# 3894      3     normal                2   no
# 3895      3     normal                2   no
# 3896      3     normal                2   no
# 3897      3     normal                2   no
#
# [351 rows x 10 columns]

# %% [markdown]
# List Comprehension

# %%
cdfs.loc[
    cdfs['coffee_name'] == 'Americano',
    ['money','cash_type']
    ].count()
# Out:
# money        593
# cash_type    593
# dtype: int64

# %%
cdfs[cdfs['money'] == 25]['coffee_name'].value_counts()
# Out:
# coffee_name
# Americano with milk    44
# Irish whiskey          21
# Americano              15
# Espresso                4
# Caramel with milk       3
# Chocolate               1
# Double chocolate        1
# Name: count, dtype: int64

# %%
cdfs['milk'] = np.where(
    cdfs['coffee_name'].str.contains('with milk', na=False), 
    'yes',
    'no'
    )

# %%
cdfs.loc[:, 'milk'].value_counts()
# Out:
# milk
# no     3822
# yes      76
# Name: count, dtype: int64

# %%
pivot_table = cdfs.pivot_table(
    index='coffee_name',        
    columns='section',  
    values='money',    
    aggfunc='mean'      # If there are multiple values for the 
                        # same index and column, use the mean
)

pivot_table.fillna('Not Sold', inplace=True)
pivot_table
# Out:
# /var/folders/b2/qc1xpbnn1wxdq6xmj3kvxxvw0000gn/T/ipykernel_19122/1536339781.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Sold' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   pivot_table.fillna('Not Sold', inplace=True)
# section                        cheap  expensive     normal
# coffee_name
# Americano                   Not Sold       30.0  25.991925
# Americano with Milk         Not Sold  31.679203      27.92
# Americano with milk         Not Sold   Not Sold       25.0
# Cappuccino                  Not Sold  35.810716   Not Sold
# Caramel                     Not Sold   Not Sold       22.0
# Caramel coffee              Not Sold   Not Sold       28.0
# Caramel with Irish whiskey  Not Sold   Not Sold       28.0
# Caramel with chocolate      Not Sold   Not Sold       28.0
# Caramel with milk           Not Sold   Not Sold       25.0
# Chocolate                   Not Sold   Not Sold       25.0
# Chocolate with coffee       Not Sold       30.0   Not Sold
# Chocolate with milk         Not Sold   Not Sold       27.0
# Cocoa                       Not Sold  35.712593   Not Sold
# Coffee with Irish whiskey   Not Sold   Not Sold       29.0
# Coffee with chocolate       Not Sold   Not Sold       28.0
# Cortado                     Not Sold       30.0   25.73122
# Double Irish whiskey        Not Sold   Not Sold       28.0
# Double chocolate            Not Sold   Not Sold       25.0
# Double espresso             Not Sold   Not Sold       27.0
# Double espresso with milk   Not Sold       32.0   Not Sold
# Double ristretto            Not Sold   Not Sold       27.0
# Double vanilla              Not Sold   Not Sold       23.5
# Espresso                       18.12       33.0  21.756174
# Hot Chocolate               Not Sold  36.072553   Not Sold
# Hot milkshake               Not Sold       30.0   Not Sold
# Irish whiskey               Not Sold   Not Sold       25.0
# Irish whiskey with milk     Not Sold   Not Sold       27.0
# Irish with chocolate        Not Sold   Not Sold       27.0
# Latte                       Not Sold  35.556203   Not Sold
# Mochaccino                  Not Sold       30.0   Not Sold
# Super chocolate             Not Sold   Not Sold       28.0
# Tea                             15.0   Not Sold   Not Sold
# Vanilla coffee              Not Sold   Not Sold       27.0
# Vanilla with Irish whiskey  Not Sold   Not Sold       28.0

# %%
cdfs['day'] = cdfs['date'].dt.day
cdfs['year'] = cdfs['date'].dt.year

# %%
a = cdfs.groupby(['month','day','coffee_name', 'year']).agg({
    'money':'sum'}).reset_index()

# %%
for a1 in range(1, 12):
  aylık_toplam = a.loc[(a['month'] == a1) & (a['year'] == 2024)]
  toplam_sat = aylık_toplam['money'].sum()
  print(f"{a1}. ay toplam satış: {toplam_sat}")
# Out:
# 1. ay toplam satış: 0.0
# 2. ay toplam satış: 0.0
# 3. ay toplam satış: 7050.2
# 4. ay toplam satış: 6720.5599999999995
# 5. ay toplam satış: 9063.42
# 6. ay toplam satış: 7758.76
# 7. ay toplam satış: 6915.9400000000005
# 8. ay toplam satış: 7613.84
# 9. ay toplam satış: 9988.64
# 10. ay toplam satış: 13891.159999999998
# 11. ay toplam satış: 8590.54

# %%
c = cdfs.groupby(['year', 'month']).agg({'money':'mean'}).reset_index()
aylar = list(range(1,12))
c[(c['year'] == 2024)&(c['month'].isin(aylar))].sum()
# Out:
# year     18216.000000
# month       63.000000
# money      288.624245
# dtype: float64

# %%
cdfs.select_dtypes(include=['float64']).cumsum()
# Out:
#           money
# 0         38.70
# 1         77.40
# 2        116.10
# 3        145.00
# 4        183.70
# ...         ...
# 3893  122211.58
# 3894  122236.58
# 3895  122264.58
# 3896  122292.58
# 3897  122321.58
#
# [3898 rows x 1 columns]
